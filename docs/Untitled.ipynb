# %%
import cartoframes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-41a31b7760a3> in <module>()
# ----> 1 import cartoframes
#
# ModuleNotFoundError: No module named 'cartoframes'
