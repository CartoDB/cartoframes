# %%
import cartoframes
from cartoframes.contrib import vector
from cartoframes import CartoContext

context = CartoContext(
    base_url='https://cartovl.carto.com/', 
    api_key='default_public'
)

viz_string ="""
    @style: ramp($country_name, bold)
    @pop: sqrt($pop_2015) / 200
    width: @pop
    color: @style
    strokeWidth: 1.5
    strokeColor: @style
"""

vector.vmap(
    [vector.Layer(
        'world_population_2015',
        viz_string=viz_string
    )],
    context=context
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x11359f470>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='cartovl.carto.com', port=443): Max retries exceeded with url: /api/v3/api_keys (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11359f470>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-11e9e4fa1fd9> in <module>
#       5 context = CartoContext(
#       6     base_url='https://cartovl.carto.com/',
# ----> 7     api_key='default_public'
#       8 )
#       9
#
# ~/Projects/CARTO/carto-data-science-stack/cartoframes/cartoframes/context.py in __init__(self, base_url, api_key, creds, session, verbose)
#     184         self.sql_client = SQLClient(self.auth_client)
#     185         self.creds.username(self.auth_client.username)
# --> 186         self._is_authenticated()
#     187         self.is_org = self._is_org_user()
#     188
#
# ~/Projects/CARTO/carto-data-science-stack/cartoframes/cartoframes/context.py in _is_authenticated(self)
#     193     def _is_authenticated(self):
#     194         """Checks if credentials allow for authenticated carto access"""
# --> 195         if not self.auth_api_client.is_valid_api_key():
#     196             raise CartoException(
#     197                 'Cannot authenticate user `{}`. Check credentials.'.format(
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/carto/auth.py in is_valid_api_key(self)
#     255         :return: True if the API key is considered valid for current user.
#     256         """
# --> 257         res = self.send('api/v3/api_keys', 'get')
#     258         return \
#     259             res.ok and \
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/pyrestcli/auth.py in send(self, relative_path, http_method, **requests_args)
#      34         url = urljoin(self.base_url, relative_path)
#      35
# ---> 36         return self.session.request(http_method, url, **requests_args)
#      37
#      38     def get_response_data(self, response, parse_json=True):
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/share/virtualenvs/carto-data-science-stack-5Km6N6FZ/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='cartovl.carto.com', port=443): Max retries exceeded with url: /api/v3/api_keys (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11359f470>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
