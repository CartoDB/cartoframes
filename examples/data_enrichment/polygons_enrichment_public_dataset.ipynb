# %% [markdown]
# # Enrich Polygons from a Public Dataset
#
# This example illustrates how to enrich polygons that are in a public dataset with variables from CARTO's Data Observatory.
#
# _Note: You'll need [CARTO Account](https://carto.com/signup) credentials to reproduce this example._

# %%
from cartoframes import CartoDataFrame
from cartoframes.auth import set_default_credentials

set_default_credentials('creds.json')

# %%
census_track = '../files/census_track.geojson'
census_track_cdf = CartoDataFrame.from_file(census_track)
census_track_cdf.head(3)
# Out:
#    OBJECTID  FULLTRACTID TRACTID  \
# 0         1  51013102901  102901
# 1         2  51013103000  103000
# 2         3  51013102902  102902
#
#                                             geometry
# 0  POLYGON ((-77.09099 38.84516, -77.08957 38.844...
# 1  POLYGON ((-77.08558 38.82992, -77.08625 38.828...
# 2  POLYGON ((-77.09520 38.84499, -77.09442 38.844...

# %%
from cartoframes.data.observatory import Catalog

Catalog().country('usa').category('demographics').geographies
# Out:
# [<Geography.get('acs_congression_b6336b2c')>,
#  <Geography.get('mbi_blockgroups_1ab060a')>,
#  <Geography.get('acs_cbsa_6c8b51ef')>,
#  <Geography.get('ags_q17_4739be4f')>,
#  <Geography.get('acs_censustract_bc698c5a')>,
#  <Geography.get('acs_schooldistr_287be4f7')>,
#  <Geography.get('mbi_counties_141b61cd')>,
#  <Geography.get('acs_blockgroup_f45b6b49')>,
#  <Geography.get('mbi_county_subd_e8e6ea23')>,
#  <Geography.get('acs_state_4c8090b5')>,
#  <Geography.get('acs_county_ec40c962')>,
#  <Geography.get('acs_schooldistr_515af763')>,
#  <Geography.get('ags_blockgroup_1c63771c')>,
#  <Geography.get('mbi_pc_5_digit_4b1682a6')>,
#  <Geography.get('acs_schooldistr_da72a4cb')>,
#  <Geography.get('acs_place_12d6699f')>,
#  <Geography.get('acs_puma_b859f0fa')>,
#  <Geography.get('acs_zcta5_75071016')>]

# %%
datasets = Catalog().country('usa').category('demographics').geography('acs_censustract_bc698c5a').datasets
datasets.to_dataframe()
# Out:
#   available_in   category_id category_name country_id     data_source_id  \
# 0         [bq]  demographics  Demographics        usa  sociodemographics
# 1         [bq]  demographics  Demographics        usa  sociodemographics
# 2         [bq]  demographics  Demographics        usa  sociodemographics
# 3         [bq]  demographics  Demographics        usa  sociodemographics
# 4         [bq]  demographics  Demographics        usa  sociodemographics
# 5         [bq]  demographics  Demographics        usa  sociodemographics
# 6         [bq]  demographics  Demographics        usa  sociodemographics
# 7         [bq]  demographics  Demographics        usa  sociodemographics
#
#                                          description  \
# 0  The American Community Survey (ACS) is an ongo...
# 1  The American Community Survey (ACS) is an ongo...
# 2  The American Community Survey (ACS) is an ongo...
# 3  The American Community Survey (ACS) is an ongo...
# 4  The American Community Survey (ACS) is an ongo...
# 5  The American Community Survey (ACS) is an ongo...
# 6  The American Community Survey (ACS) is an ongo...
# 7  The American Community Survey (ACS) is an ongo...
#
#                                geography_description  \
# 0  Shoreline clipped TIGER/Line boundaries. More ...
# 1  Shoreline clipped TIGER/Line boundaries. More ...
# 2  Shoreline clipped TIGER/Line boundaries. More ...
# 3  Shoreline clipped TIGER/Line boundaries. More ...
# 4  Shoreline clipped TIGER/Line boundaries. More ...
# 5  Shoreline clipped TIGER/Line boundaries. More ...
# 6  Shoreline clipped TIGER/Line boundaries. More ...
# 7  Shoreline clipped TIGER/Line boundaries. More ...
#
#                                         geography_id  \
# 0  carto-do-public-data.usa_carto.geography_usa_c...
# 1  carto-do-public-data.usa_carto.geography_usa_c...
# 2  carto-do-public-data.usa_carto.geography_usa_c...
# 3  carto-do-public-data.usa_carto.geography_usa_c...
# 4  carto-do-public-data.usa_carto.geography_usa_c...
# 5  carto-do-public-data.usa_carto.geography_usa_c...
# 6  carto-do-public-data.usa_carto.geography_usa_c...
# 7  carto-do-public-data.usa_carto.geography_usa_c...
#
#                              geography_name  \
# 0  Census Tracts (2015) - shoreline clipped
# 1  Census Tracts (2015) - shoreline clipped
# 2  Census Tracts (2015) - shoreline clipped
# 3  Census Tracts (2015) - shoreline clipped
# 4  Census Tracts (2015) - shoreline clipped
# 5  Census Tracts (2015) - shoreline clipped
# 6  Census Tracts (2015) - shoreline clipped
# 7  Census Tracts (2015) - shoreline clipped
#
#                                                   id  ...  lang  \
# 0  carto-do-public-data.usa_acs.demographics_soci...  ...   eng
# 1  carto-do-public-data.usa_acs.demographics_soci...  ...   eng
# 2  carto-do-public-data.usa_acs.demographics_soci...  ...   eng
# 3  carto-do-public-data.usa_acs.demographics_soci...  ...   eng
# 4  carto-do-public-data.usa_acs.demographics_soci...  ...   eng
# 5  carto-do-public-data.usa_acs.demographics_soci...  ...   eng
# 6  carto-do-public-data.usa_acs.demographics_soci...  ...   eng
# 7  carto-do-public-data.usa_acs.demographics_soci...  ...   eng
#
#                                                 name provider_id  \
# 0  5-yr ACS data at Census Tracts level (2006 - 2...     usa_acs
# 1  5-yr ACS data at Census Tracts level (2007 - 2...     usa_acs
# 2  5-yr ACS data at Census Tracts level (2008 - 2...     usa_acs
# 3  5-yr ACS data at Census Tracts level (2009 - 2...     usa_acs
# 4  5-yr ACS data at Census Tracts level (2010 - 2...     usa_acs
# 5  5-yr ACS data at Census Tracts level (2011 - 2...     usa_acs
# 6  5-yr ACS data at Census Tracts level (2012 - 2...     usa_acs
# 7  5-yr ACS data at Census Tracts level (2013 - 2...     usa_acs
#
#                    provider_name                      slug  \
# 0  USA American Community Survey  acs_sociodemogr_d4b2cf03
# 1  USA American Community Survey  acs_sociodemogr_9ed5d625
# 2  USA American Community Survey  acs_sociodemogr_858c104e
# 3  USA American Community Survey  acs_sociodemogr_cfeb0968
# 4  USA American Community Survey  acs_sociodemogr_97c32d1f
# 5  USA American Community Survey  acs_sociodemogr_dda43439
# 6  USA American Community Survey   acs_sociodemogr_30d1f53
# 7  USA American Community Survey  acs_sociodemogr_496a0675
#
#                                         summary_json temporal_aggregation  \
# 0  {'counts': {'rows': 74002, 'cells': 17464472, ...                 5yrs
# 1  {'counts': {'rows': 74001, 'cells': 18648252, ...                 5yrs
# 2  {'counts': {'rows': 74001, 'cells': 18648252, ...                 5yrs
# 3  {'counts': {'rows': 74001, 'cells': 18648252, ...                 5yrs
# 4  {'counts': {'rows': 74001, 'cells': 18796254, ...                 5yrs
# 5  {'counts': {'rows': 74001, 'cells': 18352248, ...                 5yrs
# 6  {'counts': {'rows': 74001, 'cells': 17908242, ...                 5yrs
# 7  {'counts': {'rows': 74001, 'cells': 18648252, ...                 5yrs
#
#              time_coverage update_frequency   version
# 0  [2006-01-01,2011-01-01)             None  20062010
# 1  [2007-01-01,2012-01-01)             None  20072011
# 2  [2008-01-01,2013-01-01)             None  20082012
# 3  [2009-01-01,2014-01-01)             None  20092013
# 4  [2010-01-01,2015-01-01)             None  20102014
# 5  [2011-01-01,2016-01-01)             None  20112015
# 6  [2012-01-01,2017-01-01)             None  20122016
# 7  [2013-01-01,2018-01-01)             None  20132017
#
# [8 rows x 21 columns]

# %%
from cartoframes.data.observatory import Dataset

dataset = Dataset.get('acs_sociodemogr_496a0675')
variables_df = dataset.variables.to_dataframe()
variables_df[variables_df['description'].str.contains('car', case=False, na=False)]
# Out:
#    agg_method                                    column_name  \
# 2         SUM                                 four_more_cars
# 5         SUM  employed_transportation_warehousing_utilities
# 9         SUM       employed_other_services_not_public_admin
# 13        SUM               employed_education_health_social
# 19        SUM                          commuters_drove_alone
# 21        SUM                           commuters_by_carpool
# 22        SUM                     commuters_by_car_truck_van
# 44        SUM                                     three_cars
# 45        SUM                                       two_cars
# 46        SUM                                        one_car
# 53        SUM                                        no_cars
# 54        SUM                                         no_car
# 91        AVG                                  median_income
#
#                                            dataset_id db_type  \
# 2   carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 5   carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 9   carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 13  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 19  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 21  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 22  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 44  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 45  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 46  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 53  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 54  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
# 91  carto-do-public-data.usa_acs.demographics_soci...   FLOAT
#
#                                           description  \
# 2   Four car households. The number of households ...
# 5   Workers employed in firms in transportation, w...
# 9   Workers employed in firms in other services ex...
# 13  Workers employed in firms in educational servi...
# 19  Commuters who drove alone. The number of worke...
# 21  Commuters by Carpool. The number of workers ag...
# 22  Commuters by Car, Truck, or Van. The number of...
# 44  Three car households. The number of households...
# 45  Two car households. The number of households w...
# 46  One car households. The number of households w...
# 53  Car-free households. The number of households ...
# 54  Workers age 16 and over with no vehicle. All p...
# 91  Median Household Income in the past 12 Months....
#
#                                                    id  \
# 2   carto-do-public-data.usa_acs.demographics_soci...
# 5   carto-do-public-data.usa_acs.demographics_soci...
# 9   carto-do-public-data.usa_acs.demographics_soci...
# 13  carto-do-public-data.usa_acs.demographics_soci...
# 19  carto-do-public-data.usa_acs.demographics_soci...
# 21  carto-do-public-data.usa_acs.demographics_soci...
# 22  carto-do-public-data.usa_acs.demographics_soci...
# 44  carto-do-public-data.usa_acs.demographics_soci...
# 45  carto-do-public-data.usa_acs.demographics_soci...
# 46  carto-do-public-data.usa_acs.demographics_soci...
# 53  carto-do-public-data.usa_acs.demographics_soci...
# 54  carto-do-public-data.usa_acs.demographics_soci...
# 91  carto-do-public-data.usa_acs.demographics_soci...
#
#                                              name                      slug  \
# 2                                  four_more_cars   four_more_cars_60d7217e
# 5   employed_transportation_warehousing_utilities  employed_transp_9e5b20d7
# 9        employed_other_services_not_public_admin  employed_other__46059f67
# 13               employed_education_health_social  employed_educat_f2b1607c
# 19                          commuters_drove_alone  commuters_drove_720e6216
# 21                           commuters_by_carpool  commuters_by_ca_9f22ab27
# 22                     commuters_by_car_truck_van  commuters_by_ca_a0affdc3
# 44                                     three_cars       three_cars_bb82be3d
# 45                                       two_cars         two_cars_2147dcdf
# 46                                        one_car          one_car_f7f299a7
# 53                                        no_cars          no_cars_ded903e2
# 54                                         no_car           no_car_6df757b8
# 91                                  median_income    median_income_9752e312
#
#    starred                                       summary_json  \
# 2     None  {'head': [6, 0, 0, 0, 0, 0, 0, 0, 0, 0], 'tail...
# 5     None  {'head': [43, 0, 0, 0, 0, 0, 0, 19, 0, 0], 'ta...
# 9     None  {'head': [14, 0, 0, 0, 0, 0, 0, 23, 0, 0], 'ta...
# 13    None  {'head': [57, 0, 0, 0, 0, 0, 0, 29, 0, 0], 'ta...
# 19    None  {'head': [141, 0, 0, 0, 0, 0, 0, 0, 0, 0], 'ta...
# 21    None  {'head': [21, 0, 0, 0, 0, 0, 0, 0, 0, 0], 'tai...
# 22    None  {'head': [162, 0, 0, 0, 0, 0, 0, 0, 0, 0], 'ta...
# 44    None  {'head': [0, 0, 0, 0, 0, 0, 0, 13, 0, 0], 'tai...
# 45    None  {'head': [64, 0, 0, 0, 0, 0, 0, 0, 0, 0], 'tai...
# 46    None  {'head': [122, 0, 0, 0, 0, 0, 0, 0, 0, 0], 'ta...
# 53    None  {'head': [151, 0, 0, 0, 0, 0, 0, 0, 0, 0], 'ta...
# 54    None  {'head': [76, 0, 0, 0, 0, 0, 0, 0, 0, 0], 'tai...
# 91    None  {'head': [14410, None, None, None, None, None,...
#
#    variable_group_id
# 2               None
# 5               None
# 9               None
# 13              None
# 19              None
# 21              None
# 22              None
# 44              None
# 45              None
# 46              None
# 53              None
# 54              None
# 91              None

# %%
from cartoframes.data.observatory import Variable

variable = Variable.get('no_car_6df757b8')
variable.to_dict()
# Out:
# {'id': 'carto-do-public-data.usa_acs.demographics_sociodemographics_usa_censustract_2015_5yrs_20132017.no_car',
#  'slug': 'no_car_6df757b8',
#  'name': 'no_car',
#  'description': 'Workers age 16 and over with no vehicle. All people in a geographic area over the age of 16 who do not own a car.',
#  'column_name': 'no_car',
#  'db_type': 'FLOAT',
#  'dataset_id': 'carto-do-public-data.usa_acs.demographics_sociodemographics_usa_censustract_2015_5yrs_20132017',
#  'agg_method': 'SUM',
#  'variable_group_id': None,
#  'starred': None}

# %%
from cartoframes.data.observatory import Enrichment

enrichment = Enrichment()

enriched_dataset_cdf = enrichment.enrich_polygons(
    census_track_cdf,
    variables=[variable],
)

# %%
enriched_dataset_cdf.head(3)
# Out:
#    OBJECTID  FULLTRACTID TRACTID  \
# 0         1  51013102901  102901
# 1         2  51013103000  103000
# 2         3  51013102902  102902
#
#                                             geometry  sum_no_car
# 0  POLYGON ((-77.09099 38.84516, -77.08957 38.844...   47.361711
# 1  POLYGON ((-77.08558 38.82992, -77.08625 38.828...    0.286242
# 2  POLYGON ((-77.09520 38.84499, -77.09442 38.844...  108.591640

# %%
from cartoframes.viz import Map
from cartoframes.viz.helpers import color_continuous_layer

Map(color_continuous_layer(enriched_dataset_cdf, value='sum_no_car'))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.2.0-rc.2.1/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.2.0-rc.2.1/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.2.0-rc.2.1/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/pako/1.0.10/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#
#
#
#
#
#
#         <as-legend
#           heading=&quot;sum_no_car&quot;
#           description=&quot;&quot;>
#           <as-legend-color-continuous-polygon id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-continuous-polygon>
#
#         </as-legend>
#
#
#
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <p>There is a <span class=&quot;errors&quot; id=&quot;error-highlight&quot;></span>
#   from the <a href=&quot;https://carto.com/developers/carto-vl/&quot; target=&quot;_blank&quot;>CARTO VL</a> library:</p>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   function format(value) {
#     if (Array.isArray(value)) {
#       const [first, second] = value;
#       if (first === -Infinity) {
#         return `< ${formatValue(second)}`;
#       }
#       if (second === Infinity) {
#         return `> ${formatValue(first)}`;
#       }
#       return `${formatValue(first)} - ${formatValue(second)}`;
#     }
#     return formatValue(value);
#   }
#
#   function formatValue(value) {
#     if (typeof value === 'number') {
#       return formatNumber(value);
#     }
#     return value;
#   }
#
#   function formatNumber(value) {
#     const log = Math.log10(Math.abs(value));
#
#     if ((log > 4 || log < -2.00000001) && value) {
#       return value.toExponential(2);
#     }
#
#     if (!Number.isInteger(value)) {
#       return value.toLocaleString(undefined, {
#         minimumFractionDigits: 2,
#         maximumFractionDigits: 3
#       });
#     }
#
#     return value.toLocaleString();
#   }
#
#   function updateViewport(map) {
#     function updateMapInfo() {
#       const mapInfo$ = document.getElementById('map-info');
#       const center = map.getCenter();
#       const lat = center.lat.toFixed(6);
#       const lng = center.lng.toFixed(6);
#       const zoom = map.getZoom().toFixed(2);
#
#       mapInfo$.innerText = `viewport={'zoom': ${zoom}, 'lat': ${lat}, 'lng': ${lng}}`;
#     }
#
#     updateMapInfo();
#
#     map.on('zoom', updateMapInfo);
#     map.on('move', updateMapInfo);
#   }
#
#   function getBasecolorSettings(basecolor) {
#     return {
#       'version': 8,
#       'sources': {},
#       'layers': [{
#           'id': 'background',
#           'type': 'background',
#           'paint': {
#               'background-color': basecolor
#           }
#       }]
#     };
#   }
#
#   function getImageElement(mapI
