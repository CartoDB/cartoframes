# %% [markdown]
# # Enrichment Subscription Workflow
#
# This example illustrates how to subscribe and enrich with CARTO's Data Observatory.
#
# _Note: You'll need [CARTO Account](https://carto.com/signup) credentials to reproduce this example._

# %%
from cartoframes import CartoDataFrame
from cartoframes.auth import set_default_credentials

set_default_credentials('creds.json')

# %%
dataset_name = 'carto-do.ags.demographics_retailpotential_usa_blockgroup_2015_yearly_2018'

# %%
from cartoframes.data.observatory import Catalog, Dataset, Geography

dataset = Dataset.get(dataset_name)
geography = Geography.get(dataset.geography)

dataset, geography
# Out:
# (<Dataset.get('ags_retailpoten_ddf56a1a')>,
#  <Geography.get('ags_blockgroup_1c63771c')>)

# %%
dataset.subscribe()
# Out:
# HTML(value='\n        <h3>Subscription already purchased</h3>\n        The dataset <b>carto-do.ags.demographic…

# %%
geography.subscribe()
# Out:
# HTML(value='\n        <h3>Subscription already purchased</h3>\n        The geography <b>carto-do.ags.geography…

# %%
Catalog().subscriptions()
# Out:
# Datasets: [<Dataset.get('ags_retailpoten_ddf56a1a')>]
# Geographies: [<Geography.get('ags_blockgroup_1c63771c')>]

# %%
dataset.variables
# Out:
# [<Variable.get('RSGCY45399_1b746694')> #'Retail Gap: Other Miscellaneous Retail Stores (453...',
#  <Variable.get('RSGCY45393_fba18f8a')> #'Retail Gap: Mobile Home Dealers (45393)',
#  <Variable.get('RSGCY45392_8ca6bf1c')> #'Retail Gap: Art Dealers (45392)',
#  <Variable.get('RSGCY45391_15afeea6')> #'Retail Gap: Pet and Pet Supply Stores (45391)',
#  <Variable.get('RSGCY45331_ef40062c')> #'Retail Gap: Used Merchandise Stores (45331)',
#  <Variable.get('RSGCY45322_6f5266d7')> #'Retail Gap: Gift and Souvenir Stores (45322)',
#  <Variable.get('RSGCY45321_f65b376d')> #'Retail Gap: Office and Stationary Stores (45321)',
#  <Variable.get('RSGCY45311_dd7664ae')> #'Retail Gap: Florists (45311)',
#  <Variable.get('RSGCY45299_1ab60ca3')> #'Retail Gap: Other General Merchandise Stores (4529...',
#  <Variable.get('RSGCY45291_146d8491')> #'Retail Gap: Warehouse Superstores (45291)',
#  <Variable.get('RSGCY45211_dcb40e99')> #'Retail Gap: Department Stores (45211)',
#  <Variable.get('RSGCY45121_f5dfe303')> #'Retail Gap: Book Stores (45121)',
#  <Variable.get('RSGCY45114_ae98444f')> #'Retail Gap: Musical Instrument Stores (45114)',
#  <Variable.get('RSGCY45113_30fcd1ec')> #'Retail Gap: Sewing and Needlecraft Stores (45113)',
#  <Variable.get('RSGCY45112_47fbe17a')> #'Retail Gap: Hobby, Toy, and Game Stores (45112)',
#  <Variable.get('RSGCY45111_def2b0c0')> #'Retail Gap: Sporting Goods Stores (45111)',
#  <Variable.get('RSGCY44832_c2a0df12')> #'Retail Gap: Luggage Stores (44832)',
#  <Variable.get('RSGCY44831_5ba98ea8')> #'Retail Gap: Jewelry Stores (44831)',
#  <Variable.get('RSGCY44821_42b2bfe9')> #'Retail Gap: Shoe Stores (44821)',
#  <Variable.get('RSGCY44819_67446418')> #'Retail Gap: Other Apparel Stores (44819)',
#  <Variable.get('RSGCY44815_6ef22833')> #'Retail Gap: Clothing Accessory Stores (44815)',
#  <Variable.get('RSGCY44814_19f518a5')> #'Retail Gap: Family Clothing Stores (44814)',
#  <Variable.get('RSGCY44813_87918d06')> #'Retail Gap: Childrens' and Infant's Clothing Store...',
#  <Variable.get('RSGCY44812_f096bd90')> #'Retail Gap: Women's Clothing Stores (44812)',
#  <Variable.get('RSGCY44811_699fec2a')> #'Retail Gap: Men's Clothing Stores (44811)',
#  <Variable.get('RSGCY44719_6c182325')> #'Retail Gap: Gasoline Stations (44719)',
#  <Variable.get('RSGCY44619_6dda4912')> #'Retail Gap: Other Health and Personal Care Stores ...',
#  <Variable.get('RSGCY44613_8d0fa00c')> #'Retail Gap: Optical Goods Stores (44613)',
#  <Variable.get('RSGCY44611_6301c120')> #'Retail Gap: Pharmacy and Drug Stores (44611)',
#  <Variable.get('RSGCY44531_53711dfb')> #'Retail Gap: Liquor Stores (44531)',
#  <Variable.get('RSGCY44529_44b1a488')> #'Retail Gap: Other Specialty Food Markets (44529)',
#  <Variable.get('RSGCY44523_a4644d96')> #'Retail Gap: Fruit and Vegetable Markets (44523)',
#  <Variable.get('RSGCY44522_d3637d00')> #'Retail Gap: Fish and Seafood Markets (44522)',
#  <Variable.get('RSGCY44521_4a6a2cba')> #'Retail Gap: Meat Markets (44521)',
#  <Variable.get('RSGCY44512_f84e2ec3')> #'Retail Gap: Convenience Stores (44512)',
#  <Variable.get('RSGCY44511_61477f79')> #'Retail Gap: Grocery Stores (44511)',
#  <Variable.get('RSGCY44422_d2a11737')> #'Retail Gap: Nursery and Garden Stores (44422)',
#  <Variable.get('RSGCY44421_4ba8468d')> #'Retail Gap: Outdoor Power Equipment Stores (44421)',
#  <Variable.get('RSGCY44419_6e5e9d7c')> #'Retail Gap: Other Building Materials Stores (44419...',
#  <Variable.get('RSGCY44412_f98c44f4')> #'Retail Gap: Paint and Wallpaper Stores (44412)',
#  <Variable.get('RSGCY44411_6085154e')> #'Retail Gap: Home Centers (44411)',
#  <Variable.get('RSGCY44311_65ca03cb')> #'Retail Gap: Appliances and Electronics Stores (443...',
#  <Variable.get('RSGCY44229_41feb20d')> #'Retail Gap: Other Home Furnishing Stores (44229)',
#  <Variable.get('RSGCY44221_4f253a3f')> #'Retail Gap: Floor Covering Stores (44221)',
#  <Variable.get('RSGCY44211_640869fc')> #'Retail Gap: Furniture Stores (44211)',
#  <Variable.get('RSGCY44132_cd71e49d')> #'Retail Gap: Tire Dealers (44132)',
#  <Variable.get('MLTCY44511_36af1e74')> #'Grocery Stores (Total Exp)',
#  <Variable.get('MLTCY44422_8549763a')> #'Nursery and Garden Stores (Total Exp)',
#  <Variable.get('MLTCY44421_1c402780')> #'Outdoor Power Equipment Stores (Total Exp)',
#  <Variable.get('MLTCY44419_39b6fc71')> #'Other Building Materials Stores (Total Exp)',
#  <Variable.get('MLTCY44413_d963156f')> #'Hardware Stores (Total Exp)',
#  <Variable.get('MLTCY44412_ae6425f9')> #'Paint and Wallpaper Stores (Total Exp)',
#  <Variable.get('MLTCY44411_376d7443')> #'Home Centers (Total Exp)',
#  <Variable.get('MLTCY44311_322262c6')> #'Appliances and Electronics Stores (Total Exp)',
#  <Variable.get('MLTCY44229_1616d300')> #'Other Home Furnishing Stores (Total Exp)',
#  <Variable.get('MLTCY44221_18cd5b32')> #'Floor Covering Stores (Total Exp)',
#  <Variable.get('MLTCY44211_33e008f1')> #'Furniture Stores (Total Exp)',
#  <Variable.get('MLTCY44132_9a998590')> #'Tire Dealers (Total Exp)',
#  <Variable.get('MLTCY44131_390d42a')> #'Auto Parts and Accessories (Total Exp)',
#  <Variable.get('MLTCY44122_8382b4d1')> #'Motorcycle and Boat Dealers (Total Exp)',
#  <Variable.get('MLTCY44121_1a8be56b')> #'Recreational Vehicle Dealers (Total Exp)',
#  <Variable.get('MLTCY44112_a8afe712')> #'User Car Dealers (Total Exp)',
#  <Variable.get('MLTCY44111_31a6b6a8')> #'New Car Dealers (Total Exp)',
#  <Variable.get('HHDCY_411178d2')> #'Households (2019A)',
#  <Variable.get('BLOCKGROUP_6a16eb3f')> #'Geographic Identifier',
#  <Variable.get('RSGCY7224_af96bdd')> #'Retail Gap: Drinking Places (7224)',
#  <Variable.get('RSGCY7223_949dfe7e')> #'Retail Gap: Special Food Services and Catering (72...',
#  <Variable.get('RSGCY7222_e39acee8')> #'Retail Gap: Limited Service Restaurants (7222)',
#  <Variable.get('RSGCY7221_7a939f52')> #'Retail Gap: Full Service Restaurants (7221)',
#  <Variable.get('RSGCY7213_bfb0adbd')> #'Retail Gap: Retail at Rooming and Boarding Houses ...',
#  <Variable.get('RSGCY7212_c8b79d2b')> #'Retail Gap: Retail at RV Parks (7212)',
#  <Variable.get('RSGCY7211_51becc91')> #'Retail Gap: Retail at Hotels and Other Travel Acco...',
#  <Variable.get('RSGCY45439_e4d4989b')> #'Retail Gap: Other Direct Selling Establishments (4...',
#  <Variable.get('RSGCY45431_ea0f10a9')> #'Retail Gap: Fuel Dealers (45431)',
#  <Variable.get('RSGCY45421_f31421e8')> #'Retail Gap: Vending Machines (45421)',
#  <Variable.get('RSGCY45411_d839722b')> #'Retail Gap: Mail Order and Catalog Stores (45411)',
#  <Variable.get('RSGCY44131_5478b527')> #'Retail Gap: Auto Parts and Accessories (44131)',
#  <Variable.get('RSGCY44122_d46ad5dc')> #'Retail Gap: Motorcycle and Boat Dealers (44122)',
#  <Variable.get('RSGCY44121_4d638466')> #'Retail Gap: Recreational Vehicle Dealers (44121)',
#  <Variable.get('RSGCY44112_ff47861f')> #'Retail Gap: User Car Dealers (44112)',
#  <Variable.get('RSGCY44111_664ed7a5')> #'Retail Gap: New Car Dealers (44111)',
#  <Variable.get('MLTCY7224_8a2d43a9')> #'Drinking Places (Total Exp)',
#  <Variable.get('MLTCY7223_1449d60a')> #'Special Food Services and Catering (Total Exp)',
#  <Variable.get('MLTCY7222_634ee69c')> #'Limited Service Restaurants (Total Exp)',
#  <Variable.get('MLTCY7221_fa47b726')> #'Full Service Restaurants (Total Exp)',
#  <Variable.get('MLTCY7213_3f6485c9')> #'Retail at Rooming and Boarding Houses (Total Exp)',
#  <Variable.get('MLTCY7212_4863b55f')> #'Retail at RV Parks (Total Exp)',
#  <Variable.get('MLTCY7211_d16ae4e5')> #'Retail at Hotels and Other Travel Accomodations (T...',
#  <Variable.get('MLTCY45439_b33cf996')> #'Other Direct Selling Establishments (Total Exp)',
#  <Variable.get('MLTCY45431_bde771a4')> #'Fuel Dealers (Total Exp)',
#  <Variable.get('MLTCY45421_a4fc40e5')> #'Vending Machines (Total Exp)',
#  <Variable.get('MLTCY45411_8fd11326')> #'Mail Order and Catalog Stores (Total Exp)',
#  <Variable.get('MLTCY45399_4c9c0799')> #'Other Miscellaneous Retail Stores (Total Exp)',
#  <Variable.get('MLTCY45393_ac49ee87')> #'Mobile Home Dealers (Total Exp)',
#  <Variable.get('MLTCY45392_db4ede11')> #'Art Dealers (Total Exp)',
#  <Variable.get('MLTCY45391_42478fab')> #'Pet and Pet Supply Stores (Total Exp)',
#  <Variable.get('MLTCY45331_b8a86721')> #'Used Merchandise Stores (Total Exp)',
#  <Variable.get('MLTCY45321_a1b35660')> #'Office and Stationary Stores (Total Exp)',
#  <Variable.get('MLTCY45311_8a9e05a3')> #'Florists (Total Exp)',
#  <Variable.get('MLTCY45299_4d5e6dae')> #'Other General Merchandise Stores (Total Exp)',
#  <Variable.get('MLTCY45291_4385e59c')> #'Warehouse Superstores (Total Exp)',
#  <Variable.get('MLTCY45211_8b5c6f94')> #'Department Stores (Total Exp)',
#  <Variable.get('MLTCY45121_a237820e')> #'Book Stores (Total Exp)',
#  <Variable.get('MLTCY45114_f9702542')> #'Musical Instrument Stores (Total Exp)',
#  <Variable.get('MLTCY45113_6714b0e1')> #'Sewing and Needlecraft Stores (Total Exp)',
#  <Variable.get('MLTCY45112_10138077')> #'Hobby, Toy, and Game Stores (Total Exp)',
#  <Variable.get('MLTCY45111_891ad1cd')> #'Sporting Goods Stores (Total Exp)',
#  <Variable.get('MLTCY44832_9548be1f')> #'Luggage Stores (Total Exp)',
#  <Variable.get('MLTCY44831_c41efa5')> #'Jewelry Stores (Total Exp)',
#  <Variable.get('MLTCY44819_30ac0515')> #'Other Apparel Stores (Total Exp)',
#  <Variable.get('MLTCY44815_391a493e')> #'Clothing Accessory Stores (Total Exp)',
#  <Variable.get('MLTCY44814_4e1d79a8')> #'Family Clothing Stores (Total Exp)',
#  <Variable.get('MLTCY44812_a77edc9d')> #'Womens Clothing Stores (Total Exp)',
#  <Variable.get('MLTCY44811_3e778d27')> #'Mens Clothing Stores (Total Exp)',
#  <Variable.get('MLTCY44719_3bf04228')> #'Gasoline Stations (Total Exp)',
#  <Variable.get('MLTCY44619_3a32281f')> #'Other Health and Personal Care Stores (Total Exp)',
#  <Variable.get('MLTCY44613_dae7c101')> #'Optical Goods Stores (Total Exp)',
#  <Variable.get('MLTCY44612_ade0f197')> #'Costmetics and Beauty Stores (Total Exp)',
#  <Variable.get('MLTCY44611_34e9a02d')> #'Pharmacy and Drug Stores (Total Exp)',
#  <Variable.get('MLTCY44531_4997cf6')> #'Liquor Stores (Total Exp)',
#  <Variable.get('MLTCY44529_1359c585')> #'Other Specialty Food Markets (Total Exp)',
#  <Variable.get('MLTCY44523_f38c2c9b')> #'Fruit and Vegetable Markets (Total Exp)',
#  <Variable.get('MLTCY44521_1d824db7')> #'Meat Markets (Total Exp)',
#  <Variable.get('MLTCY44512_afa64fce')> #'Convenience Stores (Total Exp)',
#  <Variable.get('MLTCY44813_d079ec0b')> #'Childrens and Infants Clothing Stores (Total Exp)',
#  <Variable.get('RSGCY44612_fa08909a')> #'Retail Gap: Costmetics and Beauty Stores (44612)',
#  <Variable.get('RSGCY44413_8e8b7462')> #'Retail Gap: Hardware Stores (44413)',
#  <Variable.get('MLTCY44821_155adee4')> #'Shoe Stores (Total Exp)',
#  <Variable.get('MLTCY44522_848b1c0d')> #'Fish and Seafood Markets (Total Exp)',
#  <Variable.get('MLTCY45322_38ba07da')> #'Gift and Souvenir Stores (Total Exp)']

# %%
variable = dataset.variables.get('MLTCY44111_31a6b6a8')
variable
# Out:
# <Variable.get('MLTCY44111_31a6b6a8')> #'New Car Dealers (Total Exp)'

# %%
census_track = '../files/census_track.geojson'
census_track_cdf = CartoDataFrame.from_file(census_track)
census_track_cdf.head(3)
# Out:
#    OBJECTID  FULLTRACTID TRACTID  \
# 0         1  51013102901  102901
# 1         2  51013103000  103000
# 2         3  51013102902  102902
#
#                                             geometry
# 0  POLYGON ((-77.09099 38.84516, -77.08957 38.844...
# 1  POLYGON ((-77.08558 38.82992, -77.08625 38.828...
# 2  POLYGON ((-77.09520 38.84499, -77.09442 38.844...

# %%
from cartoframes.data.observatory import Enrichment

enrichment = Enrichment()

enriched_dataset_cdf = enrichment.enrich_polygons(
    census_track_cdf,
    variables=['MLTCY44111_31a6b6a8']
)

# %%
enriched_dataset_cdf.head(3)
# Out:
#    OBJECTID  FULLTRACTID TRACTID  \
# 0         1  51013102901  102901
# 1         2  51013103000  103000
# 2         3  51013102902  102902
#
#                                             geometry  sum_MLTCY44111
# 0  POLYGON ((-77.09099 38.84516, -77.08957 38.844...    3.826191e+06
# 1  POLYGON ((-77.08558 38.82992, -77.08625 38.828...    3.950480e+06
# 2  POLYGON ((-77.09520 38.84499, -77.09442 38.844...    8.129480e+06

# %%
from cartoframes.viz import Map
from cartoframes.viz.helpers import color_continuous_layer

Map(color_continuous_layer(enriched_dataset_cdf, value='sum_MLTCY44111'))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.2.0-rc.2.1/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.2.0-rc.2.1/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.2.0-rc.2.1/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/pako/1.0.10/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#
#
#
#
#
#
#         <as-legend
#           heading=&quot;sum_MLTCY44111&quot;
#           description=&quot;&quot;>
#           <as-legend-color-continuous-polygon id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-continuous-polygon>
#
#         </as-legend>
#
#
#
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <p>There is a <span class=&quot;errors&quot; id=&quot;error-highlight&quot;></span>
#   from the <a href=&quot;https://carto.com/developers/carto-vl/&quot; target=&quot;_blank&quot;>CARTO VL</a> library:</p>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   function format(value) {
#     if (Array.isArray(value)) {
#       const [first, second] = value;
#       if (first === -Infinity) {
#         return `< ${formatValue(second)}`;
#       }
#       if (second === Infinity) {
#         return `> ${formatValue(first)}`;
#       }
#       return `${formatValue(first)} - ${formatValue(second)}`;
#     }
#     return formatValue(value);
#   }
#
#   function formatValue(value) {
#     if (typeof value === 'number') {
#       return formatNumber(value);
#     }
#     return value;
#   }
#
#   function formatNumber(value) {
#     const log = Math.log10(Math.abs(value));
#
#     if ((log > 4 || log < -2.00000001) && value) {
#       return value.toExponential(2);
#     }
#
#     if (!Number.isInteger(value)) {
#       return value.toLocaleString(undefined, {
#         minimumFractionDigits: 2,
#         maximumFractionDigits: 3
#       });
#     }
#
#     return value.toLocaleString();
#   }
#
#   function updateViewport(map) {
#     function updateMapInfo() {
#       const mapInfo$ = document.getElementById('map-info');
#       const center = map.getCenter();
#       const lat = center.lat.toFixed(6);
#       const lng = center.lng.toFixed(6);
#       const zoom = map.getZoom().toFixed(2);
#
#       mapInfo$.innerText = `viewport={'zoom': ${zoom}, 'lat': ${lat}, 'lng': ${lng}}`;
#     }
#
#     updateMapInfo();
#
#     map.on('zoom', updateMapInfo);
#     map.on('move', updateMapInfo);
#   }
#
#   function getBasecolorSettings(basecolor) {
#     return {
#       'version': 8,
#       'sources': {},
#       'layers': [{
#           'id': 'background',
#           'type': 'background',
#           'paint': {
#               'background-color': basecolor
#           }
#       }]
#     };
#   }
#
#   function getImageElement(
