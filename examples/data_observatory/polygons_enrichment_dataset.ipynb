# %% [markdown]
# # Enrich Polygons from a Dataset
#
# This example illustrates how to enrich polygons that are in a dataset with variables from CARTO's Data Observatory.
#
# _Note: You'll need [CARTO Account](https://carto.com/signup) credentials to reproduce this example._

# %%
from cartoframes.auth import set_default_credentials

set_default_credentials('creds.json')

# %%
from geopandas import read_file

census_track = 'http://libs.cartocdn.com/cartoframes/files/census_track.geojson'
census_track_gdf = read_file(census_track)
census_track_gdf.head(3)
# Out:
#    OBJECTID  FULLTRACTID TRACTID  \
# 0         1  51013102901  102901
# 1         2  51013103000  103000
# 2         3  51013102902  102902
#
#                                             geometry
# 0  POLYGON ((-77.09099 38.84516, -77.08957 38.844...
# 1  POLYGON ((-77.08558 38.82992, -77.08625 38.828...
# 2  POLYGON ((-77.09520 38.84499, -77.09442 38.844...

# %%
from cartoframes.data.observatory import Catalog

Catalog().country('usa').category('demographics').geographies
# Out:
# [<Geography.get('ags_q17_4739be4f')>,
#  <Geography.get('expn_grid_a4075de4')>,
#  <Geography.get('mbi_blockgroups_1ab060a')>,
#  <Geography.get('mbi_counties_141b61cd')>,
#  <Geography.get('mbi_county_subd_e8e6ea23')>,
#  <Geography.get('mbi_pc_5_digit_4b1682a6')>,
#  <Geography.get('usct_blockgroup_f45b6b49')>,
#  <Geography.get('usct_cbsa_6c8b51ef')>,
#  <Geography.get('usct_censustract_bc698c5a')>,
#  <Geography.get('usct_congression_b6336b2c')>,
#  <Geography.get('usct_county_ec40c962')>,
#  <Geography.get('usct_county_92f1b5df')>,
#  <Geography.get('usct_place_12d6699f')>,
#  <Geography.get('usct_puma_b859f0fa')>,
#  <Geography.get('usct_schooldistr_515af763')>,
#  <Geography.get('usct_schooldistr_da72a4cb')>,
#  <Geography.get('usct_schooldistr_287be4f7')>,
#  <Geography.get('usct_state_4c8090b5')>,
#  <Geography.get('usct_zcta5_75071016')>]

# %%
datasets = Catalog().country('usa').category('demographics').geography('usct_censustract_bc698c5a').datasets
datasets.to_dataframe()
# Out:
#                                                   id  \
# 0  carto-do-public-data.usa_acs.demographics_soci...
# 1  carto-do-public-data.usa_acs.demographics_soci...
# 2  carto-do-public-data.usa_acs.demographics_soci...
# 3  carto-do-public-data.usa_acs.demographics_soci...
# 4  carto-do-public-data.usa_acs.demographics_soci...
# 5  carto-do-public-data.usa_acs.demographics_soci...
# 6  carto-do-public-data.usa_acs.demographics_soci...
# 7  carto-do-public-data.usa_acs.demographics_soci...
#
#                        slug  \
# 0  acs_sociodemogr_d4b2cf03
# 1  acs_sociodemogr_9ed5d625
# 2  acs_sociodemogr_858c104e
# 3  acs_sociodemogr_cfeb0968
# 4  acs_sociodemogr_97c32d1f
# 5  acs_sociodemogr_dda43439
# 6   acs_sociodemogr_30d1f53
# 7  acs_sociodemogr_496a0675
#
#                                                 name  \
# 0  5-yr ACS data at Census Tracts level (2006 - 2...
# 1  5-yr ACS data at Census Tracts level (2007 - 2...
# 2  5-yr ACS data at Census Tracts level (2008 - 2...
# 3  5-yr ACS data at Census Tracts level (2009 - 2...
# 4  5-yr ACS data at Census Tracts level (2010 - 2...
# 5  5-yr ACS data at Census Tracts level (2011 - 2...
# 6  5-yr ACS data at Census Tracts level (2012 - 2...
# 7  5-yr ACS data at Census Tracts level (2013 - 2...
#
#                                          description country_id  \
# 0  The American Community Survey (ACS) is an ongo...        usa
# 1  The American Community Survey (ACS) is an ongo...        usa
# 2  The American Community Survey (ACS) is an ongo...        usa
# 3  The American Community Survey (ACS) is an ongo...        usa
# 4  The American Community Survey (ACS) is an ongo...        usa
# 5  The American Community Survey (ACS) is an ongo...        usa
# 6  The American Community Survey (ACS) is an ongo...        usa
# 7  The American Community Survey (ACS) is an ongo...        usa
#
#                                         geography_id  \
# 0  carto-do-public-data.usa_carto.geography_usa_c...
# 1  carto-do-public-data.usa_carto.geography_usa_c...
# 2  carto-do-public-data.usa_carto.geography_usa_c...
# 3  carto-do-public-data.usa_carto.geography_usa_c...
# 4  carto-do-public-data.usa_carto.geography_usa_c...
# 5  carto-do-public-data.usa_carto.geography_usa_c...
# 6  carto-do-public-data.usa_carto.geography_usa_c...
# 7  carto-do-public-data.usa_carto.geography_usa_c...
#
#                              geography_name  \
# 0  Census Tracts (2015) - shoreline clipped
# 1  Census Tracts (2015) - shoreline clipped
# 2  Census Tracts (2015) - shoreline clipped
# 3  Census Tracts (2015) - shoreline clipped
# 4  Census Tracts (2015) - shoreline clipped
# 5  Census Tracts (2015) - shoreline clipped
# 6  Census Tracts (2015) - shoreline clipped
# 7  Census Tracts (2015) - shoreline clipped
#
#                                geography_description   category_id  \
# 0  Shoreline clipped TIGER/Line boundaries. More ...  demographics
# 1  Shoreline clipped TIGER/Line boundaries. More ...  demographics
# 2  Shoreline clipped TIGER/Line boundaries. More ...  demographics
# 3  Shoreline clipped TIGER/Line boundaries. More ...  demographics
# 4  Shoreline clipped TIGER/Line boundaries. More ...  demographics
# 5  Shoreline clipped TIGER/Line boundaries. More ...  demographics
# 6  Shoreline clipped TIGER/Line boundaries. More ...  demographics
# 7  Shoreline clipped TIGER/Line boundaries. More ...  demographics
#
#   category_name provider_id                  provider_name     data_source_id  \
# 0  Demographics     usa_acs  USA American Community Survey  sociodemographics
# 1  Demographics     usa_acs  USA American Community Survey  sociodemographics
# 2  Demographics     usa_acs  USA American Community Survey  sociodemographics
# 3  Demographics     usa_acs  USA American Community Survey  sociodemographics
# 4  Demographics     usa_acs  USA American Community Survey  sociodemographics
# 5  Demographics     usa_acs  USA American Community Survey  sociodemographics
# 6  Demographics     usa_acs  USA American Community Survey  sociodemographics
# 7  Demographics     usa_acs  USA American Community Survey  sociodemographics
#
#   lang temporal_aggregation             time_coverage update_frequency  \
# 0  eng                 5yrs  [2006-01-01, 2011-01-01)             None
# 1  eng                 5yrs  [2007-01-01, 2012-01-01)             None
# 2  eng                 5yrs  [2008-01-01, 2013-01-01)             None
# 3  eng                 5yrs  [2009-01-01, 2014-01-01)             None
# 4  eng                 5yrs  [2010-01-01, 2015-01-01)             None
# 5  eng                 5yrs  [2011-01-01, 2016-01-01)             None
# 6  eng                 5yrs  [2012-01-01, 2017-01-01)             None
# 7  eng                 5yrs  [2013-01-01, 2018-01-01)             None
#
#     version  is_public_data
# 0  20062010            True
# 1  20072011            True
# 2  20082012            True
# 3  20092013            True
# 4  20102014            True
# 5  20112015            True
# 6  20122016            True
# 7  20132017            True

# %%
from cartoframes.data.observatory import Dataset

dataset = Dataset.get('acs_sociodemogr_d4b2cf03')
variables_df = dataset.variables.to_dataframe()
variables_df[variables_df['description'].str.contains('car', case=False, na=False)]
# Out:
#                                                     id  \
# 27   carto-do-public-data.usa_acs.demographics_soci...
# 28   carto-do-public-data.usa_acs.demographics_soci...
# 31   carto-do-public-data.usa_acs.demographics_soci...
# 46   carto-do-public-data.usa_acs.demographics_soci...
# 50   carto-do-public-data.usa_acs.demographics_soci...
# 54   carto-do-public-data.usa_acs.demographics_soci...
# 85   carto-do-public-data.usa_acs.demographics_soci...
# 164  carto-do-public-data.usa_acs.demographics_soci...
# 170  carto-do-public-data.usa_acs.demographics_soci...
# 171  carto-do-public-data.usa_acs.demographics_soci...
# 181  carto-do-public-data.usa_acs.demographics_soci...
# 217  carto-do-public-data.usa_acs.demographics_soci...
# 219  carto-do-public-data.usa_acs.demographics_soci...
#
#                          slug                                           name  \
# 27   commuters_by_ca_120481e3                     commuters_by_car_truck_van
# 28   commuters_by_ca_59febe6f                           commuters_by_carpool
# 31    commuters_drove_acf77a1                          commuters_drove_alone
# 46   employed_educat_958fdcfe               employed_education_health_social
# 50   employed_other__a5acf594       employed_other_services_not_public_admin
# 54   employed_transp_66aedbfd  employed_transportation_warehousing_utilities
# 85    four_more_cars_297e8a8a                                 four_more_cars
# 164    median_income_57be5af4                                  median_income
# 170           no_car_2207f034                                         no_car
# 171          no_cars_3a983c4e                                        no_cars
# 181          one_car_13b3a60b                                        one_car
# 217       three_cars_32e541e7                                     three_cars
# 219         two_cars_fec37223                                       two_cars
#
#                                            description  \
# 27   Commuters by Car, Truck, or Van. The number of...
# 28   Commuters by Carpool. The number of workers ag...
# 31   Commuters who drove alone. The number of worke...
# 46   Workers employed in firms in educational servi...
# 50   Workers employed in firms in other services ex...
# 54   Workers employed in firms in transportation, w...
# 85   Four car households. The number of households ...
# 164  Median Household Income in the past 12 Months....
# 170  Workers age 16 and over with no vehicle. All p...
# 171  Car-free households. The number of households ...
# 181  One car households. The number of households w...
# 217  Three car households. The number of households...
# 219  Two car households. The number of households w...
#
#                                        column_name db_type  \
# 27                      commuters_by_car_truck_van   FLOAT
# 28                            commuters_by_carpool   FLOAT
# 31                           commuters_drove_alone   FLOAT
# 46                employed_education_health_social   FLOAT
# 50        employed_other_services_not_public_admin   FLOAT
# 54   employed_transportation_warehousing_utilities   FLOAT
# 85                                  four_more_cars   FLOAT
# 164                                  median_income   FLOAT
# 170                                         no_car   FLOAT
# 171                                        no_cars   FLOAT
# 181                                        one_car   FLOAT
# 217                                     three_cars   FLOAT
# 219                                       two_cars   FLOAT
#
#                                             dataset_id agg_method  \
# 27   carto-do-public-data.usa_acs.demographics_soci...        SUM
# 28   carto-do-public-data.usa_acs.demographics_soci...        SUM
# 31   carto-do-public-data.usa_acs.demographics_soci...        SUM
# 46   carto-do-public-data.usa_acs.demographics_soci...        SUM
# 50   carto-do-public-data.usa_acs.demographics_soci...        SUM
# 54   carto-do-public-data.usa_acs.demographics_soci...        SUM
# 85   carto-do-public-data.usa_acs.demographics_soci...        SUM
# 164  carto-do-public-data.usa_acs.demographics_soci...        AVG
# 170  carto-do-public-data.usa_acs.demographics_soci...        SUM
# 171  carto-do-public-data.usa_acs.demographics_soci...        SUM
# 181  carto-do-public-data.usa_acs.demographics_soci...        SUM
# 217  carto-do-public-data.usa_acs.demographics_soci...        SUM
# 219  carto-do-public-data.usa_acs.demographics_soci...        SUM
#
#     variable_group_id starred
# 27               None    None
# 28               None    None
# 31               None    None
# 46               None    None
# 50               None    None
# 54               None    None
# 85               None    None
# 164              None    None
# 170              None    None
# 171              None    None
# 181              None    None
# 217              None    None
# 219              None    None

# %%
from cartoframes.data.observatory import Variable

variable = Variable.get('no_car_2207f034')
variable.to_dict()
# Out:
# {'id': 'carto-do-public-data.usa_acs.demographics_sociodemographics_usa_censustract_2015_5yrs_20062010.no_car',
#  'slug': 'no_car_2207f034',
#  'name': 'no_car',
#  'description': 'Workers age 16 and over with no vehicle. All people in a geographic area over the age of 16 who do not own a car.',
#  'column_name': 'no_car',
#  'db_type': 'FLOAT',
#  'dataset_id': 'carto-do-public-data.usa_acs.demographics_sociodemographics_usa_censustract_2015_5yrs_20062010',
#  'agg_method': 'SUM',
#  'variable_group_id': None,
#  'starred': None}

# %%
from cartoframes.data.observatory import Enrichment

enrichment = Enrichment()

enriched_dataset_gdf = enrichment.enrich_polygons(
    census_track_gdf,
    variables=[variable],
    aggregation='SUM'
)

# %%
enriched_dataset_gdf.head(3)
# Out:
#    OBJECTID  FULLTRACTID TRACTID  \
# 0         1  51013102901  102901
# 1         2  51013103000  103000
# 2         3  51013102902  102902
#
#                                             geometry      no_car
# 0  POLYGON ((-77.09099 38.84516, -77.08957 38.844...    0.657821
# 1  POLYGON ((-77.08558 38.82992, -77.08625 38.828...   87.516848
# 2  POLYGON ((-77.09520 38.84499, -77.09442 38.844...  123.512837

# %%
from cartoframes.viz import Layer, color_continuous_style

Layer(enriched_dataset_gdf, color_continuous_style('no_car'))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3.1-rc.1/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3.1-rc.1/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3.1-rc.1/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3.1-rc.1/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3.1-rc.1/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;no_car&quot;
#                 description=&quot;&quot;>
#                 <as-legend-color-continuous id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-continuous>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval &&
