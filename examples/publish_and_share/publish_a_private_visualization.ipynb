# %% [markdown]
# # Publish a private visualization
#
# This example illustrate how to publish a private visualization.
#
# Read more about Maps API Keys: https://carto.com/developers/auth-api/guides/types-of-API-Keys/
#
# > Note: CARTO Account credentials are needed to reproduce this example. https://carto.com/signup

# %%
from cartoframes.auth import set_default_credentials

set_default_credentials('johnsmith', '1a2b3c4d5e6f7g8h9i0j')

# %%
from cartoframes import CartoDataFrame

cdf = CartoDataFrame.from_file('../files/sustainable_palm_oil_production_mills.geojson')
cdf.head()
# Out:
#    objectid  cartodb_id entity_id  latitude   longitude  \
# 0         1          59    ID1822 -1.585833  103.205556
# 1         2         153    ID1847  0.077043  102.030838
# 2         3         103    ID1720  1.660222  100.590611
# 3         4         216    ID1945 -2.894444  112.543611
# 4         5         156    ID1553  3.593333   98.947222
#
#               audit_stat  legal_radi  illegal_ra  radius_umd  radius_for  ...  \
# 0                  ASA 1           0    0.321764    0.225759        1099  ...
# 1  Renewal Certification           0    0.445960    0.258855        1979  ...
# 2  Initial Certification           0    0.498531    0.248520        1432  ...
# 3                  ASA 1           0    0.662863    0.186332         226  ...
# 4  Initial Certification           0    0.533668    0.028972         382  ...
#
#    carbon_r_3  peat_for_2  peat_for_3  primary_10  primary_11  \
# 0        1224           0          29    0.004508    0.135391
# ...

# %%
from cartoframes.io import update_table

table_name = 'sustainable_palm_oil_production_mills_private'
cdf.to_carto(table_name, if_exists='replace')
update_table(table_name=table_name, privacy='private')
# Out:
# Debug: creating table "sustainable_palm_oil_production_mills_private"
# Success! Data uploaded correctly
# Success! Table updated correctly

# %%
from cartoframes.viz import Map, Layer

map_viz = Map(Layer(cdf))
map_viz.publish(name='sustainable_palm_oil_production_mills_private_map', password='mypassword')
# Out:
# Debug: creating table "sustainable_palm_oil_production_mills_private_map_1574266590890"
# Success! Data uploaded correctly
# {'id': '02251e11-6829-4657-bb39-123456789',
#  'url': 'https://team.carto.com/u/johnsmith/kuviz/02251e11-6829-4657-bb39-123456789',
#  'name': 'sustainable_palm_oil_production_mills_private_map',
#  'privacy': 'password'}
