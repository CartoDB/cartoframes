# %% [markdown]
# # Download a Dataset from CARTO as a CartoDataFrame
#
# This example illustrates how to download a Dataset from CARTO and convert it to a DataFrame
#
# > Note: CARTO Account credentials are needed to reproduce this example. https://carto.com/signup

# %%
from cartoframes.auth import set_default_credentials

set_default_credentials('cartoframes')

# %%
from cartoframes import CartoDataFrame

cdf = CartoDataFrame.from_carto('global_power_plants')
cdf.head()
# Out:
#       fuel4 country_abbrev      country                           name  \
# 8465                   DEU      Germany   Nordendorf Solar Power Plant
# 8410                   DEU      Germany  Miegersbach Solar Power Plant
# 11314                  NAM      Namibia                         Anixas
# 25385                  VEN    Venezuela                       Masparro
# 13042                  KOR  South Korea                        Gochang
#
#         gppd_idnr  capacity_mw  latitude  longitude fuel_type fuel2  ...  \
# 8465   WRI1030340          7.4   48.5882    10.8441     Solar        ...
# 8410   WRI1030364          5.2   48.3232    11.2014     Solar        ...
# 11314  WRI1023132         24.3  -22.9575    14.5053       Oil        ...
# 25385  WRI1018659         25.0    8.8363   -70.0989     Hydro        ...
# 13042  WRI1029915         15.0   34.4091   126.5112     Solar        ...
#
#                                source  \
# 8465                       Sinosol AG
# ...
