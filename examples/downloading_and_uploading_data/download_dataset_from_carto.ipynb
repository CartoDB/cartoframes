# %% [markdown]
# # Download a Dataset from CARTO
#
# This example illustrates how to download a Dataset from CARTO and convert it to a DataFrame
#
# > Note: CARTO Account credentials are needed to reproduce this example. https://carto.com/signup

# %%
from cartoframes.auth import set_default_credentials

set_default_credentials('cartoframes')

# %%
from cartoframes.data import Dataset

ds = Dataset('global_power_plants')
df = ds.download()
df.head()
# Out:
#                                                      the_geom fuel4  \
# cartodb_id
# 8465        0101000020E6100000711B0DE02DB02540ECC039234A4B...   NaN
# 8410        0101000020E61000002CD49AE61D6726409A081B9E5E29...   NaN
# 11314       0101000020E61000006D567DAEB6022D4085EB51B81EF5...   NaN
# 25385       0101000020E6100000C364AA60548651C0234A7B832FAC...   NaN
# 13042       0101000020E6100000C66D3480B7A05F40956588635D34...   NaN
#
#            country_abbrev      country                           name  \
# cartodb_id
# 8465                  DEU      Germany   Nordendorf Solar Power Plant
# 8410                  DEU      Germany  Miegersbach Solar Power Plant
# 11314                 NAM      Namibia                         Anixas
# 25385                 VEN    Venezuela                       Masparro
# 13042                 KOR  South Korea                        Gochang
#
#              gppd_idnr  capacity_mw  latitude  longitude fuel_type  ... owner  \
# cartodb_id                                                          ...
# 8465        WRI1030340          7.4   48.5882    10.8441     Solar  ...   NaN
# 8410        WRI1030364          5.2   48.3232    11.2014     Solar  ...   NaN
# 11314       WRI1023132         24.3  -22.9575    14.5053       Oil  ...   NaN
# 25385       WRI1018659         25.0    8.8363   -70.0989     Hydro  ...   NaN
# 13042       WRI1029915         15.0   34.4091   126.5112     Solar  ...   NaN
#
#                                     source  \
# cartodb_id
# 8465                            Sinosol AG
# 8410                      Phoenix Solar AG
# 11314       African Development Bank Group
# 25385         Venezuela Electricity Sector
# 13042                                  CDM
#
#                                                           url  \
# cartodb_id
# 8465                                    http://www.sinosol.de
# 8410                        http://www.phoenixsolar-group.com
# 11314                http://powerafrica.opendataforafrica.org
# 25385       http://www.mppee.gob.ve/download/anuario_estad...
# 13042       https://cdm.unfccc.int/Projects/DB/KEMCO125427...
#
#            geolocation_source year_of_capacity_data generation_gwh_2013  \
# cartodb_id
# 8465           Industry About                   NaN                 NaN
# 8410           Industry About                   NaN                 NaN
# 11314            Power Africa                   NaN                 NaN
# 25385                   GEODB                   NaN               165.0
# 13042                     WRI                   NaN                 NaN
#
#            generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# cartodb_id
# 8465                       NaN                  NaN                  NaN
# 8410                       NaN                  NaN                  NaN
# 11314                      NaN                  NaN                  NaN
# 25385                      NaN                  NaN                  NaN
# 13042                      NaN                  NaN                  NaN
#
#            estimated_generation_gwh
# cartodb_id
# 8465                      68.537617
# 8410                      48.161569
# 11314                      5.273790
# 25385                    123.392392
# 13042                    405.443975
#
# [5 rows x 23 columns]
