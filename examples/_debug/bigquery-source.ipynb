# %%
from cartoframes.viz import Map, Layer, BigQuerySource

query = '''
SELECT d.total_pop, g.geoid, g.geom
FROM `carto-do-public-data.usa_acs.demographics_sociodemographics_usa_blockgroup_2015_5yrs_20132017` as d
INNER JOIN `carto-do-public-data.usa_carto.geography_usa_blockgroup_2018` as g ON d.geoid=g.geoid
WHERE ST_DWITHIN(g.geom,ST_GEOGPOINT(-73.95209,40.736333),{R})
'''

project = 'cartodb-gcp-backend-data-team'

token = 'ya29.IrABwAcC0Ukgxddb0SULBcG0Y8DDioTMPf7bXVftSHg_gF0vInPB9D8xn_4xz5inLKOLFX97GOjX3lSH40BA_FyED27KUUlgOOoR3HRIp1M7-PifAAAEZd90neVQWhvqki-YIqFyOpfbVkHN9QJ4NToOi7C1q5Au9t2_VlaDj4UqMSAEWlzWORiG_sv3EvLLiQ9EtsT6ZFqZwATVA53HpbpIGlrxZMZP_EOvKTHghtWbZps'

# %% [markdown]
# ### Small dataset

# %%
source = BigQuerySource(query=query.format(R=10000), project=project, token=token)
# Out:
# Estimating size. This may take a few seconds
# DEBUG: small dataset (527.03 KB)
# ...
# DEBUG: time elapsed 2.98s

# %%
Layer(source)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://cdn.jsdelivr.net/gh/cartodb/carto-vl@bq-poc-0.1/dist/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
# ...

# %% [markdown]
# ### Big dataset

# %%
source = BigQuerySource(query=query.format(R=100000), project=project, token=token)
# Out:
# Estimating size. This may take a few seconds
# DEBUG: big dataset (13.10 MB)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-ac0a889373f4> in <module>
# ----> 1 source = BigQuerySource(query=query.format(R=100000), project=project, token=token)
#
# ~/code/carto/cartoframes/cartoframes/viz/sources/bigquery_source.py in __new__(cls, query, table, tileset, project, token, index_col, geom_col)
#      19             return _gbq_tileset_source(tileset, project, token, index_col)
#      20         else:
# ---> 21             return _geo_data_frame_source(query, project, token, geom_col)
#      22
#      23
#
# ~/code/carto/cartoframes/cartoframes/viz/sources/bigquery_source.py in _geo_data_frame_source(query, project, token, geom_col)
#      78         >>> create_tileset(query, 'tileset_table')
#      79         >>> source = BigQuerySource(tileset='tileset_table')
# ...
