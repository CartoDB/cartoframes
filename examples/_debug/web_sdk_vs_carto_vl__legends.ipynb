# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from cartoframes.auth import Credentials, set_default_credentials
from cartoframes.viz import (
    color_bins_style, color_category_style, color_continuous_style,
    size_bins_style, size_category_style, size_continuous_style,
    basic_legend,
    color_bins_legend, color_category_legend, color_continuous_legend,
    size_bins_legend, size_category_legend, size_continuous_legend,
    Layer, Map
)

# %% [markdown]
# ### Basic

# %%
set_default_credentials('cartoframes')

tree_basic_legend = basic_legend(title='Tree Map', description='San Francisco, CA',
                                 footer='Source: City of SF')

# %%
Map(Layer('trees_sf', legends=tree_basic_legend))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#
#   <!-- Include Web-SDK -->
#   <script src=&quot;https://unpkg.com/deck.gl@8.2.0/dist.min.js&quot;></script>
#   <script src=&quot;https://web-sdk-git-feature-ch95759legends-add-custom-options.carto-frontend.vercel.app/dist/umd/index.min.js&quot;></script>
#
#   <!-- Include Mapbox -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.js&quot;></script>
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.4.0/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.4.0/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.4.0/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- d3 -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3-format/1.3.0/d3-format.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Tree Map&quot;
#                 description=&quot;San Francisco, CA&quot;>
#                 <as-legend-color-category-point id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-category-point>
#
#                   <span slot=&quot;footer&quot;>Source: City of SF</span>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   const GLOBAL_FILTER = 'global';
# const LOCAL_FILTER = 'viewport';
# const LOCAL_MODE = 'fast';
#
# // Removing the 'Style' suffix from the suffix name
# function cleanStyleName(name) {
#   return name.replace('Style', '');
# }
#
# // Decoding encoding GeoJSON
# function decodeJSONData(data, encodeData) {
#   try {
#     if (encodeData) {
#       const decodedJSON = pako.inflate(atob(data), {to: 'string'});
#       return JSON.parse(decodedJSON);
#
#     } else {
#       return JSON.parse(data);
#     }
#
#   } catch(error) {
#     throw new Error(`
#       Error: &quot;${error}&quot;. CARTOframes is not able to parse your local data because it is too large.
#       Please, disable the data compresion with encode_data=False in your Layer class.
#     `);
#   }
# }
#
# async function initialize() {
#   const basemap = 'Positron';
#   const bounds = [[-122.5085209, 37.70792829], [-122.3724441, 37.80902219]];
#   const camera = null;
#   const layersDef = [{&quot;credentials&quot;: {&quot;api_key&quot;: &quot;default_public&quot;, &quot;base_url&quot;: &quot;https://cartoframes.carto.com&quot;, &quot;username&quot;: &quot;cartoframes&quot;}, &quot;data&quot;: &quot;SELECT * FROM \&quot;cartoframes\&quot;.\&quot;trees_sf\&quot;&quot;, &quot;encode_data&quot;: true, &quot;has_legend_list&quot;: true, &quot;interactivity&quot;: {&quot;click&quot;: null, &quot;hover&quot;: null}, &quot;legends&quot;: [{&quot;ascending&quot;: false, &quot;description&quot;: &quot;San Francisco, CA&quot;, &quot;dynamic&quot;: true, &quot;footer&quot;: &quot;Source: City of SF&quot;, &quot;format&quot;: null, &quot;pr

# %% [markdown]
# ### Color category

# %%
set_default_credentials('cartoframes')

species_color_category_style = color_category_style('common_species')
species_color_category_legend = color_category_legend(title='Trees in San Francisco',
                                                      description='Top 3 species',
                                                      footer='Data: City of SF')

# %%
Map(Layer('trees_sf', species_color_category_style, legends=species_color_category_legend))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#
#   <!-- Include Web-SDK -->
#   <script src=&quot;https://unpkg.com/deck.gl@8.2.0/dist.min.js&quot;></script>
#   <script src=&quot;https://web-sdk-git-feature-ch95759legends-add-custom-options.carto-frontend.vercel.app/dist/umd/index.min.js&quot;></script>
#
#   <!-- Include Mapbox -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.js&quot;></script>
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.4.0/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.4.0/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.4.0/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- d3 -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3-format/1.3.0/d3-format.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Trees in San Francisco&quot;
#                 description=&quot;Top 3 species&quot;>
#                 <as-legend-color-category id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-category>
#
#                   <span slot=&quot;footer&quot;>Data: City of SF</span>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   const GLOBAL_FILTER = 'global';
# const LOCAL_FILTER = 'viewport';
# const LOCAL_MODE = 'fast';
#
# // Removing the 'Style' suffix from the suffix name
# function cleanStyleName(name) {
#   return name.replace('Style', '');
# }
#
# // Decoding encoding GeoJSON
# function decodeJSONData(data, encodeData) {
#   try {
#     if (encodeData) {
#       const decodedJSON = pako.inflate(atob(data), {to: 'string'});
#       return JSON.parse(decodedJSON);
#
#     } else {
#       return JSON.parse(data);
#     }
#
#   } catch(error) {
#     throw new Error(`
#       Error: &quot;${error}&quot;. CARTOframes is not able to parse your local data because it is too large.
#       Please, disable the data compresion with encode_data=False in your Layer class.
#     `);
#   }
# }
#
# async function initialize() {
#   const basemap = 'Positron';
#   const bounds = [[-122.5085209, 37.70792829], [-122.3724441, 37.80902219]];
#   const camera = null;
#   const layersDef = [{&quot;credentials&quot;: {&quot;api_key&quot;: &quot;default_public&quot;, &quot;base_url&quot;: &quot;https://cartoframes.carto.com&quot;, &quot;username&quot;: &quot;cartoframes&quot;}, &quot;data&quot;: &quot;SELECT * FROM \&quot;cartoframes\&quot;.\&quot;trees_sf\&quot;&quot;, &quot;encode_data&quot;: true, &quot;has_legend_list&quot;: true, &quot;interactivity&quot;: {&quot;click&quot;: null, &quot;hover&quot;: [{&quot;attr&quot;: &quot;common_species&quot;, &quot;format&quot;: null, &quot;title&quot;: &quot;common_species&quot;}]}, &quot;legends&quot;: [{&quot;ascending&quot;: true, &quot;description&quot;: &quot;Top 3 species&quot;, &quot

# %% [markdown]
# ### Color bins

# %%
set_default_credentials('cartoframes')

masters_color_bins_style = color_bins_style('masters_percent')
masters_color_bins_legend = color_bins_legend(title="Percent Master's Degree",
                                              description='by block group',
                                              footer='Data: US Census',
                                              format='.0%')

# %%
Map(Layer('demographics_sf', masters_color_bins_style, legends=masters_color_bins_legend))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#
#   <!-- Include Web-SDK -->
#   <script src=&quot;https://unpkg.com/deck.gl@8.2.0/dist.min.js&quot;></script>
#   <script src=&quot;https://web-sdk-git-feature-ch95759legends-add-custom-options.carto-frontend.vercel.app/dist/umd/index.min.js&quot;></script>
#
#   <!-- Include Mapbox -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.js&quot;></script>
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.4.0/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.4.0/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.4.0/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- d3 -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3-format/1.3.0/d3-format.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Percent Master's Degree&quot;
#                 description=&quot;by block group&quot;>
#                 <as-legend-color-bins id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-bins>
#
#                   <span slot=&quot;footer&quot;>Data: US Census</span>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   const GLOBAL_FILTER = 'global';
# const LOCAL_FILTER = 'viewport';
# const LOCAL_MODE = 'fast';
#
# // Removing the 'Style' suffix from the suffix name
# function cleanStyleName(name) {
#   return name.replace('Style', '');
# }
#
# // Decoding encoding GeoJSON
# function decodeJSONData(data, encodeData) {
#   try {
#     if (encodeData) {
#       const decodedJSON = pako.inflate(atob(data), {to: 'string'});
#       return JSON.parse(decodedJSON);
#
#     } else {
#       return JSON.parse(data);
#     }
#
#   } catch(error) {
#     throw new Error(`
#       Error: &quot;${error}&quot;. CARTOframes is not able to parse your local data because it is too large.
#       Please, disable the data compresion with encode_data=False in your Layer class.
#     `);
#   }
# }
#
# async function initialize() {
#   const basemap = 'Positron';
#   const bounds = [[-122.53009999999998, 37.708131], [-122.35696699999995, 37.833365]];
#   const camera = null;
#   const layersDef = [{&quot;credentials&quot;: {&quot;api_key&quot;: &quot;default_public&quot;, &quot;base_url&quot;: &quot;https://cartoframes.carto.com&quot;, &quot;username&quot;: &quot;cartoframes&quot;}, &quot;data&quot;: &quot;SELECT * FROM \&quot;cartoframes\&quot;.\&quot;demographics_sf\&quot;&quot;, &quot;encode_data&quot;: true, &quot;has_legend_list&quot;: true, &quot;interactivity&quot;: {&quot;click&quot;: null, &quot;hover&quot;: [{&quot;attr&quot;: &quot;masters_percent&quot;, &quot;format&quot;: null, &quot;title&quot;: &quot;masters_percent&quot;}]}, &quot;legends&quot;: [{&quot;ascending&quot;: false, &quot;description&quot;: &quot;by block grou

# %% [markdown]
# ### Color continuous

# %%
set_default_credentials('cartoframes')

masters_color_continuous_style = color_continuous_style('masters_percent')
masters_color_continuous_legend = color_continuous_legend(title="Percent Master's Degree",
                                                          description='by block group',
                                                          footer='Data: US Census',
                                                          format='.0%')

# %%
Map(Layer('demographics_sf', masters_color_continuous_style, legends=masters_color_continuous_legend))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#
#   <!-- Include Web-SDK -->
#   <script src=&quot;https://unpkg.com/deck.gl@8.2.0/dist.min.js&quot;></script>
#   <script src=&quot;https://web-sdk-git-feature-ch95759legends-add-custom-options.carto-frontend.vercel.app/dist/umd/index.min.js&quot;></script>
#
#   <!-- Include Mapbox -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.js&quot;></script>
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.4.0/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.4.0/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.4.0/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- d3 -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3-format/1.3.0/d3-format.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Percent Master's Degree&quot;
#                 description=&quot;by block group&quot;>
#                 <as-legend-color-continuous id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-continuous>
#
#                   <span slot=&quot;footer&quot;>Data: US Census</span>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   const GLOBAL_FILTER = 'global';
# const LOCAL_FILTER = 'viewport';
# const LOCAL_MODE = 'fast';
#
# // Removing the 'Style' suffix from the suffix name
# function cleanStyleName(name) {
#   return name.replace('Style', '');
# }
#
# // Decoding encoding GeoJSON
# function decodeJSONData(data, encodeData) {
#   try {
#     if (encodeData) {
#       const decodedJSON = pako.inflate(atob(data), {to: 'string'});
#       return JSON.parse(decodedJSON);
#
#     } else {
#       return JSON.parse(data);
#     }
#
#   } catch(error) {
#     throw new Error(`
#       Error: &quot;${error}&quot;. CARTOframes is not able to parse your local data because it is too large.
#       Please, disable the data compresion with encode_data=False in your Layer class.
#     `);
#   }
# }
#
# async function initialize() {
#   const basemap = 'Positron';
#   const bounds = [[-122.53009999999998, 37.708131], [-122.35696699999995, 37.833365]];
#   const camera = null;
#   const layersDef = [{&quot;credentials&quot;: {&quot;api_key&quot;: &quot;default_public&quot;, &quot;base_url&quot;: &quot;https://cartoframes.carto.com&quot;, &quot;username&quot;: &quot;cartoframes&quot;}, &quot;data&quot;: &quot;SELECT * FROM \&quot;cartoframes\&quot;.\&quot;demographics_sf\&quot;&quot;, &quot;encode_data&quot;: true, &quot;has_legend_list&quot;: true, &quot;interactivity&quot;: {&quot;click&quot;: null, &quot;hover&quot;: [{&quot;attr&quot;: &quot;masters_percent&quot;, &quot;format&quot;: null, &quot;title&quot;: &quot;masters_percent&quot;}]}, &quot;legends&quot;: [{&quot;ascending&quot;: false, &quot;description&quot;: &quot;b

# %% [markdown]
# ### Size category

# %%
set_default_credentials('cartoframes')

feature_size_category_style = size_category_style(
    'featurecla',
    cat=['Populated place', 'Admin-1 capital', 'Admin-0 capital'],
    size_range=[3, 15]
)
feature_size_category_legend = size_category_legend(title='Spanish Cities',
                                                    footer='Source: Natural Earth')

# %%
Map(Layer('spain_populated_places', feature_size_category_style, legends=feature_size_category_legend))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#
#   <!-- Include Web-SDK -->
#   <script src=&quot;https://unpkg.com/deck.gl@8.2.0/dist.min.js&quot;></script>
#   <script src=&quot;https://web-sdk-git-feature-ch95759legends-add-custom-options.carto-frontend.vercel.app/dist/umd/index.min.js&quot;></script>
#
#   <!-- Include Mapbox -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.js&quot;></script>
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.4.0/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.4.0/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.4.0/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- d3 -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3-format/1.3.0/d3-format.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Spanish Cities&quot;
#                 description=&quot;&quot;>
#                 <as-legend-size-category id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-size-category>
#
#                   <span slot=&quot;footer&quot;>Source: Natural Earth</span>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   const GLOBAL_FILTER = 'global';
# const LOCAL_FILTER = 'viewport';
# const LOCAL_MODE = 'fast';
#
# // Removing the 'Style' suffix from the suffix name
# function cleanStyleName(name) {
#   return name.replace('Style', '');
# }
#
# // Decoding encoding GeoJSON
# function decodeJSONData(data, encodeData) {
#   try {
#     if (encodeData) {
#       const decodedJSON = pako.inflate(atob(data), {to: 'string'});
#       return JSON.parse(decodedJSON);
#
#     } else {
#       return JSON.parse(data);
#     }
#
#   } catch(error) {
#     throw new Error(`
#       Error: &quot;${error}&quot;. CARTOframes is not able to parse your local data because it is too large.
#       Please, disable the data compresion with encode_data=False in your Layer class.
#     `);
#   }
# }
#
# async function initialize() {
#   const basemap = 'Positron';
#   const bounds = [[-16.2500006525, 28.0999760122], [2.65424597028, 43.530016092]];
#   const camera = null;
#   const layersDef = [{&quot;credentials&quot;: {&quot;api_key&quot;: &quot;default_public&quot;, &quot;base_url&quot;: &quot;https://cartoframes.carto.com&quot;, &quot;username&quot;: &quot;cartoframes&quot;}, &quot;data&quot;: &quot;SELECT * FROM \&quot;cartoframes\&quot;.\&quot;spain_populated_places\&quot;&quot;, &quot;encode_data&quot;: true, &quot;has_legend_list&quot;: true, &quot;interactivity&quot;: {&quot;click&quot;: null, &quot;hover&quot;: [{&quot;attr&quot;: &quot;featurecla&quot;, &quot;format&quot;: null, &quot;title&quot;: &quot;featurecla&quot;}]}, &quot;legends&quot;: [{&quot;ascending&quot;: true, &quot;description&quot;: &quot;&quot;, &quot;dynamic&quot;: tru

# %% [markdown]
# ### Size bins

# %%
set_default_credentials('cartoframes')

speed_size_bins_style = size_bins_style('auto_speed')
speed_size_bins_legend = size_bins_legend(title='Road Congestion', description='Travel Speeds',
                                          footer='Data: City of SF', format='d')

# %%
Map(Layer('sf_road_travel', speed_size_bins_style, legends=speed_size_bins_legend))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#
#   <!-- Include Web-SDK -->
#   <script src=&quot;https://unpkg.com/deck.gl@8.2.0/dist.min.js&quot;></script>
#   <script src=&quot;https://web-sdk-git-feature-ch95759legends-add-custom-options.carto-frontend.vercel.app/dist/umd/index.min.js&quot;></script>
#
#   <!-- Include Mapbox -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.js&quot;></script>
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.4.0/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.4.0/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.4.0/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- d3 -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3-format/1.3.0/d3-format.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Road Congestion&quot;
#                 description=&quot;Travel Speeds&quot;>
#                 <as-legend-size-bins id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-size-bins>
#
#                   <span slot=&quot;footer&quot;>Data: City of SF</span>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   const GLOBAL_FILTER = 'global';
# const LOCAL_FILTER = 'viewport';
# const LOCAL_MODE = 'fast';
#
# // Removing the 'Style' suffix from the suffix name
# function cleanStyleName(name) {
#   return name.replace('Style', '');
# }
#
# // Decoding encoding GeoJSON
# function decodeJSONData(data, encodeData) {
#   try {
#     if (encodeData) {
#       const decodedJSON = pako.inflate(atob(data), {to: 'string'});
#       return JSON.parse(decodedJSON);
#
#     } else {
#       return JSON.parse(data);
#     }
#
#   } catch(error) {
#     throw new Error(`
#       Error: &quot;${error}&quot;. CARTOframes is not able to parse your local data because it is too large.
#       Please, disable the data compresion with encode_data=False in your Layer class.
#     `);
#   }
# }
#
# async function initialize() {
#   const basemap = 'Positron';
#   const bounds = [[-122.51360619457783, 37.7081003674475], [-122.35885654687338, 37.814208369553974]];
#   const camera = null;
#   const layersDef = [{&quot;credentials&quot;: {&quot;api_key&quot;: &quot;default_public&quot;, &quot;base_url&quot;: &quot;https://cartoframes.carto.com&quot;, &quot;username&quot;: &quot;cartoframes&quot;}, &quot;data&quot;: &quot;SELECT * FROM \&quot;cartoframes\&quot;.\&quot;sf_road_travel\&quot;&quot;, &quot;encode_data&quot;: true, &quot;has_legend_list&quot;: true, &quot;interactivity&quot;: {&quot;click&quot;: null, &quot;hover&quot;: [{&quot;attr&quot;: &quot;auto_speed&quot;, &quot;format&quot;: null, &quot;title&quot;: &quot;auto_speed&quot;}]}, &quot;legends&quot;: [{&quot;ascending&quot;: false, &quot;description&quot;: &quot;Travel Speeds&quot

# %% [markdown]
# ### Size continuous

# %%
set_default_credentials('cartoframes')

value_size_continuous_style = size_continuous_style('value', size_range=[8, 40])
value_size_continuous_legend = size_continuous_legend(title='Crime Counts',
                                                      description='by neighborhood',
                                                      footer='Source: City of SF',
                                                      format='.0s')

# %%
Map(Layer('sf_nbhd_crime', value_size_continuous_style, legends=value_size_continuous_legend))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#
#   <!-- Include Web-SDK -->
#   <script src=&quot;https://unpkg.com/deck.gl@8.2.0/dist.min.js&quot;></script>
#   <script src=&quot;https://web-sdk-git-feature-ch95759legends-add-custom-options.carto-frontend.vercel.app/dist/umd/index.min.js&quot;></script>
#
#   <!-- Include Mapbox -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.js&quot;></script>
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.10.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.4.0/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.4.0/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.4.0/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.4.0/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- d3 -->
#   <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3-format/1.3.0/d3-format.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Crime Counts&quot;
#                 description=&quot;by neighborhood&quot;>
#                 <as-legend-size-continuous id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-size-continuous>
#
#                   <span slot=&quot;footer&quot;>Source: City of SF</span>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   const GLOBAL_FILTER = 'global';
# const LOCAL_FILTER = 'viewport';
# const LOCAL_MODE = 'fast';
#
# // Removing the 'Style' suffix from the suffix name
# function cleanStyleName(name) {
#   return name.replace('Style', '');
# }
#
# // Decoding encoding GeoJSON
# function decodeJSONData(data, encodeData) {
#   try {
#     if (encodeData) {
#       const decodedJSON = pako.inflate(atob(data), {to: 'string'});
#       return JSON.parse(decodedJSON);
#
#     } else {
#       return JSON.parse(data);
#     }
#
#   } catch(error) {
#     throw new Error(`
#       Error: &quot;${error}&quot;. CARTOframes is not able to parse your local data because it is too large.
#       Please, disable the data compresion with encode_data=False in your Layer class.
#     `);
#   }
# }
#
# async function initialize() {
#   const basemap = 'Positron';
#   const bounds = [[-122.50107593230128, 37.71083994751319], [-122.36954500627857, 37.82065972120599]];
#   const camera = null;
#   const layersDef = [{&quot;credentials&quot;: {&quot;api_key&quot;: &quot;default_public&quot;, &quot;base_url&quot;: &quot;https://cartoframes.carto.com&quot;, &quot;username&quot;: &quot;cartoframes&quot;}, &quot;data&quot;: &quot;SELECT * FROM \&quot;cartoframes\&quot;.\&quot;sf_nbhd_crime\&quot;&quot;, &quot;encode_data&quot;: true, &quot;has_legend_list&quot;: true, &quot;interactivity&quot;: {&quot;click&quot;: null, &quot;hover&quot;: [{&quot;attr&quot;: &quot;value&quot;, &quot;format&quot;: null, &quot;title&quot;: &quot;value&quot;}]}, &quot;legends&quot;: [{&quot;ascending&quot;: false, &quot;description&quot;: &quot;by neighborhood&
