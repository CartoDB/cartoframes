# %%
from cartoframes.auth import Credentials
from cartoframes.data.observatory import Catalog, Dataset, Geography

# %%
Catalog().datasets, Catalog().geographies
# Out:
# ([<Dataset('od_acsquantile_ae4e7c82')>,
#   <Dataset('od_acs_9510981d')>,
#   <Dataset('od_acs_6d43ed82')>,
#   <Dataset('od_acs_d9e8a21b')>,
#   <Dataset('od_acsquantile_73ef5901')>,
#   <Dataset('od_acsquantile_6f90c45a')>,
#   <Dataset('od_acsquantile_aef9b650')>,
#   <Dataset('pb_pointsofint_1b371a9e')>,
#   <Dataset('pb_pointsofint_ec7d2c05')>,
#   <Dataset('od_acsquantile_6459801d')>,
#   <Dataset('ags_climateandw_cffac915')>,
#   <Dataset('pb_pointsofint_2afa556a')>,
#   <Dataset('od_acs_1f614ee8')>,
#   <Dataset('od_acs_c2868f47')>,
#   <Dataset('od_acsquantile_de9342df')>,
#   <Dataset('od_acs_1cfa643a')>,
#   <Dataset('od_acs_c4a00c26')>,
#   <Dataset('od_acs_c1c86582')>,
#   <Dataset('bbva_origindistr_a166fd91')>,
#   <Dataset('od_acs_181619a3')>,
#   <Dataset('pb_pointsofint_3e227a5c')>,
#   <Dataset('pb_pointsofint_93d12908')>,
#   <Dataset('pb_pointsofint_17d1d891')>,
#   <Dataset('pb_pointsofint_995cba18')>,
#   <Dataset('od_acs_6c9090b5')>,
#   <Dataset('pb_pointsofint_3b70f55')>,
#   <Dataset('pb_pointsofint_d3b24fdb')>,
#   <Dataset('pb_pointsofint_5ef4705d')>,
#   <Dataset('u360_touristicin_dd23f37c')>,
#   <Dataset('u360_workingpopu_7c6835ed')>,
#   <Dataset('u360_demographic_fbf2e195')>,
#   <Dataset('od_acsquantile_ee1f1fd0')>,
#   <Dataset('od_acs_a9825694')>,
#   <Dataset('od_acsquantile_14337492')>,
#   <Dataset('od_tiger_5e55275d')>,
#   <Dataset('od_acsquantile_1f5769bc')>,
#   <Dataset('od_acsquantile_457b5d3a')>,
#   <Dataset('od_acsquantile_8bf20ab8')>,
#   <Dataset('u360_cadaster_23e61803')>,
#   <Dataset('od_acsquantile_7bc07dac')>,
#   <Dataset('od_acsquantile_74829d18')>,
#   <Dataset('ags_sociodemogr_e128078d')>,
#   <Dataset('od_acs_59534db1')>,
#   <Dataset('od_acs_57d06d64')>,
#   <Dataset('od_acs_13345497')>,
#   <Dataset('od_acsquantile_8899ff3')>,
#   <Dataset('pb_pointsofint_f8c10b50')>,
#   <Dataset('bbva_basicstats_f9f50dc7')>,
#   <Dataset('bbva_categorydis_c55e1f44')>,
#   <Dataset('ags_crimerisk_9ec89442')>,
#   <Dataset('pb_pointsofint_515b22a6')>,
#   <Dataset('od_zillow_5b27620f')>,
#   <Dataset('od_bls_c2f65959')>,
#   <Dataset('pb_pointsofint_ab305738')>,
#   <Dataset('od_acs_5b67fbbf')>,
#   <Dataset('pb_pointsofint_fe0beb6a')>,
#   <Dataset('od_acsquantile_e8576a4c')>,
#   <Dataset('od_acs_52710085')>,
#   <Dataset('pb_pointsofint_1aa07bda')>,
#   <Dataset('pb_pointsofint_a7132c71')>,
#   <Dataset('pb_pointsofint_53653c12')>,
#   <Dataset('pb_pointsofint_46a64823')>,
#   <Dataset('od_acsquantile_928a2a23')>,
#   <Dataset('pb_pointsofint_db54272c')>,
#   <Dataset('bbva_categorydis_38d0bf9b')>,
#   <Dataset('od_acs_a665f9e1')>,
#   <Dataset('od_acs_b581bfd1')>,
#   <Dataset('od_acsquantile_60abf26')>,
#   <Dataset('mc_mrli_3e9a0d24')>,
#   <Dataset('mc_mrli_12ec28f')>,
#   <Dataset('pb_pointsofint_a0945d9e')>,
#   <Dataset('pb_pointsofint_b5ecd440')>,
#   <Dataset('pb_pointsofint_1d4bdf72')>,
#   <Dataset('pb_pointsofint_f23c2b51')>,
#   <Dataset('pb_pointsofint_fe1f5018')>,
#   <Dataset('pb_pointsofint_cd6164d')>,
#   <Dataset('pb_pointsofint_b67fb425')>,
#   <Dataset('pb_pointsofint_774b5488')>,
#   <Dataset('od_acsquantile_289a3e56')>,
#   <Dataset('od_acs_7b2649a9')>,
#   <Dataset('u360_cadastersoc_570840bc')>,
#   <Dataset('od_acs_478c37b8')>,
#   <Dataset('pb_pointsofint_9056f21f')>,
#   <Dataset('bbva_consumption_56029905')>,
#   <Dataset('bbva_consumption_24aaf3e')>,
#   <Dataset('pb_pointsofint_ddb566ec')>,
#   <Dataset('pb_pointsofint_1d1e3a21')>,
#   <Dataset('pb_pointsofint_c7325d87')>,
#   <Dataset('od_acs_f98ddfce')>,
#   <Dataset('od_acs_8b00f653')>,
#   <Dataset('od_acsquantile_7a726a1e')>,
#   <Dataset('od_acs_6e4b69f6')>,
#   <Dataset('od_acsquantile_115a0d63')>,
#   <Dataset('bbva_origindistr_7955301c')>,
#   <Dataset('od_acs_c31e5f28')>,
#   <Dataset('od_acsquantile_e1f5bdf4')>,
#   <Dataset('pb_pointsofint_71d27b7d')>,
#   <Dataset('pb_pointsofint_e4f294a8')>,
#   <Dataset('pb_pointsofint_c57adabe')>,
#   <Dataset('pb_pointsofint_45ae86f6')>,
#   <Dataset('mc_mrli_3c4ccbfc')>,
#   <Dataset('od_acs_d52a0635')>,
#   <Dataset('od_acsquantile_1fc24f44')>,
#   <Dataset('od_acs_1deaa51')>,
#   <Dataset('od_acs_e0f5ff55')>,
#   <Dataset('pb_pointsofint_16a656d1')>,
#   <Dataset('pb_pointsofint_89b5d2e6')>,
#   <Dataset('pb_pointsofint_ad787af9')>,
#   <Dataset('pb_pointsofint_ae2d8c5b')>,
#   <Dataset('pb_pointsofint_6fb62a6b')>,
#   <Dataset('pb_pointsofint_50ded20c')>,
#   <Dataset('pb_pointsofint_16302058')>,
#   <Dataset('pb_pointsofint_5c51c059')>,
#   <Dataset('pb_pointsofint_ddbb9154')>,
#   <Dataset('pb_pointsofint_96684653')>,
#   <Dataset('pb_pointsofint_357cd334')>,
#   <Dataset('pb_pointsofint_6b4a09c1')>,
#   <Dataset('pb_pointsofint_95b18ab2')>,
#   <Dataset('od_epa_de702825')>,
#   <Dataset('od_tiger_66b9092c')>,
#   <Dataset('bbva_origindistr_7b4bfe3d')>,
#   <Dataset('pb_pointsofint_c4695c9d')>,
#   <Dataset('pb_pointsofint_6a40eca9')>,
#   <Dataset('pb_pointsofint_5b18fa55')>,
#   <Dataset('pb_pointsofint_7a0d306f')>,
#   <Dataset('pb_pointsofint_e2f9f7')>,
#   <Dataset('pb_pointsofint_2dc5f6eb')>,
#   <Dataset('pb_pointsofint_4b320171')>,
#   <Dataset('pb_pointsofint_f75fb49b')>,
#   <Dataset('od_acs_db9898c5')>,
#   <Dataset('od_acs_670c8beb')>,
#   <Dataset('od_tiger_476ce2e9')>,
#   <Dataset('od_acsquantile_ed3f9e9e')>,
#   <Dataset('pb_pointsofint_b9777d67')>,
#   <Dataset('pb_pointsofint_305b17c2')>,
#   <Dataset('pb_pointsofint_8e7d0a90')>,
#   <Dataset('pb_pointsofint_b13d7c8c')>,
#   <Dataset('pb_pointsofint_14b6ec82')>,
#   <Dataset('pb_pointsofint_aa90f1d0')>,
#   <Dataset('pb_pointsofint_a690f647')>,
#   <Dataset('mc_mrli_35402a9d')>,
#   <Dataset('ags_consumerpro_e8344e2e')>,
#   <Dataset('od_acs_8c6d324a')>,
#   <Dataset('od_acsquantile_7d1fae07')>,
#   <Dataset('od_acs_6926adef')>,
#   <Dataset('od_acsquantile_1637c97a')>,
#   <Dataset('od_acs_9a9c93b8')>,
#   <Dataset('od_tiger_e10059f')>,
#   <Dataset('od_acs_4f56aa89')>,
#   <Dataset('od_tiger_fac69779')>,
#   <Dataset('od_tiger_384d0b09')>,
#   <Dataset('pb_pointsofint_937d4014')>,
#   <Dataset('pb_pointsofint_71262f0b')>,
#   <Dataset('od_acs_c5eb4b5e')>,
#   <Dataset('od_acsquantile_7985540b')>,
#   <Dataset('pb_pointsofint_13bb8db2')>,
#   <Dataset('ags_consumerspe_fe5d060a')>,
#   <Dataset('u360_pedestriant_391250b5')>,
#   <Dataset('pb_pointsofint_2f46938')>,
#   <Dataset('pb_pointsofint_b7b3c78a')>,
#   <Dataset('pb_pointsofint_47af82ca')>,
#   <Dataset('pb_pointsofint_7efccbfc')>,
#   <Dataset('pb_pointsofint_8d39425d')>,
#   <Dataset('pb_pointsofint_6ba4117d')>,
#   <Dataset('pb_pointsofint_6229919c')>,
#   <Dataset('pb_pointsofint_65fd2fbc')>,
#   <Dataset('od_zillow_39a655b3')>,
#   <Dataset('od_zillow_a0af0409')>,
#   <Dataset('od_zillow_217f0ec5')>,
#   <Dataset('od_zillow_b8765f7f')>,
#   <Dataset('od_zillow_cf716fe9')>,
#   <Dataset('od_zillow_5115fa4a')>,
#   <Dataset('vdf_footfall_44b28739')>,
#   <Dataset('vdf_odmatrix_1c2e4fd2')>,
#   <Dataset('tt_trafficdens_c451dfb9')>,
#   <Dataset('od_acs_e1b123b7')>,
#   <Dataset('pb_pointsofint_f59b09e1')>,
#   <Dataset('pb_pointsofint_bd3e549a')>,
#   <Dataset('od_acs_2d438a42')>,
#   <Dataset('od_acs_c6bf32c9')>,
#   <Dataset('pb_pointsofint_ff5a1ce9')>,
#   <Dataset('od_acs_91ff81e3')>,
#   <Dataset('od_epa_307e4909')>,
#   <Dataset('od_acsquantile_38b19fb0')>,
#   <Dataset('ags_retailpoten_ddf56a1a')>,
#   <Dataset('ags_sociodemogr_e92b1637')>,
#   <Dataset('od_bls_c334336e')>,
#   <Dataset('od_bls_b29cadd6')>,
#   <Dataset('od_bls_2b95fc6c')>,
#   <Dataset('od_bls_5c92ccfa')>,
#   <Dataset('ags_businesscou_a8310a11')>,
#   <Dataset('pb_pointsofint_a4d8717e')>,
#   <Dataset('pb_pointsofint_9135c72d')>,
#   <Dataset('pb_pointsofint_d1fac8e2')>,
#   <Dataset('pb_pointsofint_669a1baf')>,
#   <Dataset('od_acs_dc3cfd0f')>,
#   <Dataset('od_acs_5c10acf4')>,
#   <Dataset('mc_mrli_359ae0b8')>,
#   <Dataset('pb_pointsofint_ca608212')>,
#   <Dataset('pb_pointsofint_af4d96e8')>,
#   <Dataset('pb_pointsofint_526fd97a')>,
#   <Dataset('pb_pointsofint_f56780b3')>,
#   <Dataset('pb_pointsofint_1148f764')>,
#   <Dataset('pb_pointsofint_f7f6d89a')>,
#   <Dataset('pb_pointsofint_214cce22')>,
#   <Dataset('pb_pointsofint_8a23b79e')>,
#   <Dataset('pb_pointsofint_793fe12f')>,
#   <Dataset('pb_pointsofint_f15830c3')>,
#   <Dataset('pb_pointsofint_8ee58ba1')>,
#   <Dataset('pb_pointsofint_a9f1ef5f')>,
#   <Dataset('pb_pointsofint_76810dbb')>,
#   <Dataset('pb_pointsofint_ee8d7952')>,
#   <Dataset('pb_pointsofint_a1892c05')>,
#   <Dataset('pb_pointsofint_74d834ed')>,
#   <Dataset('pb_pointsofint_73c7c433')>,
#   <Dataset('pb_pointsofint_7cb26659')>,
#   <Dataset('pb_pointsofint_306fffef')>,
#   <Dataset('pb_pointsofint_9f32ee1a')>,
#   <Dataset('pb_pointsofint_73e9af3')>,
#   <Dataset('od_acs_5ec6965e')>,
#   <Dataset('pb_pointsofint_6bc0191e')>,
#   <Dataset('pb_pointsofint_cc9e8a05')>,
#   <Dataset('pb_pointsofint_7f183628')>,
#   <Dataset('pb_pointsofint_69b281b2')>,
#   <Dataset('pb_pointsofint_95bc528b')>,
#   <Dataset('pb_pointsofint_30d442')>,
#   <Dataset('pb_pointsofint_688c8cf7')>,
#   <Dataset('pb_pointsofint_de4cf952')>,
#   <Dataset('pb_pointsofint_a6eeb2ee')>,
#   <Dataset('pb_pointsofint_ef7412e')>,
#   <Dataset('pb_pointsofint_268739d5')>,
#   <Dataset('pb_pointsofint_afb9c29e')>,
#   <Dataset('pb_pointsofint_f4db400d')>,
#   <Dataset('pb_pointsofint_1959e464')>,
#   <Dataset('pb_pointsofint_a5afff3e')>,
#   <Dataset('pb_pointsofint_4d6b92df')>,
#   <Dataset('pb_pointsofint_2a0e011c')>,
#   <Dataset('pb_pointsofint_4b4940c5')>,
#   <Dataset('pb_pointsofint_7d7d3a77')>,
#   <Dataset('pb_pointsofint_62a873e6')>,
#   <Dataset('pb_pointsofint_ec25116f')>,
#   <Dataset('pb_pointsofint_80e18d17')>,
#   <Dataset('pb_pointsofint_6f84e8da')>,
#   <Dataset('pb_pointsofint_e4e32ac7')>,
#   <Dataset('pb_pointsofint_850b2d83')>,
#   <Dataset('pb_pointsofint_9398aa0d')>,
#   <Dataset('pb_pointsofint_2275edc7')>,
#   <Dataset('pb_pointsofint_202cd491')>,
#   <Dataset('pb_pointsofint_3d1e5ca4')>,
#   <Dataset('mc_mrli_c044b645')>,
#   <Dataset('pb_pointsofint_9cde7b2')>,
#   <Dataset('pb_pointsofint_b6d5f7a5')>,
#   <Dataset('pb_pointsofint_f029941f')>,
#   <Dataset('pb_pointsofint_c9684cc7')>,
#   <Dataset('pb_pointsofint_bf0d9217')>,
#   <Dataset('pb_pointsofint_5b291765')>,
#   <Dataset('pb_pointsofint_57c9fff6')>,
#   <Dataset('pb_pointsofint_fcc4976')>,
#   <Dataset('pb_pointsofint_17aa9925')>,
#   <Dataset('pb_pointsofint_adf440ba')>,
#   <Dataset('pb_pointsofint_2fd54cb8')>,
#   <Dataset('pb_pointsofint_576596ea')>,
#   <Dataset('pb_pointsofint_9bd18467')>,
#   <Dataset('pb_pointsofint_f479dea9')>,
#   <Dataset('pb_pointsofint_aa4f045c')>,
#   <Dataset('pb_pointsofint_ae25517f')>,
#   <Dataset('pb_pointsofint_640d691a')>,
#   <Dataset('pb_pointsofint_f7a6ca0')>,
#   <Dataset('pb_pointsofint_881da92a')>,
#   <Dataset('pb_pointsofint_3c1a4e74')>,
#   <Dataset('pb_pointsofint_20b98d99')>,
#   <Dataset('pb_pointsofint_1c32a68a')>,
#   <Dataset('pb_pointsofint_a0e936b6')>,
#   <Dataset('pb_pointsofint_582a2b15')>,
#   <Dataset('pb_pointsofint_334fbf41')>,
#   <Dataset('pb_pointsofint_989d118e')>,
#   <Dataset('pb_pointsofint_39c22c51')>,
#   <Dataset('pb_pointsofint_99de77e3')>,
#   <Dataset('pb_pointsofint_3c82cf45')>,
#   <Dataset('pb_pointsofint_ae11b952')>,
#   <Dataset('pb_pointsofint_1dde867a')>,
#   <Dataset('bbva_destination_16460d9e')>,
#   <Dataset('pb_pointsofint_607b5a6f')>,
#   <Dataset('pb_pointsofint_f5c01b0a')>,
#   <Dataset('pb_pointsofint_d45219d6')>,
#   <Dataset('pb_pointsofint_2ffdc2c3')>,
#   <Dataset('pb_pointsofint_5e82e9d0')>,
#   <Dataset('pb_pointsofint_324675a8')>,
#   <Dataset('pb_pointsofint_24799b3a')>,
#   <Dataset('pb_pointsofint_9b618b2d')>,
#   <Dataset('od_acs_f2f40516')>,
#   <Dataset('od_acs_1209a7e9')>,
#   <Dataset('od_acs_5b8fdefd')>,
#   <Dataset('od_acs_f9681e48')>,
#   <Dataset('od_acsquantile_16d4b47e')>,
#   <Dataset('od_acs_8c8516b')>,
#   <Dataset('od_acsquantile_5c268ba0')>,
#   <Dataset('od_acsquantile_b4a64e3e')>,
#   <Dataset('od_acs_87fa66db')>,
#   <Dataset('od_acs_e9e3046f')>,
#   <Dataset('pb_pointsofint_95e9426')>,
#   <Dataset('pb_pointsofint_4bc8a2bf')>,
#   <Dataset('pb_pointsofint_3c1f4b69')>,
#   <Dataset('pb_pointsofint_7807c6f6')>,
#   <Dataset('pb_pointsofint_39bf4779')>,
#   <Dataset('bbva_categorydis_eff36433')>,
#   <Dataset('od_acs_d28e63ff')>,
#   <Dataset('od_acs_506e3e6a')>,
#   <Dataset('od_acsquantile_a2a5703a')>,
#   <Dataset('od_acs_b98db80e')>,
#   <Dataset('od_acs_9f4d1f13')>,
#   <Dataset('od_acsquantile_55a55662')>,
#   <Dataset('od_acs_4bb9b377')>,
#   <Dataset('od_acs_aa92e673')>,
#   <Dataset('od_acsquantile_d1fbc83f')>,
#   <Dataset('od_acs_1db77442')>,
#   <Dataset('bbva_basicstats_34678df7')>,
#   <Dataset('mc_mrli_58fa8579')>,
#   <Dataset('mc_mrli_60cab294')>,
#   <Dataset('od_acsquantile_9b9cd119')>,
#   <Dataset('mc_mrli_323ee6ba')>,
#   <Dataset('od_acsquantile_68fd0043')>,
#   <Dataset('od_acsquantile_42ee86d5')>,
#   <Dataset('od_acs_b3eac6e8')>,
#   <Dataset('od_acs_1a09274c')>,
#   <Dataset('od_acsquantile_e8c2691c')>,
#   <Dataset('od_acs_f3eaa128')>,
#   <Dataset('od_acsquantile_a47806f6')>,
#   <Dataset('od_acsquantile_a75887b8')>,
#   <Dataset('od_acsquantile_5530709a')>,
#   <Dataset('u360_commerciali_d635cbf5')>,
#   <Dataset('od_acsquantile_bdb0b504')>,
#   <Dataset('od_acsquantile_4c6da600')>,
#   <Dataset('od_acsquantile_82e4f182')>,
#   <Dataset('bbva_consumption_ace0ddab')>,
#   <Dataset('od_acs_de856602')>,
#   <Dataset('od_acsquantile_2ff7fa4f')>,
#   <Dataset('od_acs_7c4b8db0')>,
#   <Dataset('od_acs_a1083df8')>,
#   <Dataset('mc_mrli_51f61301')>,
#   <Dataset('od_acsquantile_a9947249')>,
#   <Dataset('od_acs_6bfd54ac')>,
#   <Dataset('od_acsquantile_63344404')>,
#   <Dataset('od_acs_9df157a1')>,
#   <Dataset('od_acsquantile_e69879ed')>,
#   <Dataset('od_acsquantile_7ee89012')>,
#   <Dataset('od_acsquantile_9efa084')>,
#   <Dataset('od_acsquantile_58f0cad9')>,
#   <Dataset('od_acs_b4cbd26')>,
#   <Dataset('od_acsquantile_385ad8e')>,
#   <Dataset('od_acs_fc07c6c5')>,
#   <Dataset('od_acsquantile_d755a88')>,
#   <Dataset('od_acs_194c5960')>,
#   <Dataset('od_acsquantile_665d3df5')>,
#   <Dataset('od_acs_eaf66737')>,
#   <Dataset('od_acsquantile_919f497b')>,
#   <Dataset('od_lodes_b4b9dfac')>,
#   <Dataset('od_acs_17667f64')>,
#   <Dataset('od_acsquantile_1ffa30d5')>,
#   <Dataset('od_acs_d60f0d6e')>,
#   <Dataset('bbva_origindistr_3640323d')>,
#   <Dataset('bbva_origindistr_50f2b805')>,
#   <Dataset('bbva_basicstats_5bff5ee7')>,
#   <Dataset('bbva_origindistr_5db8b205')>,
#   <Dataset('od_acs_e8a7d88d')>,
#   <Dataset('od_acs_38016c42')>,
#   <Dataset('bbva_destination_8a14f7d1')>,
#   <Dataset('od_acsquantile_72d68696')>,
#   <Dataset('od_epa_c006dd7d')>,
#   <Dataset('od_bls_b11879b8')>,
#   <Dataset('bbva_categorydis_ad728afc')>,
#   <Dataset('od_acs_60614ff2')>,
#   <Dataset('od_acs_f09b24f4')>,
#   <Dataset('od_acs_5978c550')>,
#   <Dataset('od_acsquantile_abb38b00')>,
#   <Dataset('od_acsquantile_e709e4ea')>,
#   <Dataset('od_tiger_3336cbf')>,
#   <Dataset('od_tiger_f9247903')>,
#   <Dataset('od_tiger_19a6dc83')>,
#   <Dataset('od_tiger_e5e51d96')>,
#   <Dataset('od_tiger_41814018')>,
#   <Dataset('od_bls_b7d3bb53')>,
#   <Dataset('od_bls_2edaeae9')>,
#   <Dataset('od_bls_59ddda7f')>,
#   <Dataset('od_bls_c7b94fdc')>,
#   <Dataset('od_tiger_b0608dc7')>,
#   <Dataset('od_bls_b611d164')>,
#   <Dataset('od_bls_2f1880de')>,
#   <Dataset('od_bls_581fb048')>,
#   <Dataset('od_bls_c67b25eb')>,
#   <Dataset('od_bls_b35ec7e1')>,
#   <Dataset('od_bls_2a57965b')>,
#   <Dataset('od_bls_5d50a6cd')>,
#   <Dataset('od_bls_5ed472a3')>,
#   <Dataset('od_bls_c0b0e700')>,
#   <Dataset('od_spielmansin_5d03106a')>,
#   <Dataset('od_zillow_3d2b2901')>,
#   <Dataset('od_zillow_a42278bb')>,
#   <Dataset('od_zillow_25f27277')>,
#   <Dataset('od_zillow_bcfb23cd')>,
#   <Dataset('od_zillow_cbfc135b')>,
#   <Dataset('od_zillow_559886f8')>,
#   <Dataset('od_zillow_bb96e7d4')>,
#   <Dataset('mc_mrli_c028d508')>,
#   <Dataset('mc_mrli_7300555a')>,
#   <Dataset('mc_mrli_4579ab81')>,
#   <Dataset('bbva_basicstats_8a30b278')>,
#   <Dataset('od_acs_1a22afad')>,
#   <Dataset('od_acsquantile_19f64c9')>,
#   <Dataset('od_zillow_cc91d742')>,
#   <Dataset('od_zillow_5c2ecad3')>,
#   <Dataset('od_zillow_2b29fa45')>,
#   <Dataset('od_zillow_4bee73a0')>,
#   <Dataset('od_zillow_3ce94336')>,
#   <Dataset('od_zillow_a5e0128c')>,
#   <Dataset('od_zillow_27b4cc2e')>,
#   <Dataset('od_acsquantile_a230736a')>,
#   <Dataset('od_zillow_bebd9d94')>,
#   <Dataset('od_zillow_229fb66e')>,
#   <Dataset('od_zillow_c9baad02')>,
#   <Dataset('od_zillow_20d90837')>,
#   <Dataset('od_zillow_b9d0598d')>,
#   <Dataset('od_zillow_ced7691b')>,
#   <Dataset('od_zillow_5e68748a')>,
#   <Dataset('od_zillow_296f441c')>,
#   <Dataset('od_zillow_49a8cdf9')>,
#   <Dataset('od_zillow_3eaffd6f')>,
#   <Dataset('od_zillow_a7a6acd5')>,
#   <Dataset('od_zillow_2676a619')>,
#   <Dataset('od_zillow_bf7ff7a3')>,
#   <Dataset('od_zillow_c878c735')>,
#   <Dataset('od_zillow_561c5296')>,
#   <Dataset('od_zillow_211b6200')>,
#   <Dataset('od_zillow_b81233ba')>,
#   <Dataset('od_zillow_cf15032c')>,
#   <Dataset('od_zillow_5faa1ebd')>,
#   <Dataset('od_zillow_28ad2e2b')>,
#   <Dataset('od_zillow_486aa7ce')>,
#   <Dataset('od_zillow_3f6d9758')>,
#   <Dataset('od_zillow_a664c6e2')>,
#   <Dataset('od_zillow_2339b09c')>,
#   <Dataset('od_zillow_ba30e126')>,
#   <Dataset('od_acs_abd63a91')>,
#   <Dataset('od_zillow_cd37d1b0')>,
#   <Dataset('od_zillow_53534413')>,
#   <Dataset('od_zillow_24547485')>,
#   <Dataset('od_zillow_bd5d253f')>,
#   <Dataset('od_zillow_ca5a15a9')>,
#   <Dataset('od_zillow_5ae50838')>,
#   <Dataset('od_zillow_bbf28b11')>,
#   <Dataset('od_zillow_ccf5bb87')>,
#   <Dataset('od_zillow_52912e24')>,
#   <Dataset('od_zillow_ceb305de')>,
#   <Dataset('od_zillow_50d7907d')>,
#   <Dataset('od_zillow_5961dc56')>,
#   <Dataset('od_zillow_2612cadc')>,
#   <Dataset('od_zillow_bf1b9b66')>,
#   <Dataset('od_zillow_c81cabf0')>,
#   <Dataset('od_zillow_58a3b661')>,
#   <Dataset('od_zillow_2fa486f7')>,
#   <Dataset('od_zillow_4f630f12')>,
#   <Dataset('od_zillow_38643f84')>,
#   <Dataset('od_zillow_a16d6e3e')>,
#   <Dataset('od_zillow_25961eb2')>,
#   <Dataset('od_zillow_bc9f4f08')>,
#   <Dataset('od_zillow_cb987f9e')>,
#   <Dataset('od_zillow_2a2349f8')>,
#   <Dataset('od_zillow_b32a1842')>,
#   <Dataset('pb_pointsofint_176f2063')>,
#   <Dataset('od_bls_b0da138f')>,
#   <Dataset('od_bls_29d34235')>,
#   <Dataset('od_zillow_2e66ecc0')>,
#   <Dataset('od_zillow_4ea16525')>,
#   <Dataset('od_acs_550657ce')>,
#   <Dataset('od_zillow_57de38a1')>,
#   <Dataset('od_zillow_27d0a0eb')>,
#   <Dataset('od_zillow_bed9f151')>,
#   <Dataset('od_zillow_c9dec1c7')>,
#   <Dataset('od_acsquantile_f7d7ac22')>,
#   <Dataset('od_zillow_2de238ae')>,
#   <Dataset('od_zillow_4d25b14b')>,
#   <Dataset('od_zillow_3a2281dd')>,
#   <Dataset('od_zillow_a32bd067')>,
#   <Dataset('od_zillow_22fbdaab')>,
#   <Dataset('od_acsquantile_c883e8a4')>,
#   <Dataset('od_zillow_2c205299')>,
#   <Dataset('od_zillow_4ce7db7c')>,
#   <Dataset('od_zillow_3be0ebea')>,
#   <Dataset('od_zillow_a2e9ba50')>,
#   <Dataset('od_zillow_20bd64f2')>,
#   <Dataset('od_zillow_b9b43548')>,
#   <Dataset('bbva_consumption_d188284b')>,
#   <Dataset('pb_pointsofint_d5a170f1')>,
#   <Dataset('mc_mrli_cdabd5c6')>],
#  [<Geography('bbva_censustract_c54aba1b')>,
#   <Geography('bbva_customgrid_a736fac6')>,
#   <Geography('bbva_municipalit_8d1c2451')>,
#   <Geography('bbva_zipcodes_741df532')>,
#   <Geography('u360_grid100x100_296d665f')>,
#   <Geography('u360_roadsegment_8301db83')>,
#   <Geography('ags_q17_4739be4f')>,
#   <Geography('ags_blockgroup_1c63771c')>,
#   <Geography('mc_postcodeuni_e9ce1824')>,
#   <Geography('mc_disseminati_7f7f2b02')>,
#   <Geography('mc_zipcode_263079e3')>,
#   <Geography('od_hydrounit_3f2c89f2')>,
#   <Geography('mc_province_3cf0b534')>,
#   <Geography('mc_censusdivis_e37e6379')>,
#   <Geography('mc_disseminati_ba5e69d1')>,
#   <Geography('vdf_grid250x250_99974c78')>,
#   <Geography('tt_roadsegment_370f8761')>,
#   <Geography('mc_postcodedis_caa12468')>,
#   <Geography('mc_postcodesec_1eefd8dd')>,
#   <Geography('mc_postcodeare_a74dd661')>,
#   <Geography('od_cbsaclipped_b6a32adc')>,
#   <Geography('mc_state_cc31b9d1')>,
#   <Geography('mc_tract_3704a85c')>,
#   <Geography('od_schooldistr_6d5c417f')>,
#   <Geography('od_placeclippe_48a89947')>,
#   <Geography('mc_county_31cde2d')>,
#   <Geography('od_blockclippe_9c508438')>,
#   <Geography('od_blockgroupc_3ab29c84')>,
#   <Geography('od_state_b8a6ca8c')>,
#   <Geography('od_schooldistr_75493a16')>,
#   <Geography('od_zcta5clippe_6b6ff33c')>,
#   <Geography('mc_blockgroup_c4b8da4c')>,
#   <Geography('mc_block_9ebc626c')>,
#   <Geography('od_cbsa_9e6439f9')>,
#   <Geography('od_schooldistr_afa62633')>,
#   <Geography('od_schooldistr_e24959cf')>,
#   <Geography('od_county_b3b16730')>,
#   <Geography('od_schooldistr_20f3685')>,
#   <Geography('od_place_e6f033a6')>,
#   <Geography('od_congression_9c47b95e')>,
#   <Geography('od_puma_4ab698ec')>,
#   <Geography('od_blockgroup_b0ca4093')>,
#   <Geography('od_censustract_da2b26bb')>,
#   <Geography('od_zcta5_81214a2f')>,
#   <Geography('od_block_ea2b1131')>,
#   <Geography('od_censustract_5962fe30')>,
#   <Geography('od_countyclipp_caef1ec9')>,
#   <Geography('od_congression_6774ebb')>,
#   <Geography('od_pumaclipped_b065909')>,
#   <Geography('od_schooldistr_f70c7e28')>,
#   <Geography('od_stateclippe_8d79f5be')>])

# %%
credentials = Credentials(
    username='team-1',
    api_key='',
    base_url='https://team.carto-staging.com/u/team-1/')

# %%
dataset = Dataset.get('ags_sociodemogr_e128078d')

dataset.subscribe(credentials)
# Out:
# HTML(value='\n    <h3>Subscription contract</h3>\n    You are about to subscribe to <b>carto-do.ags.demographi…
# GridspecLayout(children=(Button(button_style='info', description='Yes', layout=Layout(grid_area='widget001', h…

# %%
geography = Geography.get('ags_q17_4739be4f')

geography.subscribe(credentials)
# Out:
# HTML(value='\n    <h3>Subscription contract</h3>\n    You are about to subscribe to <b>carto-do.carto.geograph…
# GridspecLayout(children=(Button(button_style='info', description='Yes', layout=Layout(grid_area='widget001', h…

# %%
subscriptions = Catalog().subscriptions(credentials)

subscriptions.datasets, subscriptions.geographies
# Out:
# ([<Dataset('ags_sociodemogr_e128078d')>], [<Geography('ags_q17_4739be4f')>])
