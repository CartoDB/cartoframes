# %%
from cartoframes.viz import Map, Layer
from cartoframes.io.gbq import prepare_gbq_source

query = '''
SELECT d.total_pop, g.geom
FROM `carto-do-public-data.usa_acs.demographics_sociodemographics_usa_blockgroup_2015_5yrs_20132017` as d
INNER JOIN `carto-do-public-data.usa_carto.geography_usa_blockgroup_2018` as g ON d.geoid=g.geoid
WHERE ST_DWITHIN(g.geom,ST_GEOGPOINT(-73.95209,40.736333),1000)
'''

project = 'cartodb-gcp-backend-data-team'

token = 'ya29.a0Adw1xeVy0SVJ7INYaEQoQ4CntTgJyphuTN_dibkGNK1xHnOLg2fZt6hDibjcv8FR5n7eakKnyeeH8Yh_rNDhSquXmBO3K7nlYS_DAFMGV6z1o67emQuRCCrU_N6RfljYu-lckkzDMgtcWxNUVJuwS-mDs6O22hwzXXDLlcwJeP7IHnpWR36Ra28vjA8URxe2b1G96f_2qxndbfWpKjbA7qbG9rzEH-M2uWL5pAjClSU7fMP7j6m0XLjApKfi7wAwgYAzSIWFi1SKor4'

# %% [markdown]
# ### Small datasets

# %%
source_df = prepare_gbq_source(query, project, token, force_df=True)

# %%
Layer(source_df)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://cdn.jsdelivr.net/gh/cartodb/carto-vl@bq-poc-0.1/dist/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
# ...

# %% [markdown]
# ### Big datasets

# %%
source_mvt = prepare_gbq_source(query, project, token, force_mvt=True)
# Out:
# Preparing data. This may take a few minutes

# %%
Map(Layer(source_mvt), viewport={'zoom': 12, 'lat': 40.726336, 'lng': -73.992807})
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://cdn.jsdelivr.net/gh/cartodb/carto-vl@bq-poc-0.1/dist/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
# ...
