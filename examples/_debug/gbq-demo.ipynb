# %%
from cartoframes.viz import Map, Layer
from cartoframes.io.gbq import prepare_gbq_source

query = '''
SELECT d.total_pop, g.geoid, g.geom
FROM `carto-do-public-data.usa_acs.demographics_sociodemographics_usa_blockgroup_2015_5yrs_20132017` as d
INNER JOIN `carto-do-public-data.usa_carto.geography_usa_blockgroup_2018` as g ON d.geoid=g.geoid
WHERE ST_DWITHIN(g.geom,ST_GEOGPOINT(-73.95209,40.736333),{R})
'''

project = 'cartodb-gcp-backend-data-team'

token = 'ya29.IrABvwdnNnh8PLbvx44BSU5-oSpm6pvgf0efs4nqP-2BgMd8mzFVvsvmmmYxd_6qMkOzL7wI1pb204RNklotmbyZkZy2QLxrKaomjc_hyVWukMub2MLm7NCBqS6K9_F7xdLFj2zqdvd0QeVh26-gI3SPK_kIJEL1--ShkQ3bnxPcC4cKmvvHWYNizzeP_0OHS02xNYbZ3v1ILHsfXLw7zjwAigISSlLimXk5eh1BKRSw2po'

# %% [markdown]
# ### Small datasets

# %%
source_df = prepare_gbq_source(query.format(R=10000), project, token)  # or force_df=True
# Out:
# Estimating size. This may take a few seconds
# DEBUG: small dataset (527.03 KB)
# ...
# DEBUG: time elapsed 3.02s

# %%
Layer(source_df)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://cdn.jsdelivr.net/gh/cartodb/carto-vl@bq-poc-0.1/dist/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
# ...

# %% [markdown]
# ### Big datasets

# %%
source_mvt = prepare_gbq_source(query.format(R=100000), project, token)  # or force_mvt=True
# Out:
# Estimating size. This may take a few seconds
# DEBUG: big dataset (13.10 MB)
# Preparing data. This may take a few minutes
# DEBUG: time elapsed 34.72s

# %%
Map(Layer(source_mvt), min_zoom=4, max_zoom=16)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://cdn.jsdelivr.net/gh/cartodb/carto-vl@bq-poc-0.1/dist/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
# ...
