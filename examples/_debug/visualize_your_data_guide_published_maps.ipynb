# %% [markdown]
# # Visual and Interactive Data Exploration

# %%
from cartoframes.viz import Map, Layer
map_viz = Map([
    Layer('starbucks_brooklyn_iso_enriched'),
    Layer('starbucks_brooklyn_geocoded')
])
map_viz.publish(name='viz_guide_add_layers_to_map')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-6736e86eb59e> in <module>
#       1 from cartoframes.viz import Map, Layer
#       2 map_viz = Map([
# ----> 3     Layer('starbucks_brooklyn_iso_enriched'),
#       4     Layer('starbucks_brooklyn_geocoded')
#       5 ])
#
# ~/Projects/CARTO/carto-data-science-stack/cartoframes/cartoframes/viz/layer.py in __init__(self, source, style, popup, legend, widgets, credentials, bounds)
#     134         self.is_basemap = False
#     135
# --> 136         self.source = _set_source(source, credentials)
#     137         self.style = _set_style(style)
#     138         self.popup = _set_popup(popup)
#
# ~/Projects/CARTO/carto-data-science-stack/cartoframes/cartoframes/viz/layer.py in _set_source(source, credentials)
#     165     """Set a Source class from the input"""
#     166     if isinstance(source, (str, pandas.DataFrame)):
# --> 167         return Source(source, credentials)
#     168     elif isinstance(source, Source):
#     169         return source
#
# ~/Projects/CARTO/carto-data-science-stack/cartoframes/cartoframes/viz/source.py in __init__(self, source, credentials, schema)
#      83             # Table, SQL query
#      84             self.type = SourceType.QUERY
# ---> 85             self.manager = ContextManager(credentials)
#      86             self.query = self.manager.compute_query(source, schema)
#      87             self.credentials = self.manager.credentials
#
# ~/Projects/CARTO/carto-data-science-stack/cartoframes/cartoframes/core/managers/context_manager.py in __init__(self, credentials)
#      28     def __init__(self, credentials):
#      29         self.credentials = credentials or get_default_credentials()
# ---> 30         check_credentials(self.credentials)
#      31
#      32         self.auth_client = _create_auth_client(self.credentials)
#
# ~/Projects/CARTO/carto-data-science-stack/cartoframes/cartoframes/utils/utils.py in check_credentials(credentials)
#     326 def check_credentials(credentials):
#     327     if not isinstance(credentials, Credentials):
# --> 328         raise AttributeError('Credentials attribute is required. '
#     329                              'Please pass a `Credentials` instance '
#     330                              'or use the `set_default_credentials` function.')
#
# AttributeError: Credentials attribute is required. Please pass a `Credentials` instance or use the `set_default_credentials` function.

# %%
import pandas

df = pandas.read_csv('../files/starbucks_brooklyn_geocoded.csv')
df

# %%
# Add widgets and popups to explore data
# Size points by revenue
    
from cartoframes.viz.widgets import formula_widget, histogram_widget, category_widget
from cartoframes.viz import Popup
from cartoframes.viz.helpers import size_continuous_layer

map_viz=Map([
    Layer(
        'starbucks_brooklyn_iso_enriched',
        widgets=[
            formula_widget(
                'popcy',
                'sum',
                title='Total Population Served'
            ),
            formula_widget(
                'inccymedhh',
                'sum',
                title='Median Income ($)'
            ),
            formula_widget(
                'lbfcyempl',
                'sum',
                title='Employed Population',
            ),
            formula_widget(
                'educybach',
                'sum',
                title='Number of People with Bachelor Degree',
            ),
            category_widget(
                'id_store',
                title='Store ID'
            )
        ],
        popup=Popup({
            'hover': {
                'title': 'Store ID',
                'value': '$id_store'
            }
        })
      ),
    size_continuous_layer(
        'starbucks_brooklyn_geocoded',
        'revenue',
        size=[10,50],
        title='Annual Revenue ($)',
        widget=True
    )
])
map_viz.publish(name='viz_guide_data_exploration_map')

# %%
from cartoframes.viz.helpers import color_bins_layer

map_viz=Map([
    color_bins_layer(
        'starbucks_brooklyn_iso_enriched',
        'inccymedhh',
        bins=7,
        palette='pinkyl',
        opacity=0.8,
        stroke_width=0,
        title='Median Household Income ($)',
        footer='Source: US Census Bureau'
    ),
    size_continuous_layer(
        'starbucks_brooklyn_geocoded',
        'revenue',
        size=[10,50],
        range_max=1000000,
        opacity=0,
        stroke_color='turquoise',
        stroke_width=2,
        title='Annual Revenue ($)',
        description='Reported in 2018'
    ),
    Layer(
        'starbucks_brooklyn_geocoded',
        popup=Popup({
            'hover': {
                'title': 'Store ID',
                'value': '$id_store'
            }
        })
        
    ),
],viewport={'zoom': 12, 'lat': 40.644417, 'lng': -73.934710})
map_viz.publish(name='viz_guide_present_insights')

# %%
from cartoframes.viz import Layout

Layout([
    Map([
        size_continuous_layer(
            'starbucks_brooklyn_geocoded',
            'revenue',
            size=[10,50],
            range_max=1000000,
            opacity=0,
            stroke_color='turquoise',
            stroke_width=2,
            title='Annual Revenue'
        ),
        Layer('starbucks_brooklyn_geocoded')
    ]),
    Map([
        color_bins_layer(
            'starbucks_brooklyn_iso_enriched',
            'inccymedhh',
            bins=7,
            palette='pinkyl',
            stroke_width=0,
            title='Median Income',
        ),
        Layer('starbucks_brooklyn_geocoded'),
    ]),
    Map([
        color_bins_layer(
            'starbucks_brooklyn_iso_enriched',
            'popcy',
            bins=7,
            palette='pinkyl',
            stroke_width=0,
            title='Total Pop',
        ),
        Layer('starbucks_brooklyn_geocoded'),
    ]),
    Map([
        color_bins_layer(
            'starbucks_brooklyn_iso_enriched',
            'lbfcyempl',
            bins=7,
            palette='pinkyl',
            stroke_width=0,
            title='Employed Pop',
        ),
        Layer('starbucks_brooklyn_geocoded'),
    ]),
],2,2,viewport={'zoom': 10, 'lat': 40.64, 'lng': -73.92}, map_height=400)
