# %% [markdown]
# # Discoverying content of interest in the Data Observatory
#
# The Discovery API is a powerful tool for exploring the available datasets in our data lake. Through its methods you would be able to navigate through the datasets and their properties, thus knowing in advanced which sources may be of interest for you before even requesting access to them.

# %% [markdown]
# ## Catalog: the first step for discovery
#
# The Catalog class provides the methods to be used as the starting point in your discovery. It allows you to get the complete list of categories related to the avilable datasets, for example.

# %% [markdown]
# ### Get the list of categories

# %%
from cartoframes.data.observatory import Catalog
from cartoframes.data.observatory import Category

catalog = Catalog()
categories = catalog.categories

categories
# Out:
# [<Category('demographics')>,
#  <Category('environmental')>,
#  <Category('financial')>,
#  <Category('housing')>,
#  <Category('human_mobility')>,
#  <Category('points_of_interest')>,
#  <Category('road_traffic')>]

# %%
isinstance(categories[0], Category)
# Out:
# True

# %% [markdown]
# We can also obtain the categories as a pandas DataFrame:

# %%
categories_df = categories.to_dataframe()
categories_df
# Out:
#                    id                name
# 0        demographics        Demographics
# 1       environmental       Environmental
# 2           financial           Financial
# 3             housing             Housing
# 4      human_mobility      Human Mobility
# 5  points_of_interest  Points of Interest
# 6        road_traffic        Road Traffic

# %%
import pandas as pd

isinstance(categories_df, pd.DataFrame)
# Out:
# True

# %% [markdown]
# ### Filter one category
#
# Since the list of categories is also a Pandas' DataFrame, we can use its already familiar methods to explore the data.

# %%
filtered_category = categories[0]
filtered_category
# Out:
# <Category('demographics')>

# %%
isinstance(filtered_category, Category)
# Out:
# True

# %% [markdown]
# We can obtain the category in a pandas Series:

# %%
category_series = filtered_category.to_series()
category_series
# Out:
# id      demographics
# name    Demographics
# dtype: object

# %%
import pandas as pd

isinstance(category_series, pd.Series)
# Out:
# True

# %% [markdown]
# ## Explore a particular category
#
# If we already know that a particular category has presence in the Catalog, we can retrieve it directly by using its id.

# %%
category1 = catalog.categories.get('demographics')

category1
# Out:
# [<CatalogDataset('od_acs_181619a3')>,
#  <CatalogDataset('od_acs_550657ce')>,
#  <CatalogDataset('mbi_retail_turn_a40b2d9e')>,
#  <CatalogDataset('od_acs_6e4b69f6')>,
#  <CatalogDataset('mbi_purchasing__ff4ce909')>,
#  <CatalogDataset('mbi_population_73b2034')>,
#  <CatalogDataset('mbi_population_bf3a91db')>,
#  <CatalogDataset('od_acs_9510981d')>,
#  <CatalogDataset('od_acs_6d43ed82')>,
#  <CatalogDataset('od_acs_194c5960')>,
#  <CatalogDataset('mbi_population_552f1d19')>,
#  <CatalogDataset('mbi_population_70c11317')>,
#  <CatalogDataset('mbi_population_c207835a')>,
#  <CatalogDataset('mbi_population_8b8bf92b')>,
#  <CatalogDataset('mbi_education_3d6776b9')>,
#  <CatalogDataset('mbi_retail_turn_36a9dbe1')>,
#  <CatalogDataset('mbi_population_af1d83ba')>,
#  <CatalogDataset('mbi_retail_cent_ac0457a5')>,
#  <CatalogDataset('mbi_purchasing__c9645e12')>,
#  <CatalogDataset('od_acs_38016c42')>,
#  <CatalogDataset('od_acs_9a9c93b8')>,
#  <CatalogDataset('od_acs_7b2649a9')>,
#  <CatalogDataset('od_acs_478c37b8')>,
#  <CatalogDataset('od_acs_f98ddfce')>,
#  <CatalogDataset('od_acs_1f614ee8')>,
#  <CatalogDataset('mbi_sociodemogr_1469299e')>,
#  <CatalogDataset('mbi_retail_spen_c749c2ee')>,
#  <CatalogDataset('od_acs_8b00f653')>,
#  <CatalogDataset('od_acs_d52a0635')>,
#  <CatalogDataset('od_acs_1deaa51')>,
#  <CatalogDataset('od_acs_e0f5ff55')>,
#  <CatalogDataset('od_acs_52710085')>,
#  <CatalogDataset('od_acs_b3eac6e8')>,
#  <CatalogDataset('mbi_households__6e377f70')>,
#  <CatalogDataset('od_acs_1a09274c')>,
#  <CatalogDataset('mbi_retail_spen_74ef7398')>,
#  <CatalogDataset('mbi_retail_spen_bdbc88f4')>,
#  <CatalogDataset('mbi_retail_spen_9d8d164c')>,
#  <CatalogDataset('mbi_households__400e1f2')>,
#  <CatalogDataset('mbi_sociodemogr_241fcfe')>,
#  <CatalogDataset('mbi_consumer_sp_804ae09f')>,
#  <CatalogDataset('mbi_sociodemogr_59f19c8f')>,
#  <CatalogDataset('mbi_households__bc93fe13')>,
#  <CatalogDataset('ags_sociodemogr_e92b1637')>,
#  <CatalogDataset('mbi_sociodemogr_7e5d7713')>,
#  <CatalogDataset('ags_consumerspe_fe5d060a')>,
#  <CatalogDataset('od_acs_e8a7d88d')>,
#  <CatalogDataset('mbi_sociodemogr_aaac5fe9')>,
#  <CatalogDataset('mbi_purchasing__3be4e0c8')>,
#  <CatalogDataset('od_acs_60614ff2')>,
#  <CatalogDataset('od_acs_f09b24f4')>,
#  <CatalogDataset('od_acs_1cfa643a')>,
#  <CatalogDataset('od_acs_c4a00c26')>,
#  <CatalogDataset('od_acs_c1c86582')>,
#  <CatalogDataset('od_acs_5b8fdefd')>,
#  <CatalogDataset('mbi_sociodemogr_8a7b040c')>,
#  <CatalogDataset('mbi_sociodemogr_edae8408')>,
#  <CatalogDataset('mbi_sociodemogr_61abe88c')>,
#  <CatalogDataset('mbi_sociodemogr_63544b8')>,
#  <CatalogDataset('mbi_consumer_sp_98c8591e')>,
#  <CatalogDataset('u360_demographic_94266d3')>,
#  <CatalogDataset('od_spielmansin_5d03106a')>,
#  <CatalogDataset('mbi_education_fcd214dd')>,
#  <CatalogDataset('mbi_households__109a963')>,
#  <CatalogDataset('mbi_sociodemogr_a260b8a8')>,
#  <CatalogDataset('mbi_education_b38f515')>,
#  <CatalogDataset('mbi_sociodemogr_e7e8c988')>,
#  <CatalogDataset('od_acs_c2868f47')>,
#  <CatalogDataset('od_acs_b581bfd1')>,
#  <CatalogDataset('mbi_sociodemogr_93d4a324')>,
#  <CatalogDataset('mbi_purchasing__23143aac')>,
#  <CatalogDataset('od_acs_2d438a42')>,
#  <CatalogDataset('od_acs_c6bf32c9')>,
#  <CatalogDataset('od_acs_91ff81e3')>,
#  <CatalogDataset('mbi_purchasing__2f0c36fb')>,
#  <CatalogDataset('od_acs_13345497')>,
#  <CatalogDataset('od_acs_87fa66db')>,
#  <CatalogDataset('mbi_population_fbcd3b85')>,
#  <CatalogDataset('mbi_sociodemogr_4066dd40')>,
#  <CatalogDataset('mbi_consumer_sp_fba12e82')>,
#  <CatalogDataset('od_acs_b98db80e')>,
#  <CatalogDataset('od_acs_9f4d1f13')>,
#  <CatalogDataset('od_acs_5b67fbbf')>,
#  <CatalogDataset('od_acs_29664073')>,
#  <CatalogDataset('mbi_population_deffab10')>,
#  <CatalogDataset('mbi_population_685846c7')>,
#  <CatalogDataset('mbi_consumer_sp_aa8046fd')>,
#  <CatalogDataset('od_acs_4bb9b377')>,
#  <CatalogDataset('od_acs_aa92e673')>,
#  <CatalogDataset('od_acs_1db77442')>,
#  <CatalogDataset('od_acs_9df157a1')>,
#  <CatalogDataset('mbi_population_c738f69c')>,
#  <CatalogDataset('od_acs_f3eaa128')>,
#  <CatalogDataset('od_tiger_19a6dc83')>,
#  <CatalogDataset('mbi_sociodemogr_7cf425e1')>,
#  <CatalogDataset('od_tiger_e5e51d96')>,
#  <CatalogDataset('od_tiger_41814018')>,
#  <CatalogDataset('od_tiger_b0608dc7')>,
#  <CatalogDataset('mbi_consumer_sp_95cb4e50')>,
#  <CatalogDataset('mbi_consumer_sp_cdb8f12d')>,
#  <CatalogDataset('od_acs_1a22afad')>,
#  <CatalogDataset('ags_retailpoten_ddf56a1a')>,
#  <CatalogDataset('mbi_households__a33ccbc4')>,
#  <CatalogDataset('ags_consumerpro_e8344e2e')>,
#  <CatalogDataset('mbi_population_731c061e')>,
#  <CatalogDataset('mbi_population_37484b32')>,
#  <CatalogDataset('u360_touristicin_463a7b9e')>,
#  <CatalogDataset('u360_pedestriant_4757ec23')>,
#  <CatalogDataset('u360_commerciali_7694276b')>,
#  <CatalogDataset('mbi_purchasing__958db7d5')>,
#  <CatalogDataset('mbi_purchasing__448a9698')>,
#  <CatalogDataset('mbi_sociodemogr_9c07d454')>,
#  <CatalogDataset('mbi_sociodemogr_216c9a35')>,
#  <CatalogDataset('mbi_sociodemogr_6ee94536')>,
#  <CatalogDataset('mbi_sociodemogr_1c07f6d8')>,
#  <CatalogDataset('mbi_marital_sta_d63ec9b1')>,
#  <CatalogDataset('mbi_sociodemogr_81866af0')>,
#  <CatalogDataset('mbi_purchasing__7c3d7271')>,
#  <CatalogDataset('mbi_population_f6d646f1')>,
#  <CatalogDataset('mbi_marital_sta_e24fdd88')>,
#  <CatalogDataset('ags_businesscou_a8310a11')>,
#  <CatalogDataset('u360_workingpopu_ac666c1f')>,
#  <CatalogDataset('od_acs_dc3cfd0f')>,
#  <CatalogDataset('od_acs_5c10acf4')>,
#  <CatalogDataset('mbi_education_5ae6af16')>,
#  <CatalogDataset('mbi_marital_sta_9f4f5206')>,
#  <CatalogDataset('mbi_population_f8f49fc')>,
#  <CatalogDataset('mbi_consumer_sp_735399ae')>,
#  <CatalogDataset('mbi_consumer_sp_7915d42e')>,
#  <CatalogDataset('mbi_households__45067b14')>,
#  <CatalogDataset('mbi_population_47bba1ac')>,
#  <CatalogDataset('mbi_population_83dbf8d6')>,
#  <CatalogDataset('mbi_consumer_sp_2fad0fe5')>,
#  <CatalogDataset('mbi_consumer_sp_bf918793')>,
#  <CatalogDataset('mbi_consumer_sp_ff56f52a')>,
#  <CatalogDataset('mbi_consumer_sp_f0145890')>,
#  <CatalogDataset('mbi_consumer_sp_82faeb7e')>,
#  <CatalogDataset('mbi_sociodemogr_898c773b')>,
#  <CatalogDataset('mbi_consumer_sp_1f7b7756')>,
#  <CatalogDataset('mbi_sociodemogr_2bf0faf3')>,
#  <CatalogDataset('mbi_consumer_sp_9a029b9')>,
#  <CatalogDataset('mbi_purchasing__44de421')>,
#  <CatalogDataset('mbi_purchasing__c2c9b79c')>,
#  <CatalogDataset('mbi_purchasing__9008c244')>,
#  <CatalogDataset('mbi_purchasing__7664929f')>,
#  <CatalogDataset('mbi_purchasing__87256cc1')>,
#  <CatalogDataset('mbi_purchasing__c90e0015')>,
#  <CatalogDataset('mbi_marital_sta_6576ce40')>,
#  <CatalogDataset('mbi_purchasing__5b7c0907')>,
#  <CatalogDataset('mbi_education_c5c0352d')>,
#  <CatalogDataset('od_acs_d28e63ff')>,
#  <CatalogDataset('mbi_consumer_sp_35d0adfe')>,
#  <CatalogDataset('mbi_purchasing__b926aa40')>,
#  <CatalogDataset('mbi_consumer_sp_8038837a')>,
#  <CatalogDataset('mbi_consumer_sp_148619aa')>,
#  <CatalogDataset('mbi_purchasing__59d55bf5')>,
#  <CatalogDataset('mbi_consumer_sp_72d263a7')>,
#  <CatalogDataset('mbi_purchasing__4bc83b22')>,
#  <CatalogDataset('mbi_purchasing__392688cc')>,
#  <CatalogDataset('mbi_consumer_sp_2fac9f2')>,
#  <CatalogDataset('mbi_purchasing__a4a714e4')>,
#  <CatalogDataset('ags_sociodemogr_e128078d')>,
#  <CatalogDataset('ags_crimerisk_9ec89442')>,
#  <CatalogDataset('mbi_sociodemogr_c9711f1c')>,
#  <CatalogDataset('mbi_purchasing__ee2d67ac')>,
#  <CatalogDataset('mbi_sociodemogr_61df236e')>,
#  <CatalogDataset('mbi_consumer_sp_e2093847')>,
#  <CatalogDataset('od_acs_a9825694')>,
#  <CatalogDataset('od_tiger_5e55275d')>,
#  <CatalogDataset('od_acs_a665f9e1')>,
#  <CatalogDataset('od_acs_5ec6965e')>,
#  <CatalogDataset('od_acs_f2f40516')>,
#  <CatalogDataset('od_acs_1209a7e9')>,
#  <CatalogDataset('od_acs_6c9090b5')>,
#  <CatalogDataset('od_acs_f9681e48')>,
#  <CatalogDataset('od_acs_8c8516b')>,
#  <CatalogDataset('od_acs_59534db1')>,
#  <CatalogDataset('od_acs_57d06d64')>,
#  <CatalogDataset('od_acs_e9e3046f')>,
#  <CatalogDataset('od_acs_506e3e6a')>,
#  <CatalogDataset('od_acs_b4cbd26')>,
#  <CatalogDataset('od_acs_fc07c6c5')>,
#  <CatalogDataset('od_acs_a1083df8')>,
#  <CatalogDataset('od_acs_6bfd54ac')>,
#  <CatalogDataset('od_tiger_f9247903')>,
#  <CatalogDataset('od_acs_abd63a91')>,
#  <CatalogDataset('mbi_households__981be2e8')>,
#  <CatalogDataset('od_acs_e1b123b7')>,
#  <CatalogDataset('od_acs_c31e5f28')>,
#  <CatalogDataset('od_tiger_476ce2e9')>,
#  <CatalogDataset('od_tiger_fac69779')>,
#  <CatalogDataset('od_tiger_384d0b09')>,
#  <CatalogDataset('od_acs_7c4b8db0')>,
#  <CatalogDataset('od_acs_eaf66737')>,
#  <CatalogDataset('od_lodes_b4b9dfac')>,
#  <CatalogDataset('od_acs_17667f64')>,
#  <CatalogDataset('od_acs_8c6d324a')>,
#  <CatalogDataset('od_acs_d60f0d6e')>,
#  <CatalogDataset('od_tiger_e10059f')>,
#  <CatalogDataset('od_acs_4f56aa89')>,
#  <CatalogDataset('od_acs_d9e8a21b')>,
#  <CatalogDataset('mbi_education_821a28eb')>,
#  <CatalogDataset('mbi_sociodemogr_b1501243')>,
#  <CatalogDataset('mbi_sociodemogr_b529bc50')>,
#  <CatalogDataset('mbi_sociodemogr_5345ec8b')>,
#  <CatalogDataset('od_acs_c5eb4b5e')>,
#  <CatalogDataset('od_tiger_3336cbf')>,
#  <CatalogDataset('mbi_sociodemogr_ec2f7e01')>,
#  <CatalogDataset('od_acs_de856602')>,
#  <CatalogDataset('od_acs_5978c550')>,
#  <CatalogDataset('mbi_sociodemogr_684ad049')>,
#  <CatalogDataset('mbi_sociodemogr_27d9ea78')>,
#  <CatalogDataset('mbi_sociodemogr_b3653f6')>,
#  <CatalogDataset('od_tiger_66b9092c')>,
#  <CatalogDataset('od_acs_db9898c5')>,
#  <CatalogDataset('od_acs_670c8beb')>,
#  <CatalogDataset('od_acs_6926adef')>,
#  <CatalogDataset('mbi_purchasing__c88ffa1c')>,
#  <CatalogDataset('mbi_education_cc926c54')>,
#  <CatalogDataset('mbi_education_762e04ae')>,
#  <CatalogDataset('mbi_population_678f3375')>,
#  <CatalogDataset('mbi_purchasing__94716c57')>,
#  <CatalogDataset('mbi_purchasing__2e172de2')>,
#  <CatalogDataset('mbi_purchasing__af5a7a18')>,
#  <CatalogDataset('mbi_education_1d29e506')>,
#  <CatalogDataset('mbi_education_bac941f7')>,
#  <CatalogDataset('mbi_purchasing__4d6bae5d')>,
#  <CatalogDataset('mbi_purchasing__8e0cce4c')>,
#  <CatalogDataset('mbi_education_8f53024')>,
#  <CatalogDataset('mbi_education_1b4edb2e')>,
#  <CatalogDataset('mbi_education_227ba9ac')>,
#  <CatalogDataset('mbi_consumer_sp_17716a9d')>,
#  <CatalogDataset('mbi_consumer_sp_f6b7cdef')>,
#  <CatalogDataset('mbi_population_954f45aa')>,
#  <CatalogDataset('mbi_population_63cf59c9')>,
#  <CatalogDataset('mbi_population_1b846234')>,
#  <CatalogDataset('mbi_education_50ded682')>,
#  <CatalogDataset('mbi_marital_sta_a0d1c86b')>,
#  <CatalogDataset('mbi_retail_cent_9fddd44a')>,
#  <CatalogDataset('mbi_education_54220c21')>,
#  <CatalogDataset('mbi_retail_spen_928a0453')>,
#  <CatalogDataset('mbi_retail_spen_1f4f5cc4')>,
#  <CatalogDataset('mbi_retail_spen_5eb92763')>,
#  <CatalogDataset('mbi_retail_spen_bfd9b3fb')>,
#  <CatalogDataset('mbi_households__a52da13')>,
#  <CatalogDataset('mbi_consumer_pr_70e4fbd')>,
#  <CatalogDataset('mbi_consumer_pr_d1cd7490')>,
#  <CatalogDataset('mbi_retail_spen_ffbcad71')>,
#  <CatalogDataset('mbi_retail_spen_628b3e25')>,
#  <CatalogDataset('mbi_consumer_sp_6b599fad')>,
#  <CatalogDataset('mbi_education_ab1322a4')>,
#  <CatalogDataset('mbi_retail_spen_959b2837')>,
#  <CatalogDataset('mbi_consumer_sp_26cf73a9')>,
#  <CatalogDataset('mbi_retail_spen_e2c1988e')>,
#  <CatalogDataset('mbi_retail_spen_14142fb4')>,
#  <CatalogDataset('mbi_retail_cent_73bd00d0')>,
#  <CatalogDataset('mbi_retail_spen_71ed889f')>,
#  <CatalogDataset('mbi_population_7c37e8d2')>,
#  <CatalogDataset('mbi_education_b3faf5f3')>,
#  <CatalogDataset('mbi_retail_spen_95e72b80')>,
#  <CatalogDataset('mbi_consumer_sp_dedd5576')>,
#  <CatalogDataset('mbi_consumer_sp_9a7b0cbd')>,
#  <CatalogDataset('mbi_consumer_sp_4e3123b7')>,
#  <CatalogDataset('mbi_households__23f746a9')>,
#  <CatalogDataset('mbi_population_b5973234')>,
#  <CatalogDataset('mbi_population_f8cc9f68')>,
#  <CatalogDataset('mbi_population_12e15a3f')>,
#  <CatalogDataset('mbi_population_7d5c9b58')>,
#  <CatalogDataset('mbi_education_80732cd')>,
#  <CatalogDataset('mbi_population_240d4d56')>,
#  <CatalogDataset('mbi_education_4ae1d50e')>,
#  <CatalogDataset('mbi_population_92d0ee3c')>,
#  <CatalogDataset('mbi_retail_spen_d00d641b')>,
#  <CatalogDataset('mbi_retail_turn_ee9532ae')>,
#  <CatalogDataset('mbi_purchasing__67ffb52')>,
#  <CatalogDataset('mbi_marital_sta_a68a7ec9')>,
#  <CatalogDataset('mbi_marital_sta_c20496ee')>,
#  <CatalogDataset('mbi_sociodemogr_d0d203f')>,
#  <CatalogDataset('mbi_retail_spen_179140fc')>,
#  <CatalogDataset('mbi_marital_sta_faf50e6b')>,
#  <CatalogDataset('mbi_marital_sta_676c857f')>,
#  <CatalogDataset('mbi_marital_sta_29244604')>,
#  <CatalogDataset('mbi_marital_sta_6d4a8559')>,
#  <CatalogDataset('mbi_education_f4887324')>,
#  <CatalogDataset('mbi_education_302cf48c')>,
#  <CatalogDataset('mbi_consumer_pr_85cc0535')>,
#  <CatalogDataset('mbi_consumer_pr_405e0e3b')>,
#  <CatalogDataset('mbi_consumer_pr_71f4fc68')>,
#  <CatalogDataset('mbi_population_d744417')>,
#  <CatalogDataset('mbi_retail_spen_32189ad3')>,
#  <CatalogDataset('mbi_population_a7baa4dd')>,
#  <CatalogDataset('mbi_population_47662835')>,
#  <CatalogDataset('mbi_sociodemogr_c700bf1c')>,
#  <CatalogDataset('mbi_retail_spen_366134c0')>,
#  <CatalogDataset('mbi_education_cea38973')>,
#  <CatalogDataset('mbi_population_136939b')>,
#  <CatalogDataset('mbi_population_7e96d5e8')>,
#  <CatalogDataset('mbi_population_dc8d2bec')>,
#  <CatalogDataset('mbi_population_71e2c41c')>,
#  <CatalogDataset('mbi_population_c38dcfaa')>,
#  <CatalogDataset('mbi_population_956eb25b')>,
#  <CatalogDataset('mbi_retail_turn_8963eda8')>,
#  <CatalogDataset('mbi_population_74d98571')>,
#  <CatalogDataset('mbi_education_1c7d8e8d')>,
#  <CatalogDataset('mbi_education_20d3049e')>,
#  <CatalogDataset('mbi_education_2e058ac6')>,
#  <CatalogDataset('mbi_population_43bf2e02')>,
#  <CatalogDataset('mbi_education_a867ecf')>,
#  <CatalogDataset('mbi_education_89792663')>,
#  <CatalogDataset('mbi_population_16200069')>,
#  <CatalogDataset('mbi_population_41569e34')>,
#  <CatalogDataset('mbi_population_b831b137')>,
#  <CatalogDataset('mbi_population_4222736e')>,
#  <CatalogDataset('mbi_population_fc7060e9')>,
#  <CatalogDataset('mbi_households__5e25ce97')>,
#  <CatalogDataset('mbi_population_40294f32')>,
#  <CatalogDataset('mbi_population_2d9c4518')>,
#  <CatalogDataset('mbi_population_54d31d6')>,
#  <CatalogDataset('mbi_population_499d6201')>,
#  <CatalogDataset('mbi_population_74ca8906')>,
#  <CatalogDataset('mbi_retail_spen_de784e49')>,
#  <CatalogDataset('mbi_population_a2991dc9')>,
#  <CatalogDataset('mbi_population_7f2f09bc')>,
#  <CatalogDataset('mbi_population_af9b0dc9')>,
#  <CatalogDataset('mbi_population_fd063cd8')>,
#  <CatalogDataset('mbi_consumer_pr_587a8dc1')>,
#  <CatalogDataset('mbi_population_c8491953')>,
#  <CatalogDataset('mbi_population_e4fc2cbe')>,
#  <CatalogDataset('mbi_population_128ae3a6')>,
#  <CatalogDataset('mbi_education_378ccce3')>,
#  <CatalogDataset('mbi_population_ffacf93a')>,
#  <CatalogDataset('mbi_education_9624b12b')>,
#  <CatalogDataset('mbi_population_3064fd97')>,
#  <CatalogDataset('mbi_population_e2d9a96b')>,
#  <CatalogDataset('mbi_education_39439103')>,
#  <CatalogDataset('mbi_population_f89041ae')>,
#  <CatalogDataset('mbi_population_a839556e')>,
#  <CatalogDataset('mbi_population_478bbbc3')>,
#  <CatalogDataset('mbi_population_87a15c36')>,
#  <CatalogDataset('mbi_population_fe818ea5')>,
#  <CatalogDataset('mbi_population_258fbbb9')>,
#  <CatalogDataset('mbi_population_616e9e3f')>,
#  <CatalogDataset('mbi_population_1c94706d')>,
#  <CatalogDataset('mbi_population_44e7cf10')>,
#  <CatalogDataset('mbi_population_4a68bc06')>,
#  <CatalogDataset('mbi_population_769cfa61')>,
#  <CatalogDataset('mbi_households__e3135e72')>,
#  <CatalogDataset('mbi_households__529bb220')>,
#  <CatalogDataset('mbi_population_abc14d43')>,
#  <CatalogDataset('mbi_consumer_pr_8a83111d')>,
#  <CatalogDataset('mbi_population_6d32d5c')>,
#  <CatalogDataset('mbi_population_9f1da2f7')>,
#  <CatalogDataset('mbi_population_e3f7984f')>,
#  <CatalogDataset('mbi_population_5e131025')>,
#  <CatalogDataset('mbi_population_ae87ca7a')>,
#  <CatalogDataset('mbi_population_9976c948')>,
#  <CatalogDataset('mbi_population_33106824')>,
#  <CatalogDataset('mbi_purchasing__7e784fa9')>,
#  <CatalogDataset('mbi_consumer_pr_ac6cc45b')>,
#  <CatalogDataset('mbi_population_c4c2d80f')>,
#  <CatalogDataset('mbi_population_8d74a32b')>,
#  <CatalogDataset('mbi_population_2af27f65')>,
#  <CatalogDataset('mbi_population_5114023a')>,
#  <CatalogDataset('mbi_population_ce57f616')>,
#  <CatalogDataset('mbi_education_10e7aab7')>,
#  <CatalogDataset('mbi_population_90824269')>,
#  <CatalogDataset('mbi_consumer_sp_fbde05a6')>,
#  <CatalogDataset('mbi_consumer_sp_26e2cfad')>,
#  <CatalogDataset('mbi_consumer_sp_3b5a536a')>,
#  <CatalogDataset('mbi_consumer_sp_a19bdf2e')>,
#  <CatalogDataset('mbi_population_5aefb1ef')>,
#  <CatalogDataset('mbi_population_2fd3aba0')>,
#  <CatalogDataset('mbi_population_68f8f0d5')>,
#  <CatalogDataset('mbi_population_bf8ee918')>,
#  <CatalogDataset('mbi_population_59f39389')>,
#  <CatalogDataset('mbi_households__e5b63cab')>,
#  <CatalogDataset('mbi_education_48a0352e')>,
#  <CatalogDataset('mbi_population_a77a929d')>,
#  <CatalogDataset('mbi_population_bf79d506')>,
#  <CatalogDataset('mbi_consumer_sp_d2fbe466')>,
#  <CatalogDataset('mbi_consumer_sp_66cdcdfc')>,
#  <CatalogDataset('mbi_consumer_sp_1763f32e')>,
#  <CatalogDataset('mbi_consumer_sp_c59a5a07')>,
#  <CatalogDataset('mbi_population_8b7faa5f')>,
#  <CatalogDataset('mbi_population_cff75bb3')>,
#  <CatalogDataset('mbi_population_f8718f91')>,
#  <CatalogDataset('mbi_population_341ee33b')>,
#  <CatalogDataset('mbi_population_b22eaf47')>,
#  <CatalogDataset('mbi_retail_spen_925acc12')>,
#  <CatalogDataset('mbi_population_afdcc52b')>,
#  <CatalogDataset('mbi_population_b4091b9')>,
#  <CatalogDataset('mbi_education_c0caec99')>,
#  <CatalogDataset('mbi_retail_spen_59d0722f')>,
#  <CatalogDataset('mbi_education_f2064218')>,
#  <CatalogDataset('mbi_education_8e4e3d70')>,
#  <CatalogDataset('mbi_education_b2fb2a3f')>,
#  <CatalogDataset('mbi_education_336089f1')>,
#  <CatalogDataset('mbi_consumer_pr_4a8e3dea')>,
#  <CatalogDataset('mbi_retail_spen_ac4ffab')>,
#  <CatalogDataset('mbi_education_8fb7c5fd')>,
#  <CatalogDataset('mbi_education_7a4855d5')>,
#  <CatalogDataset('mbi_education_99403e78')>,
#  <CatalogDataset('mbi_education_de6e0e32')>,
#  <CatalogDataset('mbi_retail_spen_c3140e65')>,
#  <CatalogDataset('mbi_education_97a54b22')>,
#  <CatalogDataset('mbi_consumer_sp_e363df4a')>,
#  <CatalogDataset('mbi_education_ed20829a')>,
#  <CatalogDataset('mbi_education_de67cf03')>,
#  <CatalogDataset('mbi_education_50cf9b0b')>,
#  <CatalogDataset('mbi_education_33a31435')>,
#  <CatalogDataset('mbi_education_29a29bcd')>,
#  <CatalogDataset('mbi_education_6a48b9e0')>,
#  <CatalogDataset('mbi_education_cc226caa')>,
#  <CatalogDataset('mbi_education_c2a8191a')>,
#  <CatalogDataset('mbi_education_18f605d6')>,
#  <CatalogDataset('mbi_education_2450f136')>,
#  <CatalogDataset('mbi_education_2057bd69')>,
#  <CatalogDataset('mbi_education_da0ac3b6')>,
#  <CatalogDataset('mbi_retail_turn_cd694587')>,
#  <CatalogDataset('mbi_marital_sta_8c6a94a5')>,
#  <CatalogDataset('mbi_population_da23a6ad')>,
#  <CatalogDataset('mbi_education_341b4904')>,
#  <CatalogDataset('mbi_education_9ff0e490')>,
#  <CatalogDataset('mbi_education_bb1e11d5')>,
#  <CatalogDataset('mbi_education_ea303241')>,
#  <CatalogDataset('mbi_purchasing__2b64f47')>,
#  <CatalogDataset('mbi_purchasing__afa42339')>,
#  <CatalogDataset('mbi_education_1b880265')>,
#  <CatalogDataset('mbi_education_c649c1a4')>,
#  <CatalogDataset('mbi_education_32248c13')>,
#  <CatalogDataset('mbi_consumer_sp_8c599d3c')>,
#  <CatalogDataset('mbi_retail_spen_74852ef5')>,
#  <CatalogDataset('mbi_purchasing__7a1dc666')>,
#  <CatalogDataset('mbi_purchasing__49aa311a')>,
#  <CatalogDataset('mbi_sociodemogr_bf4776ae')>,
#  <CatalogDataset('mbi_sociodemogr_48eabcd2')>,
#  <CatalogDataset('mbi_sociodemogr_a7b672ae')>,
#  <CatalogDataset('mbi_retail_spen_db24546b')>,
#  <CatalogDataset('mbi_purchasing__35515ec1')>,
#  <CatalogDataset('mbi_consumer_pr_8046648e')>,
#  <CatalogDataset('mbi_population_455945fd')>,
#  <CatalogDataset('mbi_purchasing__4d5fbd08')>,
#  <CatalogDataset('mbi_purchasing__72115dbe')>,
#  <CatalogDataset('mbi_purchasing__83037bfe')>,
#  <CatalogDataset('mbi_purchasing__a65ee8cb')>,
#  <CatalogDataset('mbi_households__4c36e6ce')>,
#  <CatalogDataset('mbi_marital_sta_1f4365c8')>,
#  <CatalogDataset('mbi_education_c7a8da7e')>,
#  <CatalogDataset('mbi_sociodemogr_baeafe91')>,
#  <CatalogDataset('mbi_sociodemogr_5bdd884a')>,
#  <CatalogDataset('mbi_sociodemogr_1c800e51')>,
#  <CatalogDataset('mbi_sociodemogr_34b172d4')>,
#  <CatalogDataset('mbi_sociodemogr_80fa578c')>,
#  <CatalogDataset('mbi_education_6dd7d678')>,
#  <CatalogDataset('mbi_education_37b7467a')>,
#  <CatalogDataset('mbi_consumer_sp_51d11f12')>,
#  <CatalogDataset('mbi_education_d15ecc92')>,
#  <CatalogDataset('mbi_education_911c1555')>,
#  <CatalogDataset('mbi_population_1a9f3725')>,
#  <CatalogDataset('mbi_consumer_sp_95c54caa')>,
#  <CatalogDataset('mbi_education_ecdf994c')>,
#  <CatalogDataset('mbi_education_73bda418')>,
#  <CatalogDataset('mbi_retail_turn_77b14ad6')>,
#  <CatalogDataset('mbi_consumer_pr_4292e0dc')>,
#  <CatalogDataset('mbi_population_c9da91f3')>,
#  <CatalogDataset('mbi_population_43643b60')>,
#  <CatalogDataset('mbi_population_aed19ab4')>,
#  <CatalogDataset('mbi_population_f074b6b8')>,
#  <CatalogDataset('mbi_population_6be8055b')>,
#  <CatalogDataset('mbi_population_e268978d')>,
#  <CatalogDataset('mbi_population_bd228fa6')>,
#  <CatalogDataset('mbi_education_21568154')>,
#  <CatalogDataset('mbi_population_53cb6ef3')>,
#  <CatalogDataset('mbi_population_10a5fd7')>,
#  <CatalogDataset('mbi_population_3d9c9b3d')>,
#  <CatalogDataset('mbi_population_e7dc93f5')>,
#  <CatalogDataset('mbi_education_aec62b5c')>,
#  <CatalogDataset('mbi_marital_sta_5369a832')>,
#  <CatalogDataset('mbi_marital_sta_957d69df')>,
#  <CatalogDataset('mbi_population_86a083fa')>,
#  <CatalogDataset('mbi_households__a9b97e1')>,
#  <CatalogDataset('mbi_education_773f92a5')>,
#  <CatalogDataset('mbi_purchasing__e78441d9')>,
#  <CatalogDataset('mbi_population_f95255c3')>,
#  <CatalogDataset('mbi_purchasing__bd9b0ad3')>,
#  <CatalogDataset('mbi_education_415eefcb')>,
#  <CatalogDataset('mbi_education_d71b708e')>,
#  <CatalogDataset('mbi_education_a0d89cb1')>,
#  <CatalogDataset('mbi_consumer_sp_c52095ec')>,
#  <CatalogDataset('mbi_consumer_sp_23abf591')>,
#  <CatalogDataset('mbi_consumer_sp_1d828b79')>,
#  <CatalogDataset('mbi_consumer_sp_bfd1ac4c')>,
#  <CatalogDataset('mbi_retail_spen_d8c4d322')>,
#  <CatalogDataset('mbi_education_846a2135')>,
#  <CatalogDataset('mbi_education_c5937c3f')>,
#  <CatalogDataset('mbi_education_db808f46')>,
#  <CatalogDataset('mbi_marital_sta_4911d8dc')>,
#  <CatalogDataset('mbi_retail_spen_c5a5cb0a')>,
#  <CatalogDataset('mbi_sociodemogr_e0353759')>,
#  <CatalogDataset('mbi_sociodemogr_ddf1aff3')>,
#  <CatalogDataset('mbi_sociodemogr_2488a49c')>,
#  <CatalogDataset('mbi_education_32999cea')>,
#  <CatalogDataset('mbi_sociodemogr_3f309ba')>,
#  <CatalogDataset('mbi_sociodemogr_5364ffc6')>,
#  <CatalogDataset('mbi_retail_spen_80789b98')>,
#  <CatalogDataset('mbi_consumer_sp_54c4abc3')>,
#  <CatalogDataset('mbi_households__541b50b5')>,
#  <CatalogDataset('mbi_consumer_pr_47d227cf')>,
#  <CatalogDataset('mbi_purchasing__9c98e51b')>,
#  <CatalogDataset('mbi_sociodemogr_5b5931bd')>,
#  <CatalogDataset('mbi_sociodemogr_151b070c')>,
#  <CatalogDataset('mbi_sociodemogr_e108978b')>,
#  <CatalogDataset('mbi_retail_spen_7450f97a')>,
#  <CatalogDataset('mbi_retail_turn_7654ee53')>,
#  <CatalogDataset('mbi_sociodemogr_4cff6123')>,
#  <CatalogDataset('mbi_sociodemogr_d5908982')>,
#  <CatalogDataset('mbi_sociodemogr_5461519b')>,
#  <CatalogDataset('mbi_education_189e2205')>,
#  <CatalogDataset('mbi_retail_spen_6f67f691')>,
#  <CatalogDataset('mbi_retail_spen_178c8c6d')>,
#  <CatalogDataset('mbi_sociodemogr_67dcce6a')>,
#  <CatalogDataset('mbi_sociodemogr_a99b8d3')>,
#  <CatalogDataset('mbi_sociodemogr_2f9e11bd')>,
#  <CatalogDataset('mbi_sociodemogr_e0eff8ec')>,
#  <CatalogDataset('mbi_sociodemogr_b9522069')>,
#  <CatalogDataset('mbi_consumer_pr_c43a7e92')>,
#  <CatalogDataset('mbi_sociodemogr_ab4e015c')>,
#  <CatalogDataset('mbi_sociodemogr_f2f31340')>,
#  <CatalogDataset('mbi_sociodemogr_ba82d942')>,
#  <CatalogDataset('mbi_sociodemogr_d54c1e7f')>,
#  <CatalogDataset('mbi_sociodemogr_ae7c4ad3')>,
#  <CatalogDataset('mbi_sociodemogr_1c1af215')>,
#  <CatalogDataset('mbi_sociodemogr_4c55184')>,
#  <CatalogDataset('mbi_sociodemogr_90fd9e3')>,
#  <CatalogDataset('mbi_marital_sta_c04e775')>,
#  <CatalogDataset('mbi_sociodemogr_6be48ed8')>,
#  <CatalogDataset('mbi_sociodemogr_3dec1fd7')>,
#  <CatalogDataset('mbi_retail_spen_51ee9377')>,
#  <CatalogDataset('mbi_purchasing__76f7182f')>,
#  <CatalogDataset('mbi_purchasing__eb570392')>,
#  <CatalogDataset('mbi_consumer_pr_2d885c89')>,
#  <CatalogDataset('mbi_sociodemogr_ba72e486')>,
#  <CatalogDataset('mbi_sociodemogr_a1f5b96a')>,
#  <CatalogDataset('mbi_sociodemogr_482cc906')>,
#  <CatalogDataset('mbi_sociodemogr_74ba0dec')>,
#  <CatalogDataset('mbi_purchasing__5bb7b3be')>,
#  <CatalogDataset('mbi_consumer_pr_71810128')>,
#  <CatalogDataset('mbi_consumer_sp_d617a174')>,
#  <CatalogDataset('mbi_consumer_sp_b275be11')>,
#  <CatalogDataset('mbi_households__4ba4a1b4')>,
#  <CatalogDataset('mbi_consumer_sp_d8105e3c')>,
#  <CatalogDataset('mbi_retail_spen_b6aaa6dc')>,
#  <CatalogDataset('mbi_households__90dd4218')>,
#  <CatalogDataset('mbi_consumer_pr_4216592b')>,
#  <CatalogDataset('mbi_consumer_sp_9097456')>,
#  <CatalogDataset('mbi_consumer_sp_68b9815b')>,
#  <CatalogDataset('mbi_consumer_sp_aaac9d89')>,
#  <CatalogDataset('mbi_consumer_sp_2f9e7020')>,
#  <CatalogDataset('mbi_retail_spen_a22412a5')>,
#  <CatalogDataset('mbi_retail_spen_e2e3601c')>,
#  <CatalogDataset('mbi_retail_spen_371e4f')>,
#  <CatalogDataset('mbi_retail_spen_9f4f7e48')>,
#  <CatalogDataset('mbi_consumer_sp_aff46bfd')>,
#  <CatalogDataset('mbi_education_64db9744')>,
#  <CatalogDataset('mbi_education_ca53d0c9')>,
#  <CatalogDataset('mbi_consumer_sp_fae394ee')>,
#  <CatalogDataset('mbi_consumer_sp_d0af3e77')>,
#  <CatalogDataset('mbi_consumer_sp_1509de7d')>,
#  <CatalogDataset('mbi_households__5d5b1ed6')>,
#  <CatalogDataset('mbi_consumer_sp_bfd34dd7')>,
#  <CatalogDataset('mbi_consumer_sp_90236f6e')>,
#  <CatalogDataset('mbi_consumer_sp_f460f004')>,
#  <CatalogDataset('mbi_consumer_sp_c5a42c1b')>,
#  <CatalogDataset('mbi_consumer_sp_4ecb60c9')>,
#  <CatalogDataset('mbi_consumer_sp_cde9549c')>,
#  <CatalogDataset('mbi_consumer_sp_d0809991')>,
#  <CatalogDataset('mbi_consumer_sp_5fe0bb64')>,
#  <CatalogDataset('mbi_consumer_sp_ce830d51')>,
#  <CatalogDataset('mbi_consumer_sp_c7df2517')>,
#  <CatalogDataset('mbi_consumer_sp_ce0bd24c')>,
#  <CatalogDataset('mbi_consumer_sp_7bb411a7')>,
#  <CatalogDataset('mbi_consumer_sp_9f9eb8cf')>,
#  <CatalogDataset('mbi_consumer_sp_233ee921')>,
#  <CatalogDataset('mbi_consumer_sp_c937fcca')>,
#  <CatalogDataset('mbi_consumer_sp_5e11b3e4')>,
#  <CatalogDataset('mbi_consumer_sp_a8c1aec5')>,
#  <CatalogDataset('mbi_consumer_sp_1d71955d')>,
#  <CatalogDataset('mbi_consumer_pr_786039ed')>,
#  <CatalogDataset('mbi_consumer_sp_1c991bfb')>,
#  <CatalogDataset('mbi_consumer_sp_a9293242')>,
#  <CatalogDataset('mbi_households__f90930aa')>,
#  <CatalogDataset('mbi_households__8af896e3')>,
#  <CatalogDataset('mbi_households__56a61919')>,
#  <CatalogDataset('mbi_households__b2153c15')>,
#  <CatalogDataset('mbi_retail_spen_e66b9090')>,
#  <CatalogDataset('mbi_households__9e2c7244')>,
#  <CatalogDataset('mbi_households__6058cba3')>,
#  <CatalogDataset('mbi_households__bf3e0a4')>,
#  <CatalogDataset('mbi_households__7bfb8a4f')>,
#  <CatalogDataset('mbi_households__d0b84ddd')>,
#  <CatalogDataset('mbi_households__e7146470')>,
#  <CatalogDataset('mbi_households__da53f787')>,
#  <CatalogDataset('mbi_retail_spen_fa06f554')>,
#  <CatalogDataset('mbi_households__c510e2cc')>,
#  <CatalogDataset('mbi_households__91883048')>,
#  <CatalogDataset('mbi_households__dd3cdfa0')>,
#  <CatalogDataset('mbi_households__cad2ff8d')>,
#  <CatalogDataset('mbi_education_38ed8470')>,
#  <CatalogDataset('mbi_households__1afde171')>,
#  <CatalogDataset('mbi_households__52c47fac')>,
#  <CatalogDataset('mbi_households__4458cdcf')>,
#  <CatalogDataset('mbi_households__7c08c60c')>,
#  <CatalogDataset('mbi_households__68d4d6b1')>,
#  <CatalogDataset('mbi_consumer_pr_262c944e')>,
#  <CatalogDataset('mbi_retail_spen_709f5d')>,
#  <CatalogDataset('mbi_households__cd0c3ffa')>,
#  <CatalogDataset('mbi_households__9b6cb6e8')>,
#  <CatalogDataset('mbi_households__15ae55dc')>,
#  <CatalogDataset('mbi_households__83bb8b60')>,
#  <CatalogDataset('mbi_households__b523df4d')>,
#  <CatalogDataset('mbi_households__9ae0a9c1')>,
#  <CatalogDataset('mbi_households__3466a5b7')>,
#  <CatalogDataset('mbi_households__997e9144')>,
#  <CatalogDataset('mbi_households__dfc9029b')>,
#  <CatalogDataset('mbi_households__8a4ffc52')>,
#  <CatalogDataset('mbi_households__5c453314')>,
#  <CatalogDataset('mbi_households__d5c29eea')>,
#  <CatalogDataset('mbi_households__9c948cd1')>,
#  <CatalogDataset('mbi_households__66e99138')>,
#  <CatalogDataset('mbi_households__f6573901')>,
#  <CatalogDataset('mbi_households__2b96fac0')>,
#  <CatalogDataset('mbi_households__fb6792ca')>,
#  <CatalogDataset('mbi_households__fdd5fe53')>,
#  <CatalogDataset('mbi_households__3a2cc928')>,
#  <CatalogDataset('mbi_households__ec5a08b7')>,
#  <CatalogDataset('mbi_households__8e06a7f3')>,
#  <CatalogDataset('mbi_households__b11a7344')>,
#  <CatalogDataset('mbi_households__c88593a3')>,
#  <CatalogDataset('mbi_education_fafff1e')>,
#  <CatalogDataset('mbi_households__764c6196')>,
#  <CatalogDataset('mbi_retail_turn_42ff98b9')>,
#  <CatalogDataset('mbi_consumer_sp_58f735aa')>,
#  <CatalogDataset('mbi_households__69695999')>,
#  <CatalogDataset('mbi_households__372b910a')>,
#  <CatalogDataset('mbi_sociodemogr_5d30c6d9')>,
#  <CatalogDataset('mbi_households__f78d0c4c')>,
#  <CatalogDataset('mbi_households__a4f03ceb')>,
#  <CatalogDataset('mbi_marital_sta_290f87e6')>,
#  <CatalogDataset('mbi_households__cd156e0e')>,
#  <CatalogDataset('mbi_households__bf75c797')>,
#  <CatalogDataset('mbi_retail_cent_c00d1dfc')>,
#  <CatalogDataset('mbi_households__eaa86152')>,
#  <CatalogDataset('mbi_marital_sta_5e11da68')>,
#  <CatalogDataset('mbi_households__4478d9e')>,
#  <CatalogDataset('mbi_households__5da15f26')>,
#  <CatalogDataset('mbi_marital_sta_e945e70c')>,
#  <CatalogDataset('mbi_households__4818f2c8')>,
#  <CatalogDataset('mbi_households__7ccd4ea0')>,
#  <CatalogDataset('mbi_population_4c9ea8ad')>,
#  <CatalogDataset('mbi_households__452920ed')>,
#  <CatalogDataset('mbi_households__a9aa3313')>,
#  <CatalogDataset('mbi_households__b6ee8fb2')>,
#  <CatalogDataset('mbi_retail_cent_91a8fe18')>,
#  <CatalogDataset('mbi_retail_spen_9a2c77fc')>,
#  <CatalogDataset('mbi_retail_spen_286538c8')>,
#  <CatalogDataset('mbi_retail_spen_64a04118')>,
#  <CatalogDataset('mbi_retail_spen_cf4e7150')>,
#  <CatalogDataset('mbi_retail_cent_7684f9c0')>,
#  <CatalogDataset('mbi_retail_spen_86f1a870')>,
#  <CatalogDataset('mbi_retail_spen_eb0258d9')>,
#  <CatalogDataset('mbi_retail_spen_386e24b4')>,
#  <CatalogDataset('mbi_retail_spen_9338c9c')>,
#  <CatalogDataset('mbi_retail_spen_d89500da')>,
#  <CatalogDataset('mbi_retail_spen_ec0cd59d')>,
#  <CatalogDataset('mbi_retail_spen_eda1cda6')>,
#  <CatalogDataset('mbi_retail_spen_70768c40')>,
#  <CatalogDataset('mbi_population_e1529805')>,
#  <CatalogDataset('mbi_retail_spen_ad9d00ac')>,
#  <CatalogDataset('mbi_retail_spen_96e753c4')>,
#  <CatalogDataset('mbi_retail_cent_b123832')>,
#  <CatalogDataset('mbi_retail_cent_418c2702')>,
#  <CatalogDataset('mbi_retail_cent_b1884e39')>,
#  <CatalogDataset('mbi_retail_cent_104b0974')>,
#  <CatalogDataset('mbi_retail_cent_99309ad9')>,
#  <CatalogDataset('mbi_retail_turn_19d5f465')>,
#  <CatalogDataset('mbi_retail_turn_25703f0e')>,
#  <CatalogDataset('mbi_retail_turn_b9b65fe2')>,
#  <CatalogDataset('mbi_retail_turn_95e0a3be')>,
#  <CatalogDataset('mbi_retail_turn_147e3217')>,
#  <CatalogDataset('mbi_education_87bcae55')>,
#  <CatalogDataset('mbi_retail_turn_7c76fd5f')>,
#  <CatalogDataset('mbi_retail_turn_cb840b14')>,
#  <CatalogDataset('mbi_retail_turn_f1f26bd2')>,
#  <CatalogDataset('mbi_retail_turn_4ba5304f')>,
#  <CatalogDataset('mbi_purchasing__56d4d9b2')>,
#  <CatalogDataset('mbi_education_952fa1b')>,
#  <CatalogDataset('mbi_retail_turn_4da82cad')>,
#  <CatalogDataset('mbi_retail_turn_f033cfff')>,
#  <CatalogDataset('mbi_retail_turn_f8135317')>,
#  <CatalogDataset('mbi_purchasing__c2d48fc1')>,
#  <CatalogDataset('mbi_purchasing__bc2a0709')>,
#  <CatalogDataset('mbi_purchasing__f1ebc21c')>,
#  <CatalogDataset('mbi_purchasing__6dcbc2c6')>,
#  <CatalogDataset('mbi_purchasing__f81944c')>,
#  <CatalogDataset('mbi_purchasing__84a62bd4')>,
#  <CatalogDataset('mbi_purchasing__e3d4a3da')>,
#  <CatalogDataset('mbi_purchasing__5a80cc29')>,
#  <CatalogDataset('mbi_purchasing__c2527bf0')>,
#  <CatalogDataset('mbi_purchasing__46112d4d')>,
#  <CatalogDataset('mbi_education_afcbc85a')>,
#  <CatalogDataset('mbi_purchasing__dcc70505')>,
#  <CatalogDataset('mbi_purchasing__692787d4')>,
#  <CatalogDataset('mbi_purchasing__494e4978')>,
#  <CatalogDataset('mbi_purchasing__b413352')>,
#  <CatalogDataset('mbi_purchasing__41dadaba')>,
#  <CatalogDataset('mbi_purchasing__6fd2bc1')>,
#  <CatalogDataset('mbi_purchasing__b54d32ba')>,
#  <CatalogDataset('mbi_purchasing__d3134b00')>,
#  <CatalogDataset('mbi_purchasing__87a3e23c')>,
#  <CatalogDataset('mbi_purchasing__ee45ca6b')>,
#  <CatalogDataset('mbi_purchasing__b99055d2')>,
#  <CatalogDataset('mbi_purchasing__b15d896e')>,
#  <CatalogDataset('mbi_households__f3093d63')>,
#  <CatalogDataset('mbi_sociodemogr_ab2db058')>,
#  <CatalogDataset('mbi_purchasing__edbb1709')>,
#  <CatalogDataset('mbi_purchasing__15d2f1c3')>,
#  <CatalogDataset('mbi_marital_sta_b620160')>,
#  <CatalogDataset('mbi_education_9f17d26c')>,
#  <CatalogDataset('mbi_purchasing__4f1c1ca8')>,
#  <CatalogDataset('mbi_purchasing__c22d6fc8')>,
#  <CatalogDataset('mbi_purchasing__bc3ac75d')>,
#  <CatalogDataset('mbi_sociodemogr_dc2b5374')>,
#  <CatalogDataset('mbi_purchasing__9a05a28f')>,
#  <CatalogDataset('mbi_purchasing__ab8ea8c5')>,
#  <CatalogDataset('mbi_purchasing__9e816ee3')>,
#  <CatalogDataset('mbi_marital_sta_3cab91b6')>,
#  <CatalogDataset('mbi_purchasing__69bdc2d6')>,
#  <CatalogDataset('mbi_purchasing__4c8327cd')>,
#  <CatalogDataset('mbi_purchasing__6cf8fb63')>,
#  <CatalogDataset('mbi_purchasing__c1098dee')>,
#  <CatalogDataset('mbi_purchasing__7a42824')>,
#  <CatalogDataset('mbi_purchasing__5da8fc60')>,
#  <CatalogDataset('mbi_purchasing__1618bf73')>,
#  <CatalogDataset('mbi_purchasing__8f54483e')>,
#  <CatalogDataset('mbi_purchasing__191dbb94')>,
#  <CatalogDataset('mbi_marital_sta_2ac874b8')>,
#  <CatalogDataset('mbi_purchasing__436dd28')>,
#  <CatalogDataset('mbi_purchasing__c6b7d189')>,
#  <CatalogDataset('mbi_purchasing__4b0b3668')>,
#  <CatalogDataset('mbi_purchasing__10664dd0')>,
#  <CatalogDataset('mbi_purchasing__e99cab1e')>,
#  <CatalogDataset('mbi_purchasing__79fc56a3')>,
#  <CatalogDataset('mbi_purchasing__118e7a9')>,
#  <CatalogDataset('mbi_purchasing__b1b1f45f')>,
#  <CatalogDataset('mbi_purchasing__d7d26d54')>,
#  <CatalogDataset('mbi_consumer_sp_568ddd76')>,
#  <CatalogDataset('mbi_purchasing__f06d606b')>,
#  <CatalogDataset('mbi_purchasing__a53ac6dd')>,
#  <CatalogDataset('mbi_retail_turn_5e4029c')>,
#  <CatalogDataset('mbi_purchasing__9dd6ffcb')>,
#  <CatalogDataset('mbi_purchasing__72582dad')>,
#  <CatalogDataset('mbi_education_8a54f3a9')>,
#  <CatalogDataset('mbi_purchasing__2713ead4')>,
#  <CatalogDataset('mbi_purchasing__71c1e4f2')>,
#  <CatalogDataset('mbi_sociodemogr_c870c0d0')>,
#  <CatalogDataset('mbi_purchasing__ef590dd8')>,
#  <CatalogDataset('mbi_purchasing__31ba71ef')>,
#  <CatalogDataset('mbi_purchasing__45234952')>,
#  <CatalogDataset('mbi_purchasing__aa89e9c1')>,
#  <CatalogDataset('mbi_purchasing__a7e3ec24')>,
#  <CatalogDataset('mbi_purchasing__8ffe918')>,
#  <CatalogDataset('mbi_purchasing__ba71e577')>,
#  <CatalogDataset('mbi_consumer_sp_c3cddb7f')>,
#  <CatalogDataset('mbi_purchasing__cbbdaa4e')>,
#  <CatalogDataset('mbi_purchasing__6ec77948')>,
#  <CatalogDataset('mbi_marital_sta_a53c866b')>,
#  <CatalogDataset('mbi_consumer_pr_8e977645')>,
#  <CatalogDataset('mbi_purchasing__efdf83ab')>,
#  <CatalogDataset('mbi_marital_sta_72936267')>,
#  <CatalogDataset('mbi_marital_sta_cd96234e')>,
#  <CatalogDataset('mbi_marital_sta_86173bc2')>,
#  <CatalogDataset('mbi_marital_sta_8d6b4b69')>,
#  <CatalogDataset('mbi_marital_sta_b0e51c15')>,
#  <CatalogDataset('mbi_marital_sta_ef37e42d')>,
#  <CatalogDataset('mbi_marital_sta_df42763c')>,
#  <CatalogDataset('mbi_marital_sta_5a3b5324')>,
#  <CatalogDataset('mbi_marital_sta_ab5332b8')>,
#  <CatalogDataset('mbi_purchasing__ed51bec4')>,
#  <CatalogDataset('mbi_marital_sta_a9b4d07d')>,
#  <CatalogDataset('mbi_marital_sta_2f717ef')>,
#  <CatalogDataset('mbi_marital_sta_8a432e59')>,
#  <CatalogDataset('mbi_marital_sta_81cadb5')>,
#  <CatalogDataset('mbi_marital_sta_6c05206a')>,
#  <CatalogDataset('mbi_marital_sta_f133e825')>,
#  <CatalogDataset('mbi_marital_sta_8639709')>,
#  <CatalogDataset('mbi_marital_sta_bb8c5ab0')>,
#  <CatalogDataset('mbi_marital_sta_1050e8bb')>,
#  <CatalogDataset('mbi_marital_sta_ac1cc159')>,
#  <CatalogDataset('mbi_marital_sta_911938ca')>,
#  <CatalogDataset('mbi_marital_sta_1ac6f8d8')>,
#  <CatalogDataset('mbi_marital_sta_30b01f5c')>,
#  <CatalogDataset('mbi_marital_sta_1d8a0fd6')>,
#  <CatalogDataset('mbi_marital_sta_be315c8c')>,
#  <CatalogDataset('mbi_marital_sta_23c9d170')>,
#  <CatalogDataset('mbi_marital_sta_d1836976')>,
#  <CatalogDataset('mbi_marital_sta_48aff3f3')>,
#  <CatalogDataset('mbi_marital_sta_c5e573a')>,
#  <CatalogDataset('mbi_marital_sta_fc63bb6d')>,
#  <CatalogDataset('mbi_marital_sta_12bbd79c')>,
#  <CatalogDataset('mbi_marital_sta_dea1a4a8')>,
#  <CatalogDataset('mbi_marital_sta_9979bf8e')>,
#  <CatalogDataset('mbi_marital_sta_6023cdc8')>,
#  <CatalogDataset('mbi_marital_sta_88b11a6f')>,
#  <CatalogDataset('mbi_marital_sta_9aa946a5')>,
#  <CatalogDataset('mbi_marital_sta_285b9702')>,
#  <CatalogDataset('mbi_marital_sta_91564a0a')>,
#  <CatalogDataset('mbi_marital_sta_46e91895')>,
#  <CatalogDataset('mbi_marital_sta_5800a660')>,
#  <CatalogDataset('mbi_marital_sta_2f4ef97c')>,
#  <CatalogDataset('mbi_marital_sta_2172caf8')>,
#  <CatalogDataset('mbi_marital_sta_24186333')>,
#  <CatalogDataset('mbi_marital_sta_4a4cfd2a')>,
#  <CatalogDataset('mbi_marital_sta_f9d9a0f2')>,
#  <CatalogDataset('mbi_marital_sta_d63798ed')>,
#  <CatalogDataset('mbi_marital_sta_dd41bca')>,
#  <CatalogDataset('mbi_marital_sta_7b4bb9f7')>,
#  <CatalogDataset('mbi_marital_sta_ca516305')>,
#  <CatalogDataset('mbi_purchasing__7811b8cd')>,
#  <CatalogDataset('mbi_marital_sta_9b681890')>,
#  <CatalogDataset('mbi_marital_sta_4a904a9d')>,
#  <CatalogDataset('mbi_marital_sta_bf0a3175')>,
#  <CatalogDataset('mbi_consumer_pr_c7efa2d3')>,
#  <CatalogDataset('mbi_consumer_pr_9047a65a')>,
#  <CatalogDataset('mbi_consumer_pr_d0bace7d')>,
#  <CatalogDataset('mbi_consumer_pr_b2e66139')>,
#  <CatalogDataset('mbi_households__e8a831c')>,
#  <CatalogDataset('mbi_consumer_pr_5f2692fb')>,
#  <CatalogDataset('mbi_consumer_pr_fe2318e9')>,
#  <CatalogDataset('mbi_consumer_pr_a0452346')>,
#  <CatalogDataset('mbi_population_93cdf7c')>,
#  <CatalogDataset('mbi_consumer_pr_77229457')>,
#  <CatalogDataset('mbi_consumer_pr_2fbd23aa')>,
#  <CatalogDataset('mbi_population_b2c4ea47')>,
#  <CatalogDataset('mbi_population_49e4d85e')>,
#  <CatalogDataset('mbi_education_ef892935')>,
#  <CatalogDataset('mbi_population_17749443')>,
#  <CatalogDataset('mbi_retail_cent_69c0a2cb')>,
#  <CatalogDataset('mbi_retail_cent_c7543273')>,
#  <CatalogDataset('mbi_population_c65debdd')>,
#  <CatalogDataset('mbi_population_4bdfae58')>,
#  <CatalogDataset('mbi_population_25836b29')>,
#  <CatalogDataset('mbi_population_630f291d')>,
#  <CatalogDataset('mbi_population_2bf0810f')>,
#  <CatalogDataset('mbi_education_3b9bdc1')>,
#  <CatalogDataset('mbi_retail_cent_4b6165a8')>,
#  <CatalogDataset('mbi_population_ad17f037')>,
#  <CatalogDataset('mbi_purchasing__8d6cb5f2')>,
#  <CatalogDataset('mbi_consumer_sp_5cae5da5')>,
#  <CatalogDataset('mbi_purchasing__657af1e')>,
#  <CatalogDataset('mbi_purchasing__706b45d0')>,
#  <CatalogDataset('mbi_purchasing__196cae87')>,
#  <CatalogDataset('mbi_purchasing__2994d992')>,
#  <CatalogDataset('mbi_purchasing__3409649d')>,
#  <CatalogDataset('mbi_purchasing__7d233b69')>,
#  <CatalogDataset('mbi_population_b129c20d')>,
#  <CatalogDataset('mbi_population_2af284e6')>,
#  <CatalogDataset('mbi_population_a27f18ee')>,
#  <CatalogDataset('mbi_population_ffc6d96')>,
#  <CatalogDataset('mbi_population_3d76526')>,
#  <CatalogDataset('mbi_population_faf820b6')>,
#  <CatalogDataset('mbi_population_a41f5345')>,
#  <CatalogDataset('mbi_population_e090a867')>,
#  <CatalogDataset('mbi_population_8772c540')>,
#  <CatalogDataset('mbi_population_5cd1ad50')>,
#  <CatalogDataset('mbi_marital_sta_9ac16176')>,
#  <CatalogDataset('mbi_population_ca76d571')>,
#  <CatalogDataset('mbi_population_a3fee2e7')>,
#  <CatalogDataset('mbi_population_d850bbf3')>,
#  <CatalogDataset('mbi_population_1bf65c2b')>,
#  <CatalogDataset('mbi_population_d3d648b2')>,
#  <CatalogDataset('mbi_retail_cent_2505db1b')>,
#  <CatalogDataset('mbi_purchasing__1acde529')>,
#  <CatalogDataset('mbi_marital_sta_c79c30bb')>,
#  <CatalogDataset('mbi_purchasing__b9b69254')>,
#  <CatalogDataset('mbi_population_291f2076')>,
#  <CatalogDataset('mbi_population_f6f3b0df')>,
#  <CatalogDataset('mbi_population_f3cc6840')>,
#  <CatalogDataset('mbi_population_3325b907')>,
#  <CatalogDataset('mbi_population_e6763708')>,
#  <CatalogDataset('mbi_population_ecb61db8')>,
#  <CatalogDataset('mbi_education_c6de2887')>,
#  <CatalogDataset('mbi_population_2138d9d0')>,
#  <CatalogDataset('mbi_population_3adfc677')>,
#  <CatalogDataset('mbi_population_7819f561')>,
#  <CatalogDataset('mbi_population_ef662328')>,
#  <CatalogDataset('mbi_population_2f72a488')>,
#  <CatalogDataset('mbi_marital_sta_b58022da')>,
#  <CatalogDataset('mbi_population_5a0fe538')>,
#  <CatalogDataset('mbi_population_70d82a6a')>,
#  <CatalogDataset('mbi_population_352696fb')>,
#  <CatalogDataset('mbi_population_1a9ba722')>,
#  <CatalogDataset('mbi_population_bbf5f69d')>,
#  <CatalogDataset('mbi_population_a8a29902')>,
#  <CatalogDataset('mbi_population_5b9568b')>,
#  <CatalogDataset('mbi_population_279b4caf')>,
#  <CatalogDataset('mbi_population_7340a78d')>,
#  <CatalogDataset('mbi_marital_sta_d4d56ac0')>,
#  <CatalogDataset('mbi_population_e4c7127c')>,
#  <CatalogDataset('mbi_population_82ef6fd9')>,
#  <CatalogDataset('mbi_population_c5aa98ea')>,
#  <CatalogDataset('mbi_population_d5156048')>,
#  <CatalogDataset('mbi_population_7552b3a1')>,
#  <CatalogDataset('mbi_population_6ebd06d3')>,
#  <CatalogDataset('mbi_population_140c14ac')>,
#  <CatalogDataset('mbi_marital_sta_42fd8839')>,
#  <CatalogDataset('mbi_population_2e7a746a')>,
#  <CatalogDataset('mbi_population_55a69880')>,
#  <CatalogDataset('mbi_population_1fbd38ad')>,
#  <CatalogDataset('mbi_population_c9dcc15d')>,
#  <CatalogDataset('mbi_population_d9dbd19')>,
#  <CatalogDataset('mbi_households__a70ed971')>,
#  <CatalogDataset('mbi_retail_cent_77c4aec3')>,
#  <CatalogDataset('mbi_consumer_pr_f21e5fd5')>,
#  <CatalogDataset('mbi_population_ccae0a39')>,
#  <CatalogDataset('mbi_retail_cent_457f1ac5')>,
#  <CatalogDataset('mbi_purchasing__f463c70f')>,
#  <CatalogDataset('mbi_population_a43bdcbb')>,
#  <CatalogDataset('mbi_population_52176b42')>,
#  <CatalogDataset('mbi_population_f4718c11')>,
#  <CatalogDataset('mbi_population_1b75b3af')>,
#  <CatalogDataset('mbi_population_e757018d')>,
#  <CatalogDataset('mbi_population_79c4a13f')>,
#  <CatalogDataset('mbi_population_4b232af5')>,
#  <CatalogDataset('mbi_population_6ca74dec')>,
#  <CatalogDataset('mbi_population_4ac4d846')>,
#  <CatalogDataset('mbi_population_20f4dfe2')>,
#  <CatalogDataset('mbi_population_6f535a47')>,
#  <CatalogDataset('mbi_population_f2126861')>,
#  <CatalogDataset('mbi_retail_turn_3957f48')>,
#  <CatalogDataset('mbi_retail_cent_2ec26c92')>,
#  <CatalogDataset('mbi_population_2efa58bb')>,
#  <CatalogDataset('mbi_population_11723c38')>,
#  <CatalogDataset('mbi_education_1eebb188')>,
#  <CatalogDataset('mbi_population_e1bc1359')>,
#  <CatalogDataset('mbi_population_f3a44f93')>,
#  <CatalogDataset('mbi_population_f5589550')>,
#  <CatalogDataset('mbi_education_5400fc4d')>,
#  <CatalogDataset('mbi_retail_turn_3b743306')>,
#  <CatalogDataset('mbi_retail_turn_f2aadea8')>,
#  <CatalogDataset('mbi_population_d1cbef14')>,
#  <CatalogDataset('mbi_population_3a7e99f')>,
#  <CatalogDataset('mbi_purchasing__2a6b58c4')>,
#  <CatalogDataset('mbi_population_4efa9a7f')>,
#  <CatalogDataset('mbi_retail_cent_a346fa1f')>,
#  <CatalogDataset('mbi_retail_cent_ec7cf552')>,
#  <CatalogDataset('mbi_purchasing__ab03a531')>,
#  <CatalogDataset('mbi_purchasing__b265708b')>,
#  <CatalogDataset('mbi_purchasing__13f02ce0')>,
#  <CatalogDataset('mbi_purchasing__fdeea5f1')>,
#  <CatalogDataset('mbi_purchasing__a3add56a')>,
#  <CatalogDataset('mbi_purchasing__a07d2c41')>,
#  <CatalogDataset('mbi_purchasing__ca177752')>,
#  <CatalogDataset('mbi_purchasing__159a9398')>,
#  <CatalogDataset('mbi_purchasing__d49f7ec5')>,
#  <CatalogDataset('mbi_purchasing__98e28a93')>,
#  <CatalogDataset('mbi_purchasing__ec3e3d8d')>,
#  <CatalogDataset('mbi_education_3d8a414a')>,
#  <CatalogDataset('mbi_sociodemogr_7ee37233')>,
#  <CatalogDataset('mbi_sociodemogr_2cdeb5fb')>,
#  <CatalogDataset('mbi_education_ad799ddc')>,
#  <CatalogDataset('mbi_education_9a6dbad3')>,
#  <CatalogDataset('mbi_purchasing__fe45fd7e')>,
#  <CatalogDataset('mbi_purchasing__4365e98e')>,
#  <CatalogDataset('mbi_sociodemogr_912e37f6')>,
#  <CatalogDataset('mbi_sociodemogr_2073d4a2')>,
#  <CatalogDataset('mbi_retail_turn_c31c6fd5')>,
#  <CatalogDataset('mbi_sociodemogr_c8a359a6')>,
#  <CatalogDataset('mbi_sociodemogr_df1232aa')>,
#  <CatalogDataset('mbi_sociodemogr_33e67434')>,
#  <CatalogDataset('mbi_sociodemogr_d0cc3e11')>,
#  <CatalogDataset('mbi_sociodemogr_11c28cc3')>,
#  <CatalogDataset('mbi_sociodemogr_d6a755ae')>,
#  <CatalogDataset('mbi_sociodemogr_b9222c39')>,
#  <CatalogDataset('mbi_purchasing__9ffcbef')>,
#  <CatalogDataset('mbi_purchasing__e1edcb5a')>,
#  <CatalogDataset('mbi_purchasing__82d6f267')>,
#  <CatalogDataset('mbi_purchasing__53ab279d')>,
#  <CatalogDataset('mbi_marital_sta_a6132310')>,
#  <CatalogDataset('mbi_purchasing__ed8227b2')>,
#  <CatalogDataset('mbi_sociodemogr_92529d1d')>,
#  <CatalogDataset('mbi_sociodemogr_e9ed3c58')>,
#  <CatalogDataset('mbi_consumer_sp_2bd4a1f6')>,
#  <CatalogDataset('mbi_sociodemogr_f2d3604c')>,
#  <CatalogDataset('mbi_sociodemogr_d2a61be7')>,
#  <CatalogDataset('mbi_sociodemogr_8bd99ff')>,
#  <CatalogDataset('mbi_purchasing__82128cc6')>,
#  <CatalogDataset('mbi_sociodemogr_aecacd23')>,
#  <CatalogDataset('mbi_purchasing__b9a967eb')>,
#  <CatalogDataset('mbi_sociodemogr_a0e97ed9')>,
#  <CatalogDataset('mbi_purchasing__13bb4b3b')>,
#  ...]

# %%
isinstance(category1, Category)
# Out:
# True

# %% [markdown]
# And we can access its different properties:

# %%
category1.name
# Out:
# 'Demographics'

# %% [markdown]
# ### Get the datasets for that category
#
# Once we have a Category we can use the discovery methods to get the datasets related to that category.

# %%
demographics_datasets = category1.datasets
demographics_datasets
# Out:
# [<CatalogDataset('od_acs_181619a3')>,
#  <CatalogDataset('od_acs_550657ce')>,
#  <CatalogDataset('mbi_retail_turn_a40b2d9e')>,
#  <CatalogDataset('od_acs_6e4b69f6')>,
#  <CatalogDataset('mbi_purchasing__ff4ce909')>,
#  <CatalogDataset('mbi_population_73b2034')>,
#  <CatalogDataset('mbi_population_bf3a91db')>,
#  <CatalogDataset('od_acs_9510981d')>,
#  <CatalogDataset('od_acs_6d43ed82')>,
#  <CatalogDataset('od_acs_194c5960')>,
#  <CatalogDataset('mbi_population_552f1d19')>,
#  <CatalogDataset('mbi_population_70c11317')>,
#  <CatalogDataset('mbi_population_c207835a')>,
#  <CatalogDataset('mbi_population_8b8bf92b')>,
#  <CatalogDataset('mbi_education_3d6776b9')>,
#  <CatalogDataset('mbi_retail_turn_36a9dbe1')>,
#  <CatalogDataset('mbi_population_af1d83ba')>,
#  <CatalogDataset('mbi_retail_cent_ac0457a5')>,
#  <CatalogDataset('mbi_purchasing__c9645e12')>,
#  <CatalogDataset('od_acs_38016c42')>,
#  <CatalogDataset('od_acs_9a9c93b8')>,
#  <CatalogDataset('od_acs_7b2649a9')>,
#  <CatalogDataset('od_acs_478c37b8')>,
#  <CatalogDataset('od_acs_f98ddfce')>,
#  <CatalogDataset('od_acs_1f614ee8')>,
#  <CatalogDataset('mbi_sociodemogr_1469299e')>,
#  <CatalogDataset('mbi_retail_spen_c749c2ee')>,
#  <CatalogDataset('od_acs_8b00f653')>,
#  <CatalogDataset('od_acs_d52a0635')>,
#  <CatalogDataset('od_acs_1deaa51')>,
#  <CatalogDataset('od_acs_e0f5ff55')>,
#  <CatalogDataset('od_acs_52710085')>,
#  <CatalogDataset('od_acs_b3eac6e8')>,
#  <CatalogDataset('mbi_households__6e377f70')>,
#  <CatalogDataset('od_acs_1a09274c')>,
#  <CatalogDataset('mbi_retail_spen_74ef7398')>,
#  <CatalogDataset('mbi_retail_spen_bdbc88f4')>,
#  <CatalogDataset('mbi_retail_spen_9d8d164c')>,
#  <CatalogDataset('mbi_households__400e1f2')>,
#  <CatalogDataset('mbi_sociodemogr_241fcfe')>,
#  <CatalogDataset('mbi_consumer_sp_804ae09f')>,
#  <CatalogDataset('mbi_sociodemogr_59f19c8f')>,
#  <CatalogDataset('mbi_households__bc93fe13')>,
#  <CatalogDataset('ags_sociodemogr_e92b1637')>,
#  <CatalogDataset('mbi_sociodemogr_7e5d7713')>,
#  <CatalogDataset('ags_consumerspe_fe5d060a')>,
#  <CatalogDataset('od_acs_e8a7d88d')>,
#  <CatalogDataset('mbi_sociodemogr_aaac5fe9')>,
#  <CatalogDataset('mbi_purchasing__3be4e0c8')>,
#  <CatalogDataset('od_acs_60614ff2')>,
#  <CatalogDataset('od_acs_f09b24f4')>,
#  <CatalogDataset('od_acs_1cfa643a')>,
#  <CatalogDataset('od_acs_c4a00c26')>,
#  <CatalogDataset('od_acs_c1c86582')>,
#  <CatalogDataset('od_acs_5b8fdefd')>,
#  <CatalogDataset('mbi_sociodemogr_8a7b040c')>,
#  <CatalogDataset('mbi_sociodemogr_edae8408')>,
#  <CatalogDataset('mbi_sociodemogr_61abe88c')>,
#  <CatalogDataset('mbi_sociodemogr_63544b8')>,
#  <CatalogDataset('mbi_consumer_sp_98c8591e')>,
#  <CatalogDataset('u360_demographic_94266d3')>,
#  <CatalogDataset('od_spielmansin_5d03106a')>,
#  <CatalogDataset('mbi_education_fcd214dd')>,
#  <CatalogDataset('mbi_households__109a963')>,
#  <CatalogDataset('mbi_sociodemogr_a260b8a8')>,
#  <CatalogDataset('mbi_education_b38f515')>,
#  <CatalogDataset('mbi_sociodemogr_e7e8c988')>,
#  <CatalogDataset('od_acs_c2868f47')>,
#  <CatalogDataset('od_acs_b581bfd1')>,
#  <CatalogDataset('mbi_sociodemogr_93d4a324')>,
#  <CatalogDataset('mbi_purchasing__23143aac')>,
#  <CatalogDataset('od_acs_2d438a42')>,
#  <CatalogDataset('od_acs_c6bf32c9')>,
#  <CatalogDataset('od_acs_91ff81e3')>,
#  <CatalogDataset('mbi_purchasing__2f0c36fb')>,
#  <CatalogDataset('od_acs_13345497')>,
#  <CatalogDataset('od_acs_87fa66db')>,
#  <CatalogDataset('mbi_population_fbcd3b85')>,
#  <CatalogDataset('mbi_sociodemogr_4066dd40')>,
#  <CatalogDataset('mbi_consumer_sp_fba12e82')>,
#  <CatalogDataset('od_acs_b98db80e')>,
#  <CatalogDataset('od_acs_9f4d1f13')>,
#  <CatalogDataset('od_acs_5b67fbbf')>,
#  <CatalogDataset('od_acs_29664073')>,
#  <CatalogDataset('mbi_population_deffab10')>,
#  <CatalogDataset('mbi_population_685846c7')>,
#  <CatalogDataset('mbi_consumer_sp_aa8046fd')>,
#  <CatalogDataset('od_acs_4bb9b377')>,
#  <CatalogDataset('od_acs_aa92e673')>,
#  <CatalogDataset('od_acs_1db77442')>,
#  <CatalogDataset('od_acs_9df157a1')>,
#  <CatalogDataset('mbi_population_c738f69c')>,
#  <CatalogDataset('od_acs_f3eaa128')>,
#  <CatalogDataset('od_tiger_19a6dc83')>,
#  <CatalogDataset('mbi_sociodemogr_7cf425e1')>,
#  <CatalogDataset('od_tiger_e5e51d96')>,
#  <CatalogDataset('od_tiger_41814018')>,
#  <CatalogDataset('od_tiger_b0608dc7')>,
#  <CatalogDataset('mbi_consumer_sp_95cb4e50')>,
#  <CatalogDataset('mbi_consumer_sp_cdb8f12d')>,
#  <CatalogDataset('od_acs_1a22afad')>,
#  <CatalogDataset('ags_retailpoten_ddf56a1a')>,
#  <CatalogDataset('mbi_households__a33ccbc4')>,
#  <CatalogDataset('ags_consumerpro_e8344e2e')>,
#  <CatalogDataset('mbi_population_731c061e')>,
#  <CatalogDataset('mbi_population_37484b32')>,
#  <CatalogDataset('u360_touristicin_463a7b9e')>,
#  <CatalogDataset('u360_pedestriant_4757ec23')>,
#  <CatalogDataset('u360_commerciali_7694276b')>,
#  <CatalogDataset('mbi_purchasing__958db7d5')>,
#  <CatalogDataset('mbi_purchasing__448a9698')>,
#  <CatalogDataset('mbi_sociodemogr_9c07d454')>,
#  <CatalogDataset('mbi_sociodemogr_216c9a35')>,
#  <CatalogDataset('mbi_sociodemogr_6ee94536')>,
#  <CatalogDataset('mbi_sociodemogr_1c07f6d8')>,
#  <CatalogDataset('mbi_marital_sta_d63ec9b1')>,
#  <CatalogDataset('mbi_sociodemogr_81866af0')>,
#  <CatalogDataset('mbi_purchasing__7c3d7271')>,
#  <CatalogDataset('mbi_population_f6d646f1')>,
#  <CatalogDataset('mbi_marital_sta_e24fdd88')>,
#  <CatalogDataset('ags_businesscou_a8310a11')>,
#  <CatalogDataset('u360_workingpopu_ac666c1f')>,
#  <CatalogDataset('od_acs_dc3cfd0f')>,
#  <CatalogDataset('od_acs_5c10acf4')>,
#  <CatalogDataset('mbi_education_5ae6af16')>,
#  <CatalogDataset('mbi_marital_sta_9f4f5206')>,
#  <CatalogDataset('mbi_population_f8f49fc')>,
#  <CatalogDataset('mbi_consumer_sp_735399ae')>,
#  <CatalogDataset('mbi_consumer_sp_7915d42e')>,
#  <CatalogDataset('mbi_households__45067b14')>,
#  <CatalogDataset('mbi_population_47bba1ac')>,
#  <CatalogDataset('mbi_population_83dbf8d6')>,
#  <CatalogDataset('mbi_consumer_sp_2fad0fe5')>,
#  <CatalogDataset('mbi_consumer_sp_bf918793')>,
#  <CatalogDataset('mbi_consumer_sp_ff56f52a')>,
#  <CatalogDataset('mbi_consumer_sp_f0145890')>,
#  <CatalogDataset('mbi_consumer_sp_82faeb7e')>,
#  <CatalogDataset('mbi_sociodemogr_898c773b')>,
#  <CatalogDataset('mbi_consumer_sp_1f7b7756')>,
#  <CatalogDataset('mbi_sociodemogr_2bf0faf3')>,
#  <CatalogDataset('mbi_consumer_sp_9a029b9')>,
#  <CatalogDataset('mbi_purchasing__44de421')>,
#  <CatalogDataset('mbi_purchasing__c2c9b79c')>,
#  <CatalogDataset('mbi_purchasing__9008c244')>,
#  <CatalogDataset('mbi_purchasing__7664929f')>,
#  <CatalogDataset('mbi_purchasing__87256cc1')>,
#  <CatalogDataset('mbi_purchasing__c90e0015')>,
#  <CatalogDataset('mbi_marital_sta_6576ce40')>,
#  <CatalogDataset('mbi_purchasing__5b7c0907')>,
#  <CatalogDataset('mbi_education_c5c0352d')>,
#  <CatalogDataset('od_acs_d28e63ff')>,
#  <CatalogDataset('mbi_consumer_sp_35d0adfe')>,
#  <CatalogDataset('mbi_purchasing__b926aa40')>,
#  <CatalogDataset('mbi_consumer_sp_8038837a')>,
#  <CatalogDataset('mbi_consumer_sp_148619aa')>,
#  <CatalogDataset('mbi_purchasing__59d55bf5')>,
#  <CatalogDataset('mbi_consumer_sp_72d263a7')>,
#  <CatalogDataset('mbi_purchasing__4bc83b22')>,
#  <CatalogDataset('mbi_purchasing__392688cc')>,
#  <CatalogDataset('mbi_consumer_sp_2fac9f2')>,
#  <CatalogDataset('mbi_purchasing__a4a714e4')>,
#  <CatalogDataset('ags_sociodemogr_e128078d')>,
#  <CatalogDataset('ags_crimerisk_9ec89442')>,
#  <CatalogDataset('mbi_sociodemogr_c9711f1c')>,
#  <CatalogDataset('mbi_purchasing__ee2d67ac')>,
#  <CatalogDataset('mbi_sociodemogr_61df236e')>,
#  <CatalogDataset('mbi_consumer_sp_e2093847')>,
#  <CatalogDataset('od_acs_a9825694')>,
#  <CatalogDataset('od_tiger_5e55275d')>,
#  <CatalogDataset('od_acs_a665f9e1')>,
#  <CatalogDataset('od_acs_5ec6965e')>,
#  <CatalogDataset('od_acs_f2f40516')>,
#  <CatalogDataset('od_acs_1209a7e9')>,
#  <CatalogDataset('od_acs_6c9090b5')>,
#  <CatalogDataset('od_acs_f9681e48')>,
#  <CatalogDataset('od_acs_8c8516b')>,
#  <CatalogDataset('od_acs_59534db1')>,
#  <CatalogDataset('od_acs_57d06d64')>,
#  <CatalogDataset('od_acs_e9e3046f')>,
#  <CatalogDataset('od_acs_506e3e6a')>,
#  <CatalogDataset('od_acs_b4cbd26')>,
#  <CatalogDataset('od_acs_fc07c6c5')>,
#  <CatalogDataset('od_acs_a1083df8')>,
#  <CatalogDataset('od_acs_6bfd54ac')>,
#  <CatalogDataset('od_tiger_f9247903')>,
#  <CatalogDataset('od_acs_abd63a91')>,
#  <CatalogDataset('mbi_households__981be2e8')>,
#  <CatalogDataset('od_acs_e1b123b7')>,
#  <CatalogDataset('od_acs_c31e5f28')>,
#  <CatalogDataset('od_tiger_476ce2e9')>,
#  <CatalogDataset('od_tiger_fac69779')>,
#  <CatalogDataset('od_tiger_384d0b09')>,
#  <CatalogDataset('od_acs_7c4b8db0')>,
#  <CatalogDataset('od_acs_eaf66737')>,
#  <CatalogDataset('od_lodes_b4b9dfac')>,
#  <CatalogDataset('od_acs_17667f64')>,
#  <CatalogDataset('od_acs_8c6d324a')>,
#  <CatalogDataset('od_acs_d60f0d6e')>,
#  <CatalogDataset('od_tiger_e10059f')>,
#  <CatalogDataset('od_acs_4f56aa89')>,
#  <CatalogDataset('od_acs_d9e8a21b')>,
#  <CatalogDataset('mbi_education_821a28eb')>,
#  <CatalogDataset('mbi_sociodemogr_b1501243')>,
#  <CatalogDataset('mbi_sociodemogr_b529bc50')>,
#  <CatalogDataset('mbi_sociodemogr_5345ec8b')>,
#  <CatalogDataset('od_acs_c5eb4b5e')>,
#  <CatalogDataset('od_tiger_3336cbf')>,
#  <CatalogDataset('mbi_sociodemogr_ec2f7e01')>,
#  <CatalogDataset('od_acs_de856602')>,
#  <CatalogDataset('od_acs_5978c550')>,
#  <CatalogDataset('mbi_sociodemogr_684ad049')>,
#  <CatalogDataset('mbi_sociodemogr_27d9ea78')>,
#  <CatalogDataset('mbi_sociodemogr_b3653f6')>,
#  <CatalogDataset('od_tiger_66b9092c')>,
#  <CatalogDataset('od_acs_db9898c5')>,
#  <CatalogDataset('od_acs_670c8beb')>,
#  <CatalogDataset('od_acs_6926adef')>,
#  <CatalogDataset('mbi_purchasing__c88ffa1c')>,
#  <CatalogDataset('mbi_education_cc926c54')>,
#  <CatalogDataset('mbi_education_762e04ae')>,
#  <CatalogDataset('mbi_population_678f3375')>,
#  <CatalogDataset('mbi_purchasing__94716c57')>,
#  <CatalogDataset('mbi_purchasing__2e172de2')>,
#  <CatalogDataset('mbi_purchasing__af5a7a18')>,
#  <CatalogDataset('mbi_education_1d29e506')>,
#  <CatalogDataset('mbi_education_bac941f7')>,
#  <CatalogDataset('mbi_purchasing__4d6bae5d')>,
#  <CatalogDataset('mbi_purchasing__8e0cce4c')>,
#  <CatalogDataset('mbi_education_8f53024')>,
#  <CatalogDataset('mbi_education_1b4edb2e')>,
#  <CatalogDataset('mbi_education_227ba9ac')>,
#  <CatalogDataset('mbi_consumer_sp_17716a9d')>,
#  <CatalogDataset('mbi_consumer_sp_f6b7cdef')>,
#  <CatalogDataset('mbi_population_954f45aa')>,
#  <CatalogDataset('mbi_population_63cf59c9')>,
#  <CatalogDataset('mbi_population_1b846234')>,
#  <CatalogDataset('mbi_education_50ded682')>,
#  <CatalogDataset('mbi_marital_sta_a0d1c86b')>,
#  <CatalogDataset('mbi_retail_cent_9fddd44a')>,
#  <CatalogDataset('mbi_education_54220c21')>,
#  <CatalogDataset('mbi_retail_spen_928a0453')>,
#  <CatalogDataset('mbi_retail_spen_1f4f5cc4')>,
#  <CatalogDataset('mbi_retail_spen_5eb92763')>,
#  <CatalogDataset('mbi_retail_spen_bfd9b3fb')>,
#  <CatalogDataset('mbi_households__a52da13')>,
#  <CatalogDataset('mbi_consumer_pr_70e4fbd')>,
#  <CatalogDataset('mbi_consumer_pr_d1cd7490')>,
#  <CatalogDataset('mbi_retail_spen_ffbcad71')>,
#  <CatalogDataset('mbi_retail_spen_628b3e25')>,
#  <CatalogDataset('mbi_consumer_sp_6b599fad')>,
#  <CatalogDataset('mbi_education_ab1322a4')>,
#  <CatalogDataset('mbi_retail_spen_959b2837')>,
#  <CatalogDataset('mbi_consumer_sp_26cf73a9')>,
#  <CatalogDataset('mbi_retail_spen_e2c1988e')>,
#  <CatalogDataset('mbi_retail_spen_14142fb4')>,
#  <CatalogDataset('mbi_retail_cent_73bd00d0')>,
#  <CatalogDataset('mbi_retail_spen_71ed889f')>,
#  <CatalogDataset('mbi_population_7c37e8d2')>,
#  <CatalogDataset('mbi_education_b3faf5f3')>,
#  <CatalogDataset('mbi_retail_spen_95e72b80')>,
#  <CatalogDataset('mbi_consumer_sp_dedd5576')>,
#  <CatalogDataset('mbi_consumer_sp_9a7b0cbd')>,
#  <CatalogDataset('mbi_consumer_sp_4e3123b7')>,
#  <CatalogDataset('mbi_households__23f746a9')>,
#  <CatalogDataset('mbi_population_b5973234')>,
#  <CatalogDataset('mbi_population_f8cc9f68')>,
#  <CatalogDataset('mbi_population_12e15a3f')>,
#  <CatalogDataset('mbi_population_7d5c9b58')>,
#  <CatalogDataset('mbi_education_80732cd')>,
#  <CatalogDataset('mbi_population_240d4d56')>,
#  <CatalogDataset('mbi_education_4ae1d50e')>,
#  <CatalogDataset('mbi_population_92d0ee3c')>,
#  <CatalogDataset('mbi_retail_spen_d00d641b')>,
#  <CatalogDataset('mbi_retail_turn_ee9532ae')>,
#  <CatalogDataset('mbi_purchasing__67ffb52')>,
#  <CatalogDataset('mbi_marital_sta_a68a7ec9')>,
#  <CatalogDataset('mbi_marital_sta_c20496ee')>,
#  <CatalogDataset('mbi_sociodemogr_d0d203f')>,
#  <CatalogDataset('mbi_retail_spen_179140fc')>,
#  <CatalogDataset('mbi_marital_sta_faf50e6b')>,
#  <CatalogDataset('mbi_marital_sta_676c857f')>,
#  <CatalogDataset('mbi_marital_sta_29244604')>,
#  <CatalogDataset('mbi_marital_sta_6d4a8559')>,
#  <CatalogDataset('mbi_education_f4887324')>,
#  <CatalogDataset('mbi_education_302cf48c')>,
#  <CatalogDataset('mbi_consumer_pr_85cc0535')>,
#  <CatalogDataset('mbi_consumer_pr_405e0e3b')>,
#  <CatalogDataset('mbi_consumer_pr_71f4fc68')>,
#  <CatalogDataset('mbi_population_d744417')>,
#  <CatalogDataset('mbi_retail_spen_32189ad3')>,
#  <CatalogDataset('mbi_population_a7baa4dd')>,
#  <CatalogDataset('mbi_population_47662835')>,
#  <CatalogDataset('mbi_sociodemogr_c700bf1c')>,
#  <CatalogDataset('mbi_retail_spen_366134c0')>,
#  <CatalogDataset('mbi_education_cea38973')>,
#  <CatalogDataset('mbi_population_136939b')>,
#  <CatalogDataset('mbi_population_7e96d5e8')>,
#  <CatalogDataset('mbi_population_dc8d2bec')>,
#  <CatalogDataset('mbi_population_71e2c41c')>,
#  <CatalogDataset('mbi_population_c38dcfaa')>,
#  <CatalogDataset('mbi_population_956eb25b')>,
#  <CatalogDataset('mbi_retail_turn_8963eda8')>,
#  <CatalogDataset('mbi_population_74d98571')>,
#  <CatalogDataset('mbi_education_1c7d8e8d')>,
#  <CatalogDataset('mbi_education_20d3049e')>,
#  <CatalogDataset('mbi_education_2e058ac6')>,
#  <CatalogDataset('mbi_population_43bf2e02')>,
#  <CatalogDataset('mbi_education_a867ecf')>,
#  <CatalogDataset('mbi_education_89792663')>,
#  <CatalogDataset('mbi_population_16200069')>,
#  <CatalogDataset('mbi_population_41569e34')>,
#  <CatalogDataset('mbi_population_b831b137')>,
#  <CatalogDataset('mbi_population_4222736e')>,
#  <CatalogDataset('mbi_population_fc7060e9')>,
#  <CatalogDataset('mbi_households__5e25ce97')>,
#  <CatalogDataset('mbi_population_40294f32')>,
#  <CatalogDataset('mbi_population_2d9c4518')>,
#  <CatalogDataset('mbi_population_54d31d6')>,
#  <CatalogDataset('mbi_population_499d6201')>,
#  <CatalogDataset('mbi_population_74ca8906')>,
#  <CatalogDataset('mbi_retail_spen_de784e49')>,
#  <CatalogDataset('mbi_population_a2991dc9')>,
#  <CatalogDataset('mbi_population_7f2f09bc')>,
#  <CatalogDataset('mbi_population_af9b0dc9')>,
#  <CatalogDataset('mbi_population_fd063cd8')>,
#  <CatalogDataset('mbi_consumer_pr_587a8dc1')>,
#  <CatalogDataset('mbi_population_c8491953')>,
#  <CatalogDataset('mbi_population_e4fc2cbe')>,
#  <CatalogDataset('mbi_population_128ae3a6')>,
#  <CatalogDataset('mbi_education_378ccce3')>,
#  <CatalogDataset('mbi_population_ffacf93a')>,
#  <CatalogDataset('mbi_education_9624b12b')>,
#  <CatalogDataset('mbi_population_3064fd97')>,
#  <CatalogDataset('mbi_population_e2d9a96b')>,
#  <CatalogDataset('mbi_education_39439103')>,
#  <CatalogDataset('mbi_population_f89041ae')>,
#  <CatalogDataset('mbi_population_a839556e')>,
#  <CatalogDataset('mbi_population_478bbbc3')>,
#  <CatalogDataset('mbi_population_87a15c36')>,
#  <CatalogDataset('mbi_population_fe818ea5')>,
#  <CatalogDataset('mbi_population_258fbbb9')>,
#  <CatalogDataset('mbi_population_616e9e3f')>,
#  <CatalogDataset('mbi_population_1c94706d')>,
#  <CatalogDataset('mbi_population_44e7cf10')>,
#  <CatalogDataset('mbi_population_4a68bc06')>,
#  <CatalogDataset('mbi_population_769cfa61')>,
#  <CatalogDataset('mbi_households__e3135e72')>,
#  <CatalogDataset('mbi_households__529bb220')>,
#  <CatalogDataset('mbi_population_abc14d43')>,
#  <CatalogDataset('mbi_consumer_pr_8a83111d')>,
#  <CatalogDataset('mbi_population_6d32d5c')>,
#  <CatalogDataset('mbi_population_9f1da2f7')>,
#  <CatalogDataset('mbi_population_e3f7984f')>,
#  <CatalogDataset('mbi_population_5e131025')>,
#  <CatalogDataset('mbi_population_ae87ca7a')>,
#  <CatalogDataset('mbi_population_9976c948')>,
#  <CatalogDataset('mbi_population_33106824')>,
#  <CatalogDataset('mbi_purchasing__7e784fa9')>,
#  <CatalogDataset('mbi_consumer_pr_ac6cc45b')>,
#  <CatalogDataset('mbi_population_c4c2d80f')>,
#  <CatalogDataset('mbi_population_8d74a32b')>,
#  <CatalogDataset('mbi_population_2af27f65')>,
#  <CatalogDataset('mbi_population_5114023a')>,
#  <CatalogDataset('mbi_population_ce57f616')>,
#  <CatalogDataset('mbi_education_10e7aab7')>,
#  <CatalogDataset('mbi_population_90824269')>,
#  <CatalogDataset('mbi_consumer_sp_fbde05a6')>,
#  <CatalogDataset('mbi_consumer_sp_26e2cfad')>,
#  <CatalogDataset('mbi_consumer_sp_3b5a536a')>,
#  <CatalogDataset('mbi_consumer_sp_a19bdf2e')>,
#  <CatalogDataset('mbi_population_5aefb1ef')>,
#  <CatalogDataset('mbi_population_2fd3aba0')>,
#  <CatalogDataset('mbi_population_68f8f0d5')>,
#  <CatalogDataset('mbi_population_bf8ee918')>,
#  <CatalogDataset('mbi_population_59f39389')>,
#  <CatalogDataset('mbi_households__e5b63cab')>,
#  <CatalogDataset('mbi_education_48a0352e')>,
#  <CatalogDataset('mbi_population_a77a929d')>,
#  <CatalogDataset('mbi_population_bf79d506')>,
#  <CatalogDataset('mbi_consumer_sp_d2fbe466')>,
#  <CatalogDataset('mbi_consumer_sp_66cdcdfc')>,
#  <CatalogDataset('mbi_consumer_sp_1763f32e')>,
#  <CatalogDataset('mbi_consumer_sp_c59a5a07')>,
#  <CatalogDataset('mbi_population_8b7faa5f')>,
#  <CatalogDataset('mbi_population_cff75bb3')>,
#  <CatalogDataset('mbi_population_f8718f91')>,
#  <CatalogDataset('mbi_population_341ee33b')>,
#  <CatalogDataset('mbi_population_b22eaf47')>,
#  <CatalogDataset('mbi_retail_spen_925acc12')>,
#  <CatalogDataset('mbi_population_afdcc52b')>,
#  <CatalogDataset('mbi_population_b4091b9')>,
#  <CatalogDataset('mbi_education_c0caec99')>,
#  <CatalogDataset('mbi_retail_spen_59d0722f')>,
#  <CatalogDataset('mbi_education_f2064218')>,
#  <CatalogDataset('mbi_education_8e4e3d70')>,
#  <CatalogDataset('mbi_education_b2fb2a3f')>,
#  <CatalogDataset('mbi_education_336089f1')>,
#  <CatalogDataset('mbi_consumer_pr_4a8e3dea')>,
#  <CatalogDataset('mbi_retail_spen_ac4ffab')>,
#  <CatalogDataset('mbi_education_8fb7c5fd')>,
#  <CatalogDataset('mbi_education_7a4855d5')>,
#  <CatalogDataset('mbi_education_99403e78')>,
#  <CatalogDataset('mbi_education_de6e0e32')>,
#  <CatalogDataset('mbi_retail_spen_c3140e65')>,
#  <CatalogDataset('mbi_education_97a54b22')>,
#  <CatalogDataset('mbi_consumer_sp_e363df4a')>,
#  <CatalogDataset('mbi_education_ed20829a')>,
#  <CatalogDataset('mbi_education_de67cf03')>,
#  <CatalogDataset('mbi_education_50cf9b0b')>,
#  <CatalogDataset('mbi_education_33a31435')>,
#  <CatalogDataset('mbi_education_29a29bcd')>,
#  <CatalogDataset('mbi_education_6a48b9e0')>,
#  <CatalogDataset('mbi_education_cc226caa')>,
#  <CatalogDataset('mbi_education_c2a8191a')>,
#  <CatalogDataset('mbi_education_18f605d6')>,
#  <CatalogDataset('mbi_education_2450f136')>,
#  <CatalogDataset('mbi_education_2057bd69')>,
#  <CatalogDataset('mbi_education_da0ac3b6')>,
#  <CatalogDataset('mbi_retail_turn_cd694587')>,
#  <CatalogDataset('mbi_marital_sta_8c6a94a5')>,
#  <CatalogDataset('mbi_population_da23a6ad')>,
#  <CatalogDataset('mbi_education_341b4904')>,
#  <CatalogDataset('mbi_education_9ff0e490')>,
#  <CatalogDataset('mbi_education_bb1e11d5')>,
#  <CatalogDataset('mbi_education_ea303241')>,
#  <CatalogDataset('mbi_purchasing__2b64f47')>,
#  <CatalogDataset('mbi_purchasing__afa42339')>,
#  <CatalogDataset('mbi_education_1b880265')>,
#  <CatalogDataset('mbi_education_c649c1a4')>,
#  <CatalogDataset('mbi_education_32248c13')>,
#  <CatalogDataset('mbi_consumer_sp_8c599d3c')>,
#  <CatalogDataset('mbi_retail_spen_74852ef5')>,
#  <CatalogDataset('mbi_purchasing__7a1dc666')>,
#  <CatalogDataset('mbi_purchasing__49aa311a')>,
#  <CatalogDataset('mbi_sociodemogr_bf4776ae')>,
#  <CatalogDataset('mbi_sociodemogr_48eabcd2')>,
#  <CatalogDataset('mbi_sociodemogr_a7b672ae')>,
#  <CatalogDataset('mbi_retail_spen_db24546b')>,
#  <CatalogDataset('mbi_purchasing__35515ec1')>,
#  <CatalogDataset('mbi_consumer_pr_8046648e')>,
#  <CatalogDataset('mbi_population_455945fd')>,
#  <CatalogDataset('mbi_purchasing__4d5fbd08')>,
#  <CatalogDataset('mbi_purchasing__72115dbe')>,
#  <CatalogDataset('mbi_purchasing__83037bfe')>,
#  <CatalogDataset('mbi_purchasing__a65ee8cb')>,
#  <CatalogDataset('mbi_households__4c36e6ce')>,
#  <CatalogDataset('mbi_marital_sta_1f4365c8')>,
#  <CatalogDataset('mbi_education_c7a8da7e')>,
#  <CatalogDataset('mbi_sociodemogr_baeafe91')>,
#  <CatalogDataset('mbi_sociodemogr_5bdd884a')>,
#  <CatalogDataset('mbi_sociodemogr_1c800e51')>,
#  <CatalogDataset('mbi_sociodemogr_34b172d4')>,
#  <CatalogDataset('mbi_sociodemogr_80fa578c')>,
#  <CatalogDataset('mbi_education_6dd7d678')>,
#  <CatalogDataset('mbi_education_37b7467a')>,
#  <CatalogDataset('mbi_consumer_sp_51d11f12')>,
#  <CatalogDataset('mbi_education_d15ecc92')>,
#  <CatalogDataset('mbi_education_911c1555')>,
#  <CatalogDataset('mbi_population_1a9f3725')>,
#  <CatalogDataset('mbi_consumer_sp_95c54caa')>,
#  <CatalogDataset('mbi_education_ecdf994c')>,
#  <CatalogDataset('mbi_education_73bda418')>,
#  <CatalogDataset('mbi_retail_turn_77b14ad6')>,
#  <CatalogDataset('mbi_consumer_pr_4292e0dc')>,
#  <CatalogDataset('mbi_population_c9da91f3')>,
#  <CatalogDataset('mbi_population_43643b60')>,
#  <CatalogDataset('mbi_population_aed19ab4')>,
#  <CatalogDataset('mbi_population_f074b6b8')>,
#  <CatalogDataset('mbi_population_6be8055b')>,
#  <CatalogDataset('mbi_population_e268978d')>,
#  <CatalogDataset('mbi_population_bd228fa6')>,
#  <CatalogDataset('mbi_education_21568154')>,
#  <CatalogDataset('mbi_population_53cb6ef3')>,
#  <CatalogDataset('mbi_population_10a5fd7')>,
#  <CatalogDataset('mbi_population_3d9c9b3d')>,
#  <CatalogDataset('mbi_population_e7dc93f5')>,
#  <CatalogDataset('mbi_education_aec62b5c')>,
#  <CatalogDataset('mbi_marital_sta_5369a832')>,
#  <CatalogDataset('mbi_marital_sta_957d69df')>,
#  <CatalogDataset('mbi_population_86a083fa')>,
#  <CatalogDataset('mbi_households__a9b97e1')>,
#  <CatalogDataset('mbi_education_773f92a5')>,
#  <CatalogDataset('mbi_purchasing__e78441d9')>,
#  <CatalogDataset('mbi_population_f95255c3')>,
#  <CatalogDataset('mbi_purchasing__bd9b0ad3')>,
#  <CatalogDataset('mbi_education_415eefcb')>,
#  <CatalogDataset('mbi_education_d71b708e')>,
#  <CatalogDataset('mbi_education_a0d89cb1')>,
#  <CatalogDataset('mbi_consumer_sp_c52095ec')>,
#  <CatalogDataset('mbi_consumer_sp_23abf591')>,
#  <CatalogDataset('mbi_consumer_sp_1d828b79')>,
#  <CatalogDataset('mbi_consumer_sp_bfd1ac4c')>,
#  <CatalogDataset('mbi_retail_spen_d8c4d322')>,
#  <CatalogDataset('mbi_education_846a2135')>,
#  <CatalogDataset('mbi_education_c5937c3f')>,
#  <CatalogDataset('mbi_education_db808f46')>,
#  <CatalogDataset('mbi_marital_sta_4911d8dc')>,
#  <CatalogDataset('mbi_retail_spen_c5a5cb0a')>,
#  <CatalogDataset('mbi_sociodemogr_e0353759')>,
#  <CatalogDataset('mbi_sociodemogr_ddf1aff3')>,
#  <CatalogDataset('mbi_sociodemogr_2488a49c')>,
#  <CatalogDataset('mbi_education_32999cea')>,
#  <CatalogDataset('mbi_sociodemogr_3f309ba')>,
#  <CatalogDataset('mbi_sociodemogr_5364ffc6')>,
#  <CatalogDataset('mbi_retail_spen_80789b98')>,
#  <CatalogDataset('mbi_consumer_sp_54c4abc3')>,
#  <CatalogDataset('mbi_households__541b50b5')>,
#  <CatalogDataset('mbi_consumer_pr_47d227cf')>,
#  <CatalogDataset('mbi_purchasing__9c98e51b')>,
#  <CatalogDataset('mbi_sociodemogr_5b5931bd')>,
#  <CatalogDataset('mbi_sociodemogr_151b070c')>,
#  <CatalogDataset('mbi_sociodemogr_e108978b')>,
#  <CatalogDataset('mbi_retail_spen_7450f97a')>,
#  <CatalogDataset('mbi_retail_turn_7654ee53')>,
#  <CatalogDataset('mbi_sociodemogr_4cff6123')>,
#  <CatalogDataset('mbi_sociodemogr_d5908982')>,
#  <CatalogDataset('mbi_sociodemogr_5461519b')>,
#  <CatalogDataset('mbi_education_189e2205')>,
#  <CatalogDataset('mbi_retail_spen_6f67f691')>,
#  <CatalogDataset('mbi_retail_spen_178c8c6d')>,
#  <CatalogDataset('mbi_sociodemogr_67dcce6a')>,
#  <CatalogDataset('mbi_sociodemogr_a99b8d3')>,
#  <CatalogDataset('mbi_sociodemogr_2f9e11bd')>,
#  <CatalogDataset('mbi_sociodemogr_e0eff8ec')>,
#  <CatalogDataset('mbi_sociodemogr_b9522069')>,
#  <CatalogDataset('mbi_consumer_pr_c43a7e92')>,
#  <CatalogDataset('mbi_sociodemogr_ab4e015c')>,
#  <CatalogDataset('mbi_sociodemogr_f2f31340')>,
#  <CatalogDataset('mbi_sociodemogr_ba82d942')>,
#  <CatalogDataset('mbi_sociodemogr_d54c1e7f')>,
#  <CatalogDataset('mbi_sociodemogr_ae7c4ad3')>,
#  <CatalogDataset('mbi_sociodemogr_1c1af215')>,
#  <CatalogDataset('mbi_sociodemogr_4c55184')>,
#  <CatalogDataset('mbi_sociodemogr_90fd9e3')>,
#  <CatalogDataset('mbi_marital_sta_c04e775')>,
#  <CatalogDataset('mbi_sociodemogr_6be48ed8')>,
#  <CatalogDataset('mbi_sociodemogr_3dec1fd7')>,
#  <CatalogDataset('mbi_retail_spen_51ee9377')>,
#  <CatalogDataset('mbi_purchasing__76f7182f')>,
#  <CatalogDataset('mbi_purchasing__eb570392')>,
#  <CatalogDataset('mbi_consumer_pr_2d885c89')>,
#  <CatalogDataset('mbi_sociodemogr_ba72e486')>,
#  <CatalogDataset('mbi_sociodemogr_a1f5b96a')>,
#  <CatalogDataset('mbi_sociodemogr_482cc906')>,
#  <CatalogDataset('mbi_sociodemogr_74ba0dec')>,
#  <CatalogDataset('mbi_purchasing__5bb7b3be')>,
#  <CatalogDataset('mbi_consumer_pr_71810128')>,
#  <CatalogDataset('mbi_consumer_sp_d617a174')>,
#  <CatalogDataset('mbi_consumer_sp_b275be11')>,
#  <CatalogDataset('mbi_households__4ba4a1b4')>,
#  <CatalogDataset('mbi_consumer_sp_d8105e3c')>,
#  <CatalogDataset('mbi_retail_spen_b6aaa6dc')>,
#  <CatalogDataset('mbi_households__90dd4218')>,
#  <CatalogDataset('mbi_consumer_pr_4216592b')>,
#  <CatalogDataset('mbi_consumer_sp_9097456')>,
#  <CatalogDataset('mbi_consumer_sp_68b9815b')>,
#  <CatalogDataset('mbi_consumer_sp_aaac9d89')>,
#  <CatalogDataset('mbi_consumer_sp_2f9e7020')>,
#  <CatalogDataset('mbi_retail_spen_a22412a5')>,
#  <CatalogDataset('mbi_retail_spen_e2e3601c')>,
#  <CatalogDataset('mbi_retail_spen_371e4f')>,
#  <CatalogDataset('mbi_retail_spen_9f4f7e48')>,
#  <CatalogDataset('mbi_consumer_sp_aff46bfd')>,
#  <CatalogDataset('mbi_education_64db9744')>,
#  <CatalogDataset('mbi_education_ca53d0c9')>,
#  <CatalogDataset('mbi_consumer_sp_fae394ee')>,
#  <CatalogDataset('mbi_consumer_sp_d0af3e77')>,
#  <CatalogDataset('mbi_consumer_sp_1509de7d')>,
#  <CatalogDataset('mbi_households__5d5b1ed6')>,
#  <CatalogDataset('mbi_consumer_sp_bfd34dd7')>,
#  <CatalogDataset('mbi_consumer_sp_90236f6e')>,
#  <CatalogDataset('mbi_consumer_sp_f460f004')>,
#  <CatalogDataset('mbi_consumer_sp_c5a42c1b')>,
#  <CatalogDataset('mbi_consumer_sp_4ecb60c9')>,
#  <CatalogDataset('mbi_consumer_sp_cde9549c')>,
#  <CatalogDataset('mbi_consumer_sp_d0809991')>,
#  <CatalogDataset('mbi_consumer_sp_5fe0bb64')>,
#  <CatalogDataset('mbi_consumer_sp_ce830d51')>,
#  <CatalogDataset('mbi_consumer_sp_c7df2517')>,
#  <CatalogDataset('mbi_consumer_sp_ce0bd24c')>,
#  <CatalogDataset('mbi_consumer_sp_7bb411a7')>,
#  <CatalogDataset('mbi_consumer_sp_9f9eb8cf')>,
#  <CatalogDataset('mbi_consumer_sp_233ee921')>,
#  <CatalogDataset('mbi_consumer_sp_c937fcca')>,
#  <CatalogDataset('mbi_consumer_sp_5e11b3e4')>,
#  <CatalogDataset('mbi_consumer_sp_a8c1aec5')>,
#  <CatalogDataset('mbi_consumer_sp_1d71955d')>,
#  <CatalogDataset('mbi_consumer_pr_786039ed')>,
#  <CatalogDataset('mbi_consumer_sp_1c991bfb')>,
#  <CatalogDataset('mbi_consumer_sp_a9293242')>,
#  <CatalogDataset('mbi_households__f90930aa')>,
#  <CatalogDataset('mbi_households__8af896e3')>,
#  <CatalogDataset('mbi_households__56a61919')>,
#  <CatalogDataset('mbi_households__b2153c15')>,
#  <CatalogDataset('mbi_retail_spen_e66b9090')>,
#  <CatalogDataset('mbi_households__9e2c7244')>,
#  <CatalogDataset('mbi_households__6058cba3')>,
#  <CatalogDataset('mbi_households__bf3e0a4')>,
#  <CatalogDataset('mbi_households__7bfb8a4f')>,
#  <CatalogDataset('mbi_households__d0b84ddd')>,
#  <CatalogDataset('mbi_households__e7146470')>,
#  <CatalogDataset('mbi_households__da53f787')>,
#  <CatalogDataset('mbi_retail_spen_fa06f554')>,
#  <CatalogDataset('mbi_households__c510e2cc')>,
#  <CatalogDataset('mbi_households__91883048')>,
#  <CatalogDataset('mbi_households__dd3cdfa0')>,
#  <CatalogDataset('mbi_households__cad2ff8d')>,
#  <CatalogDataset('mbi_education_38ed8470')>,
#  <CatalogDataset('mbi_households__1afde171')>,
#  <CatalogDataset('mbi_households__52c47fac')>,
#  <CatalogDataset('mbi_households__4458cdcf')>,
#  <CatalogDataset('mbi_households__7c08c60c')>,
#  <CatalogDataset('mbi_households__68d4d6b1')>,
#  <CatalogDataset('mbi_consumer_pr_262c944e')>,
#  <CatalogDataset('mbi_retail_spen_709f5d')>,
#  <CatalogDataset('mbi_households__cd0c3ffa')>,
#  <CatalogDataset('mbi_households__9b6cb6e8')>,
#  <CatalogDataset('mbi_households__15ae55dc')>,
#  <CatalogDataset('mbi_households__83bb8b60')>,
#  <CatalogDataset('mbi_households__b523df4d')>,
#  <CatalogDataset('mbi_households__9ae0a9c1')>,
#  <CatalogDataset('mbi_households__3466a5b7')>,
#  <CatalogDataset('mbi_households__997e9144')>,
#  <CatalogDataset('mbi_households__dfc9029b')>,
#  <CatalogDataset('mbi_households__8a4ffc52')>,
#  <CatalogDataset('mbi_households__5c453314')>,
#  <CatalogDataset('mbi_households__d5c29eea')>,
#  <CatalogDataset('mbi_households__9c948cd1')>,
#  <CatalogDataset('mbi_households__66e99138')>,
#  <CatalogDataset('mbi_households__f6573901')>,
#  <CatalogDataset('mbi_households__2b96fac0')>,
#  <CatalogDataset('mbi_households__fb6792ca')>,
#  <CatalogDataset('mbi_households__fdd5fe53')>,
#  <CatalogDataset('mbi_households__3a2cc928')>,
#  <CatalogDataset('mbi_households__ec5a08b7')>,
#  <CatalogDataset('mbi_households__8e06a7f3')>,
#  <CatalogDataset('mbi_households__b11a7344')>,
#  <CatalogDataset('mbi_households__c88593a3')>,
#  <CatalogDataset('mbi_education_fafff1e')>,
#  <CatalogDataset('mbi_households__764c6196')>,
#  <CatalogDataset('mbi_retail_turn_42ff98b9')>,
#  <CatalogDataset('mbi_consumer_sp_58f735aa')>,
#  <CatalogDataset('mbi_households__69695999')>,
#  <CatalogDataset('mbi_households__372b910a')>,
#  <CatalogDataset('mbi_sociodemogr_5d30c6d9')>,
#  <CatalogDataset('mbi_households__f78d0c4c')>,
#  <CatalogDataset('mbi_households__a4f03ceb')>,
#  <CatalogDataset('mbi_marital_sta_290f87e6')>,
#  <CatalogDataset('mbi_households__cd156e0e')>,
#  <CatalogDataset('mbi_households__bf75c797')>,
#  <CatalogDataset('mbi_retail_cent_c00d1dfc')>,
#  <CatalogDataset('mbi_households__eaa86152')>,
#  <CatalogDataset('mbi_marital_sta_5e11da68')>,
#  <CatalogDataset('mbi_households__4478d9e')>,
#  <CatalogDataset('mbi_households__5da15f26')>,
#  <CatalogDataset('mbi_marital_sta_e945e70c')>,
#  <CatalogDataset('mbi_households__4818f2c8')>,
#  <CatalogDataset('mbi_households__7ccd4ea0')>,
#  <CatalogDataset('mbi_population_4c9ea8ad')>,
#  <CatalogDataset('mbi_households__452920ed')>,
#  <CatalogDataset('mbi_households__a9aa3313')>,
#  <CatalogDataset('mbi_households__b6ee8fb2')>,
#  <CatalogDataset('mbi_retail_cent_91a8fe18')>,
#  <CatalogDataset('mbi_retail_spen_9a2c77fc')>,
#  <CatalogDataset('mbi_retail_spen_286538c8')>,
#  <CatalogDataset('mbi_retail_spen_64a04118')>,
#  <CatalogDataset('mbi_retail_spen_cf4e7150')>,
#  <CatalogDataset('mbi_retail_cent_7684f9c0')>,
#  <CatalogDataset('mbi_retail_spen_86f1a870')>,
#  <CatalogDataset('mbi_retail_spen_eb0258d9')>,
#  <CatalogDataset('mbi_retail_spen_386e24b4')>,
#  <CatalogDataset('mbi_retail_spen_9338c9c')>,
#  <CatalogDataset('mbi_retail_spen_d89500da')>,
#  <CatalogDataset('mbi_retail_spen_ec0cd59d')>,
#  <CatalogDataset('mbi_retail_spen_eda1cda6')>,
#  <CatalogDataset('mbi_retail_spen_70768c40')>,
#  <CatalogDataset('mbi_population_e1529805')>,
#  <CatalogDataset('mbi_retail_spen_ad9d00ac')>,
#  <CatalogDataset('mbi_retail_spen_96e753c4')>,
#  <CatalogDataset('mbi_retail_cent_b123832')>,
#  <CatalogDataset('mbi_retail_cent_418c2702')>,
#  <CatalogDataset('mbi_retail_cent_b1884e39')>,
#  <CatalogDataset('mbi_retail_cent_104b0974')>,
#  <CatalogDataset('mbi_retail_cent_99309ad9')>,
#  <CatalogDataset('mbi_retail_turn_19d5f465')>,
#  <CatalogDataset('mbi_retail_turn_25703f0e')>,
#  <CatalogDataset('mbi_retail_turn_b9b65fe2')>,
#  <CatalogDataset('mbi_retail_turn_95e0a3be')>,
#  <CatalogDataset('mbi_retail_turn_147e3217')>,
#  <CatalogDataset('mbi_education_87bcae55')>,
#  <CatalogDataset('mbi_retail_turn_7c76fd5f')>,
#  <CatalogDataset('mbi_retail_turn_cb840b14')>,
#  <CatalogDataset('mbi_retail_turn_f1f26bd2')>,
#  <CatalogDataset('mbi_retail_turn_4ba5304f')>,
#  <CatalogDataset('mbi_purchasing__56d4d9b2')>,
#  <CatalogDataset('mbi_education_952fa1b')>,
#  <CatalogDataset('mbi_retail_turn_4da82cad')>,
#  <CatalogDataset('mbi_retail_turn_f033cfff')>,
#  <CatalogDataset('mbi_retail_turn_f8135317')>,
#  <CatalogDataset('mbi_purchasing__c2d48fc1')>,
#  <CatalogDataset('mbi_purchasing__bc2a0709')>,
#  <CatalogDataset('mbi_purchasing__f1ebc21c')>,
#  <CatalogDataset('mbi_purchasing__6dcbc2c6')>,
#  <CatalogDataset('mbi_purchasing__f81944c')>,
#  <CatalogDataset('mbi_purchasing__84a62bd4')>,
#  <CatalogDataset('mbi_purchasing__e3d4a3da')>,
#  <CatalogDataset('mbi_purchasing__5a80cc29')>,
#  <CatalogDataset('mbi_purchasing__c2527bf0')>,
#  <CatalogDataset('mbi_purchasing__46112d4d')>,
#  <CatalogDataset('mbi_education_afcbc85a')>,
#  <CatalogDataset('mbi_purchasing__dcc70505')>,
#  <CatalogDataset('mbi_purchasing__692787d4')>,
#  <CatalogDataset('mbi_purchasing__494e4978')>,
#  <CatalogDataset('mbi_purchasing__b413352')>,
#  <CatalogDataset('mbi_purchasing__41dadaba')>,
#  <CatalogDataset('mbi_purchasing__6fd2bc1')>,
#  <CatalogDataset('mbi_purchasing__b54d32ba')>,
#  <CatalogDataset('mbi_purchasing__d3134b00')>,
#  <CatalogDataset('mbi_purchasing__87a3e23c')>,
#  <CatalogDataset('mbi_purchasing__ee45ca6b')>,
#  <CatalogDataset('mbi_purchasing__b99055d2')>,
#  <CatalogDataset('mbi_purchasing__b15d896e')>,
#  <CatalogDataset('mbi_households__f3093d63')>,
#  <CatalogDataset('mbi_sociodemogr_ab2db058')>,
#  <CatalogDataset('mbi_purchasing__edbb1709')>,
#  <CatalogDataset('mbi_purchasing__15d2f1c3')>,
#  <CatalogDataset('mbi_marital_sta_b620160')>,
#  <CatalogDataset('mbi_education_9f17d26c')>,
#  <CatalogDataset('mbi_purchasing__4f1c1ca8')>,
#  <CatalogDataset('mbi_purchasing__c22d6fc8')>,
#  <CatalogDataset('mbi_purchasing__bc3ac75d')>,
#  <CatalogDataset('mbi_sociodemogr_dc2b5374')>,
#  <CatalogDataset('mbi_purchasing__9a05a28f')>,
#  <CatalogDataset('mbi_purchasing__ab8ea8c5')>,
#  <CatalogDataset('mbi_purchasing__9e816ee3')>,
#  <CatalogDataset('mbi_marital_sta_3cab91b6')>,
#  <CatalogDataset('mbi_purchasing__69bdc2d6')>,
#  <CatalogDataset('mbi_purchasing__4c8327cd')>,
#  <CatalogDataset('mbi_purchasing__6cf8fb63')>,
#  <CatalogDataset('mbi_purchasing__c1098dee')>,
#  <CatalogDataset('mbi_purchasing__7a42824')>,
#  <CatalogDataset('mbi_purchasing__5da8fc60')>,
#  <CatalogDataset('mbi_purchasing__1618bf73')>,
#  <CatalogDataset('mbi_purchasing__8f54483e')>,
#  <CatalogDataset('mbi_purchasing__191dbb94')>,
#  <CatalogDataset('mbi_marital_sta_2ac874b8')>,
#  <CatalogDataset('mbi_purchasing__436dd28')>,
#  <CatalogDataset('mbi_purchasing__c6b7d189')>,
#  <CatalogDataset('mbi_purchasing__4b0b3668')>,
#  <CatalogDataset('mbi_purchasing__10664dd0')>,
#  <CatalogDataset('mbi_purchasing__e99cab1e')>,
#  <CatalogDataset('mbi_purchasing__79fc56a3')>,
#  <CatalogDataset('mbi_purchasing__118e7a9')>,
#  <CatalogDataset('mbi_purchasing__b1b1f45f')>,
#  <CatalogDataset('mbi_purchasing__d7d26d54')>,
#  <CatalogDataset('mbi_consumer_sp_568ddd76')>,
#  <CatalogDataset('mbi_purchasing__f06d606b')>,
#  <CatalogDataset('mbi_purchasing__a53ac6dd')>,
#  <CatalogDataset('mbi_retail_turn_5e4029c')>,
#  <CatalogDataset('mbi_purchasing__9dd6ffcb')>,
#  <CatalogDataset('mbi_purchasing__72582dad')>,
#  <CatalogDataset('mbi_education_8a54f3a9')>,
#  <CatalogDataset('mbi_purchasing__2713ead4')>,
#  <CatalogDataset('mbi_purchasing__71c1e4f2')>,
#  <CatalogDataset('mbi_sociodemogr_c870c0d0')>,
#  <CatalogDataset('mbi_purchasing__ef590dd8')>,
#  <CatalogDataset('mbi_purchasing__31ba71ef')>,
#  <CatalogDataset('mbi_purchasing__45234952')>,
#  <CatalogDataset('mbi_purchasing__aa89e9c1')>,
#  <CatalogDataset('mbi_purchasing__a7e3ec24')>,
#  <CatalogDataset('mbi_purchasing__8ffe918')>,
#  <CatalogDataset('mbi_purchasing__ba71e577')>,
#  <CatalogDataset('mbi_consumer_sp_c3cddb7f')>,
#  <CatalogDataset('mbi_purchasing__cbbdaa4e')>,
#  <CatalogDataset('mbi_purchasing__6ec77948')>,
#  <CatalogDataset('mbi_marital_sta_a53c866b')>,
#  <CatalogDataset('mbi_consumer_pr_8e977645')>,
#  <CatalogDataset('mbi_purchasing__efdf83ab')>,
#  <CatalogDataset('mbi_marital_sta_72936267')>,
#  <CatalogDataset('mbi_marital_sta_cd96234e')>,
#  <CatalogDataset('mbi_marital_sta_86173bc2')>,
#  <CatalogDataset('mbi_marital_sta_8d6b4b69')>,
#  <CatalogDataset('mbi_marital_sta_b0e51c15')>,
#  <CatalogDataset('mbi_marital_sta_ef37e42d')>,
#  <CatalogDataset('mbi_marital_sta_df42763c')>,
#  <CatalogDataset('mbi_marital_sta_5a3b5324')>,
#  <CatalogDataset('mbi_marital_sta_ab5332b8')>,
#  <CatalogDataset('mbi_purchasing__ed51bec4')>,
#  <CatalogDataset('mbi_marital_sta_a9b4d07d')>,
#  <CatalogDataset('mbi_marital_sta_2f717ef')>,
#  <CatalogDataset('mbi_marital_sta_8a432e59')>,
#  <CatalogDataset('mbi_marital_sta_81cadb5')>,
#  <CatalogDataset('mbi_marital_sta_6c05206a')>,
#  <CatalogDataset('mbi_marital_sta_f133e825')>,
#  <CatalogDataset('mbi_marital_sta_8639709')>,
#  <CatalogDataset('mbi_marital_sta_bb8c5ab0')>,
#  <CatalogDataset('mbi_marital_sta_1050e8bb')>,
#  <CatalogDataset('mbi_marital_sta_ac1cc159')>,
#  <CatalogDataset('mbi_marital_sta_911938ca')>,
#  <CatalogDataset('mbi_marital_sta_1ac6f8d8')>,
#  <CatalogDataset('mbi_marital_sta_30b01f5c')>,
#  <CatalogDataset('mbi_marital_sta_1d8a0fd6')>,
#  <CatalogDataset('mbi_marital_sta_be315c8c')>,
#  <CatalogDataset('mbi_marital_sta_23c9d170')>,
#  <CatalogDataset('mbi_marital_sta_d1836976')>,
#  <CatalogDataset('mbi_marital_sta_48aff3f3')>,
#  <CatalogDataset('mbi_marital_sta_c5e573a')>,
#  <CatalogDataset('mbi_marital_sta_fc63bb6d')>,
#  <CatalogDataset('mbi_marital_sta_12bbd79c')>,
#  <CatalogDataset('mbi_marital_sta_dea1a4a8')>,
#  <CatalogDataset('mbi_marital_sta_9979bf8e')>,
#  <CatalogDataset('mbi_marital_sta_6023cdc8')>,
#  <CatalogDataset('mbi_marital_sta_88b11a6f')>,
#  <CatalogDataset('mbi_marital_sta_9aa946a5')>,
#  <CatalogDataset('mbi_marital_sta_285b9702')>,
#  <CatalogDataset('mbi_marital_sta_91564a0a')>,
#  <CatalogDataset('mbi_marital_sta_46e91895')>,
#  <CatalogDataset('mbi_marital_sta_5800a660')>,
#  <CatalogDataset('mbi_marital_sta_2f4ef97c')>,
#  <CatalogDataset('mbi_marital_sta_2172caf8')>,
#  <CatalogDataset('mbi_marital_sta_24186333')>,
#  <CatalogDataset('mbi_marital_sta_4a4cfd2a')>,
#  <CatalogDataset('mbi_marital_sta_f9d9a0f2')>,
#  <CatalogDataset('mbi_marital_sta_d63798ed')>,
#  <CatalogDataset('mbi_marital_sta_dd41bca')>,
#  <CatalogDataset('mbi_marital_sta_7b4bb9f7')>,
#  <CatalogDataset('mbi_marital_sta_ca516305')>,
#  <CatalogDataset('mbi_purchasing__7811b8cd')>,
#  <CatalogDataset('mbi_marital_sta_9b681890')>,
#  <CatalogDataset('mbi_marital_sta_4a904a9d')>,
#  <CatalogDataset('mbi_marital_sta_bf0a3175')>,
#  <CatalogDataset('mbi_consumer_pr_c7efa2d3')>,
#  <CatalogDataset('mbi_consumer_pr_9047a65a')>,
#  <CatalogDataset('mbi_consumer_pr_d0bace7d')>,
#  <CatalogDataset('mbi_consumer_pr_b2e66139')>,
#  <CatalogDataset('mbi_households__e8a831c')>,
#  <CatalogDataset('mbi_consumer_pr_5f2692fb')>,
#  <CatalogDataset('mbi_consumer_pr_fe2318e9')>,
#  <CatalogDataset('mbi_consumer_pr_a0452346')>,
#  <CatalogDataset('mbi_population_93cdf7c')>,
#  <CatalogDataset('mbi_consumer_pr_77229457')>,
#  <CatalogDataset('mbi_consumer_pr_2fbd23aa')>,
#  <CatalogDataset('mbi_population_b2c4ea47')>,
#  <CatalogDataset('mbi_population_49e4d85e')>,
#  <CatalogDataset('mbi_education_ef892935')>,
#  <CatalogDataset('mbi_population_17749443')>,
#  <CatalogDataset('mbi_retail_cent_69c0a2cb')>,
#  <CatalogDataset('mbi_retail_cent_c7543273')>,
#  <CatalogDataset('mbi_population_c65debdd')>,
#  <CatalogDataset('mbi_population_4bdfae58')>,
#  <CatalogDataset('mbi_population_25836b29')>,
#  <CatalogDataset('mbi_population_630f291d')>,
#  <CatalogDataset('mbi_population_2bf0810f')>,
#  <CatalogDataset('mbi_education_3b9bdc1')>,
#  <CatalogDataset('mbi_retail_cent_4b6165a8')>,
#  <CatalogDataset('mbi_population_ad17f037')>,
#  <CatalogDataset('mbi_purchasing__8d6cb5f2')>,
#  <CatalogDataset('mbi_consumer_sp_5cae5da5')>,
#  <CatalogDataset('mbi_purchasing__657af1e')>,
#  <CatalogDataset('mbi_purchasing__706b45d0')>,
#  <CatalogDataset('mbi_purchasing__196cae87')>,
#  <CatalogDataset('mbi_purchasing__2994d992')>,
#  <CatalogDataset('mbi_purchasing__3409649d')>,
#  <CatalogDataset('mbi_purchasing__7d233b69')>,
#  <CatalogDataset('mbi_population_b129c20d')>,
#  <CatalogDataset('mbi_population_2af284e6')>,
#  <CatalogDataset('mbi_population_a27f18ee')>,
#  <CatalogDataset('mbi_population_ffc6d96')>,
#  <CatalogDataset('mbi_population_3d76526')>,
#  <CatalogDataset('mbi_population_faf820b6')>,
#  <CatalogDataset('mbi_population_a41f5345')>,
#  <CatalogDataset('mbi_population_e090a867')>,
#  <CatalogDataset('mbi_population_8772c540')>,
#  <CatalogDataset('mbi_population_5cd1ad50')>,
#  <CatalogDataset('mbi_marital_sta_9ac16176')>,
#  <CatalogDataset('mbi_population_ca76d571')>,
#  <CatalogDataset('mbi_population_a3fee2e7')>,
#  <CatalogDataset('mbi_population_d850bbf3')>,
#  <CatalogDataset('mbi_population_1bf65c2b')>,
#  <CatalogDataset('mbi_population_d3d648b2')>,
#  <CatalogDataset('mbi_retail_cent_2505db1b')>,
#  <CatalogDataset('mbi_purchasing__1acde529')>,
#  <CatalogDataset('mbi_marital_sta_c79c30bb')>,
#  <CatalogDataset('mbi_purchasing__b9b69254')>,
#  <CatalogDataset('mbi_population_291f2076')>,
#  <CatalogDataset('mbi_population_f6f3b0df')>,
#  <CatalogDataset('mbi_population_f3cc6840')>,
#  <CatalogDataset('mbi_population_3325b907')>,
#  <CatalogDataset('mbi_population_e6763708')>,
#  <CatalogDataset('mbi_population_ecb61db8')>,
#  <CatalogDataset('mbi_education_c6de2887')>,
#  <CatalogDataset('mbi_population_2138d9d0')>,
#  <CatalogDataset('mbi_population_3adfc677')>,
#  <CatalogDataset('mbi_population_7819f561')>,
#  <CatalogDataset('mbi_population_ef662328')>,
#  <CatalogDataset('mbi_population_2f72a488')>,
#  <CatalogDataset('mbi_marital_sta_b58022da')>,
#  <CatalogDataset('mbi_population_5a0fe538')>,
#  <CatalogDataset('mbi_population_70d82a6a')>,
#  <CatalogDataset('mbi_population_352696fb')>,
#  <CatalogDataset('mbi_population_1a9ba722')>,
#  <CatalogDataset('mbi_population_bbf5f69d')>,
#  <CatalogDataset('mbi_population_a8a29902')>,
#  <CatalogDataset('mbi_population_5b9568b')>,
#  <CatalogDataset('mbi_population_279b4caf')>,
#  <CatalogDataset('mbi_population_7340a78d')>,
#  <CatalogDataset('mbi_marital_sta_d4d56ac0')>,
#  <CatalogDataset('mbi_population_e4c7127c')>,
#  <CatalogDataset('mbi_population_82ef6fd9')>,
#  <CatalogDataset('mbi_population_c5aa98ea')>,
#  <CatalogDataset('mbi_population_d5156048')>,
#  <CatalogDataset('mbi_population_7552b3a1')>,
#  <CatalogDataset('mbi_population_6ebd06d3')>,
#  <CatalogDataset('mbi_population_140c14ac')>,
#  <CatalogDataset('mbi_marital_sta_42fd8839')>,
#  <CatalogDataset('mbi_population_2e7a746a')>,
#  <CatalogDataset('mbi_population_55a69880')>,
#  <CatalogDataset('mbi_population_1fbd38ad')>,
#  <CatalogDataset('mbi_population_c9dcc15d')>,
#  <CatalogDataset('mbi_population_d9dbd19')>,
#  <CatalogDataset('mbi_households__a70ed971')>,
#  <CatalogDataset('mbi_retail_cent_77c4aec3')>,
#  <CatalogDataset('mbi_consumer_pr_f21e5fd5')>,
#  <CatalogDataset('mbi_population_ccae0a39')>,
#  <CatalogDataset('mbi_retail_cent_457f1ac5')>,
#  <CatalogDataset('mbi_purchasing__f463c70f')>,
#  <CatalogDataset('mbi_population_a43bdcbb')>,
#  <CatalogDataset('mbi_population_52176b42')>,
#  <CatalogDataset('mbi_population_f4718c11')>,
#  <CatalogDataset('mbi_population_1b75b3af')>,
#  <CatalogDataset('mbi_population_e757018d')>,
#  <CatalogDataset('mbi_population_79c4a13f')>,
#  <CatalogDataset('mbi_population_4b232af5')>,
#  <CatalogDataset('mbi_population_6ca74dec')>,
#  <CatalogDataset('mbi_population_4ac4d846')>,
#  <CatalogDataset('mbi_population_20f4dfe2')>,
#  <CatalogDataset('mbi_population_6f535a47')>,
#  <CatalogDataset('mbi_population_f2126861')>,
#  <CatalogDataset('mbi_retail_turn_3957f48')>,
#  <CatalogDataset('mbi_retail_cent_2ec26c92')>,
#  <CatalogDataset('mbi_population_2efa58bb')>,
#  <CatalogDataset('mbi_population_11723c38')>,
#  <CatalogDataset('mbi_education_1eebb188')>,
#  <CatalogDataset('mbi_population_e1bc1359')>,
#  <CatalogDataset('mbi_population_f3a44f93')>,
#  <CatalogDataset('mbi_population_f5589550')>,
#  <CatalogDataset('mbi_education_5400fc4d')>,
#  <CatalogDataset('mbi_retail_turn_3b743306')>,
#  <CatalogDataset('mbi_retail_turn_f2aadea8')>,
#  <CatalogDataset('mbi_population_d1cbef14')>,
#  <CatalogDataset('mbi_population_3a7e99f')>,
#  <CatalogDataset('mbi_purchasing__2a6b58c4')>,
#  <CatalogDataset('mbi_population_4efa9a7f')>,
#  <CatalogDataset('mbi_retail_cent_a346fa1f')>,
#  <CatalogDataset('mbi_retail_cent_ec7cf552')>,
#  <CatalogDataset('mbi_purchasing__ab03a531')>,
#  <CatalogDataset('mbi_purchasing__b265708b')>,
#  <CatalogDataset('mbi_purchasing__13f02ce0')>,
#  <CatalogDataset('mbi_purchasing__fdeea5f1')>,
#  <CatalogDataset('mbi_purchasing__a3add56a')>,
#  <CatalogDataset('mbi_purchasing__a07d2c41')>,
#  <CatalogDataset('mbi_purchasing__ca177752')>,
#  <CatalogDataset('mbi_purchasing__159a9398')>,
#  <CatalogDataset('mbi_purchasing__d49f7ec5')>,
#  <CatalogDataset('mbi_purchasing__98e28a93')>,
#  <CatalogDataset('mbi_purchasing__ec3e3d8d')>,
#  <CatalogDataset('mbi_education_3d8a414a')>,
#  <CatalogDataset('mbi_sociodemogr_7ee37233')>,
#  <CatalogDataset('mbi_sociodemogr_2cdeb5fb')>,
#  <CatalogDataset('mbi_education_ad799ddc')>,
#  <CatalogDataset('mbi_education_9a6dbad3')>,
#  <CatalogDataset('mbi_purchasing__fe45fd7e')>,
#  <CatalogDataset('mbi_purchasing__4365e98e')>,
#  <CatalogDataset('mbi_sociodemogr_912e37f6')>,
#  <CatalogDataset('mbi_sociodemogr_2073d4a2')>,
#  <CatalogDataset('mbi_retail_turn_c31c6fd5')>,
#  <CatalogDataset('mbi_sociodemogr_c8a359a6')>,
#  <CatalogDataset('mbi_sociodemogr_df1232aa')>,
#  <CatalogDataset('mbi_sociodemogr_33e67434')>,
#  <CatalogDataset('mbi_sociodemogr_d0cc3e11')>,
#  <CatalogDataset('mbi_sociodemogr_11c28cc3')>,
#  <CatalogDataset('mbi_sociodemogr_d6a755ae')>,
#  <CatalogDataset('mbi_sociodemogr_b9222c39')>,
#  <CatalogDataset('mbi_purchasing__9ffcbef')>,
#  <CatalogDataset('mbi_purchasing__e1edcb5a')>,
#  <CatalogDataset('mbi_purchasing__82d6f267')>,
#  <CatalogDataset('mbi_purchasing__53ab279d')>,
#  <CatalogDataset('mbi_marital_sta_a6132310')>,
#  <CatalogDataset('mbi_purchasing__ed8227b2')>,
#  <CatalogDataset('mbi_sociodemogr_92529d1d')>,
#  <CatalogDataset('mbi_sociodemogr_e9ed3c58')>,
#  <CatalogDataset('mbi_consumer_sp_2bd4a1f6')>,
#  <CatalogDataset('mbi_sociodemogr_f2d3604c')>,
#  <CatalogDataset('mbi_sociodemogr_d2a61be7')>,
#  <CatalogDataset('mbi_sociodemogr_8bd99ff')>,
#  <CatalogDataset('mbi_purchasing__82128cc6')>,
#  <CatalogDataset('mbi_sociodemogr_aecacd23')>,
#  <CatalogDataset('mbi_purchasing__b9a967eb')>,
#  <CatalogDataset('mbi_sociodemogr_a0e97ed9')>,
#  <CatalogDataset('mbi_purchasing__13bb4b3b')>,
#  ...]

# %%
from cartoframes.data.observatory import CatalogDataset

isinstance(demographics_datasets[0], CatalogDataset)
# Out:
# True

# %% [markdown]
# Again, we can export the data as a pandas' DataFrame:

# %%
demographics_datasets.to_dataframe().iloc[0]
# Out:
# category_id                                                   demographics
# category_name                                                 Demographics
# country_id                                                             usa
# data_source_id                                                         acs
# description                                                           None
# geography_description                                                 None
# geography_id             carto-do-public-data.tiger.geography_usa_pumac...
# geography_name           Topologically Integrated Geographic Encoding a...
# id                       carto-do-public-data.acs.demographics_acs_usa_...
# is_public_data                                                        True
# lang                                                                   eng
# name                     American Community Survey (ACS) data at pumacl...
# provider_id                                                      open_data
# provider_name                                                    Open Data
# slug                                                       od_acs_181619a3
# summary_json                                                          None
# temporal_aggregation                                                  5yrs
# time_coverage                                      [2010-01-01,2014-01-01)
# update_frequency                                                      None
# version                                                           20102014
# Name: 0, dtype: object

# %% [markdown]
# And as well as Category, a Dataset can be used to extract related properties:

# %%
d1 = demographics_datasets[0]

d1.country
# Out:
# 'usa'

# %%
vars1 = d1.variables
vars1
# Out:
# [<Variable('households_publ_14c36c88','None')>,
#  <Variable('median_income_c0ef31a5','Within a geographic area, the ...')>,
#  <Variable('income_200000_o_c40255b2','The number of households in a ...')>,
#  <Variable('households_reti_3d9952d0','None')>,
#  <Variable('income_150000_1_28ac2dc2','The number of households in a ...')>,
#  <Variable('income_125000_1_d5f3acbe','The number of households in a ...')>,
#  <Variable('income_100000_1_35b5b31e','The number of households in a ...')>,
#  <Variable('income_75000_99_e304f470','The number of households in a ...')>,
#  <Variable('income_60000_74_89f98648','The number of households in a ...')>,
#  <Variable('income_50000_59_98b16bf4','The number of households in a ...')>,
#  <Variable('income_45000_49_827656c0','The number of households in a ...')>,
#  <Variable('income_40000_44_96354559','The number of households in a ...')>,
#  <Variable('income_35000_39_196d9f53','The number of households in a ...')>,
#  <Variable('less_one_year_c_434945a4','The number of people in a geog...')>,
#  <Variable('high_school_dip_df8ec68b','The number of people in a geog...')>,
#  <Variable('pop_25_years_ov_f071e00','The number of people in a geog...')>,
#  <Variable('male_45_64_grad_ec4dc936','')>,
#  <Variable('male_45_64_bach_6ff2160c','')>,
#  <Variable('male_45_64_asso_86ca6dca','')>,
#  <Variable('male_45_64_high_2ce365c','')>,
#  <Variable('male_45_64_grad_673865d5','')>,
#  <Variable('male_45_to_64_bd2838b2','The male population between th...')>,
#  <Variable('in_undergrad_co_d3bb7269','The number of people in a geog...')>,
#  <Variable('male_45_64_some_e71d541a','')>,
#  <Variable('in_grades_9_to__771a4c96','The total number of people in ...')>,
#  <Variable('in_grades_5_to__1c0808ca','The total number of people in ...')>,
#  <Variable('in_school_b69793d8','The total number of people in ...')>,
#  <Variable('population_3_ye_f19faa0f','The total number of people in ...')>,
#  <Variable('pop_separated_87fa3e8','The number of people in a geog...')>,
#  <Variable('pop_now_married_97527be4','The number of people in a geog...')>,
#  <Variable('female_female_h_14c0754','An unmarried partner is a pers...')>,
#  <Variable('nonfamily_house_ee62d3a0','A householder living alone or ...')>,
#  <Variable('pop_15_and_over_62e59bb6','The number of people in a geog...')>,
#  <Variable('pop_never_marri_9fed0e19','The number of people in a geog...')>,
#  <Variable('median_year_str_b5564410','Median Year Structure Built')>,
#  <Variable('family_househol_87a1363','A family consists of a househo...')>,
#  <Variable('married_househo_dedb3','People in formal marriages, as...')>,
#  <Variable('households_1f79d4d1','A count of the number of house...')>,
#  <Variable('commute_90_more_cec93262','The number of workers in a geo...')>,
#  <Variable('commute_60_89_m_84bcb51a','The number of workers in a geo...')>,
#  <Variable('commute_45_59_m_ab0941a8','The number of workers in a geo...')>,
#  <Variable('commute_40_44_m_fb771c8d','The number of workers in a geo...')>,
#  <Variable('commute_35_39_m_2a056feb','The number of workers in a geo...')>,
#  <Variable('commute_30_34_m_dc0c397a','The number of workers in a geo...')>,
#  <Variable('children_in_sin_ae6045d8','None')>,
#  <Variable('commute_25_29_m_63b00f61','The number of workers in a geo...')>,
#  <Variable('commute_20_24_m_95b959f0','The number of workers in a geo...')>,
#  <Variable('commute_15_19_m_b96faeff','The number of workers in a geo...')>,
#  <Variable('male_45_64_less_681047dc','')>,
#  <Variable('commute_10_14_m_4f66f86e','The number of workers in a geo...')>,
#  <Variable('commute_5_9_min_48bcdf59','The number of workers in a geo...')>,
#  <Variable('commuters_by_pu_97a062b3','The number of workers age 16 y...')>,
#  <Variable('female_10_to_14_5ad3b688','The female population between ...')>,
#  <Variable('black_including_d656e491','')>,
#  <Variable('male_62_64_bd575c1','The male population between th...')>,
#  <Variable('asian_male_45_5_8913b68d','')>,
#  <Variable('four_more_cars_3585ba83','The number of households with ...')>,
#  <Variable('employed_other__9efd68fa','The Other Services (Except Pub...')>,
#  <Variable('employed_arts_e_2d9fc129','The Arts, Entertainment, and R...')>,
#  <Variable('employed_public_99ff927b','The Public Administration sect...')>,
#  <Variable('employed_educat_8ca92c6f','Outpatient health services, ot...')>,
#  <Variable('employed_scienc_2f4b6041','The Administrative and Support...')>,
#  <Variable('occupation_mana_589e9b3b','')>,
#  <Variable('employed_financ_925256','The Real Estate and Rental and...')>,
#  <Variable('employed_inform_e6cc951','The Information sector compris...')>,
#  <Variable('employed_transp_5e4a8017','The Transportation and Warehou...')>,
#  <Variable('employed_retail_8835660a','The Retail Trade sector compri...')>,
#  <Variable('employed_wholes_fb75d2f','The Wholesale Trade sector com...')>,
#  <Variable('occupation_serv_1352402','')>,
#  <Variable('employed_manufa_233b499c','The Manufacturing sector compr...')>,
#  <Variable('employed_constr_b46b4447','The Construction sector compri...')>,
#  <Variable('employed_agricu_dda87125','The Agriculture, Forestry, Fis...')>,
#  <Variable('mortgaged_housi_1741ccf','The count of housing units wit...')>,
#  <Variable('owner_occupied__b6e4295b','The middle value (median) in a...')>,
#  <Variable('million_dollar__d43e3c19','The count of owner occupied ho...')>,
#  <Variable('owner_occupied__9a9ed8e2','')>,
#  <Variable('owner_occupied__62ddb10e','')>,
#  <Variable('income_30000_34_d2e8cca','The number of households in a ...')>,
#  <Variable('income_25000_29_e5836923','The number of households in a ...')>,
#  <Variable('income_20000_24_f1c07aba','The number of households in a ...')>,
#  <Variable('income_15000_19_3bc175f2','The number of households in a ...')>,
#  <Variable('income_10000_14_2f82666b','The number of households in a ...')>,
#  <Variable('poverty_801a1d14','The number of people in a geog...')>,
#  <Variable('pop_determined__618d5784','The number of people in each g...')>,
#  <Variable('income_less_100_8ca587ff','The number of households in a ...')>,
#  <Variable('speak_spanish_a_497897b4','')>,
#  <Variable('dwellings_2_uni_3f372588','')>,
#  <Variable('speak_spanish_a_3e27e70a','The number of people in a geog...')>,
#  <Variable('pop_5_years_ove_da289cde','The number of people in a geog...')>,
#  <Variable('masters_degree_4e9dc92f','The number of people in a geog...')>,
#  <Variable('bachelors_degre_7d3f3d6a','The number of people in a geog...')>,
#  <Variable('speak_only_engl_64695679','The number of people in a geog...')>,
#  <Variable('associates_degr_2209648c','The number of people in a geog...')>,
#  <Variable('one_year_more_c_65e5ca7','The number of people in a geog...')>,
#  <Variable('percent_income__e93222ce','Within a geographic area, the ...')>,
#  <Variable('rent_over_50_pe_6f54e264','Gross rent over 50 percent of ...')>,
#  <Variable('rent_40_to_50_p_600cde42','Gross rent from 40.0 to 49.9 p...')>,
#  <Variable('rent_35_to_40_p_41b0f382','Gross rent from 35.0 to 39.9 p...')>,
#  <Variable('rent_30_to_35_p_da7c133f','Gross rent from 30.0 to 34.9 p...')>,
#  <Variable('owner_occupied__cb54507f','')>,
#  <Variable('rent_25_to_30_p_d04796a','Gross rent from 25.0 to 29.9 p...')>,
#  <Variable('rent_burden_not_a046737','Units for which no rent is pai...')>,
#  <Variable('rent_20_to_25_p_9bd6e990','Gross rent from 20.0 to 24.9 p...')>,
#  <Variable('rent_15_to_20_p_cb0ea6a6','Gross rent from 15.0 to 19.9 p...')>,
#  <Variable('rent_10_to_15_p_5929e661','Gross rent from 10.0 to 14.9 p...')>,
#  <Variable('rent_under_10_p_95d30900','Gross rent less than 10 percen...')>,
#  <Variable('renter_occupied_2bd4f22e','')>,
#  <Variable('median_rent_894bdf6b','The median contract rent withi...')>,
#  <Variable('housing_built_1_54089669','A house, an apartment, a mobil...')>,
#  <Variable('group_quarters_eeb54e88','')>,
#  <Variable('housing_built_2_58ee008','A house, an apartment, a mobil...')>,
#  <Variable('housing_built_2_8387b21c','A house, an apartment, a mobil...')>,
#  <Variable('two_parents_not_ed728250','')>,
#  <Variable('mobile_homes_a326a7e2','A manufactured home is defined...')>,
#  <Variable('commuters_by_ca_59f3665','The number of workers age 16 y...')>,
#  <Variable('bachelors_degre_78bb4b2e','The number of people in each g...')>,
#  <Variable('dwellings_1_uni_9b5c73db','This is a 1-unit structure tha...')>,
#  <Variable('dwellings_1_uni_1215eac5','This is a 1-unit structure det...')>,
#  <Variable('vacant_housing__4b179f0d','The count of vacant housing un...')>,
#  <Variable('vacant_housing__ac2412c4','The count of vacant housing un...')>,
#  <Variable('male_21_78f8fadb','The male population with an ag...')>,
#  <Variable('dwellings_10_to_a8b39637','')>,
#  <Variable('black_male_45_5_7b9782c0','')>,
#  <Variable('male_20_fffca4d','The male population with an ag...')>,
#  <Variable('dwellings_5_to__1c0114c3','')>,
#  <Variable('dwellings_3_to__92ebd0e3','')>,
#  <Variable('male_60_61_d1b649c5','The male population between th...')>,
#  <Variable('male_18_to_19_a5efbd6c','The male population between th...')>,
#  <Variable('female_35_to_39_649806d','The female population between ...')>,
#  <Variable('female_30_to_34_2ac0d377','The female population between ...')>,
#  <Variable('hispanic_male_4_610a00a9','')>,
#  <Variable('male_55_to_59_241e1752','The male population between th...')>,
#  <Variable('male_15_to_17_2380f1ab','The male population between th...')>,
#  <Variable('white_male_55_6_68c413f2','')>,
#  <Variable('male_10_to_14_e8b18fb6','The male population between th...')>,
#  <Variable('male_5_to_9_140e0ee8','The male population between th...')>,
#  <Variable('asian_male_55_6_9f5eccfe','')>,
#  <Variable('bachelors_degre_7357b0e7','')>,
#  <Variable('male_under_5_ad3680ef','The male population over the a...')>,
#  <Variable('male_85_and_ove_93e9b00d','The male population of the age...')>,
#  <Variable('female_pop_8bf47638','The number of people within ea...')>,
#  <Variable('male_40_to_44_dd267597','The male population between th...')>,
#  <Variable('commuters_drove_be06bcb4','The number of workers age 16 y...')>,
#  <Variable('sales_office_em_1f70b9a3','The number of employed civilia...')>,
#  <Variable('management_busi_a2997c2b','The number of employed civilia...')>,
#  <Variable('occupation_prod_74756495','')>,
#  <Variable('occupation_natu_1a9aab89','')>,
#  <Variable('occupation_sale_dcac9b74','')>,
#  <Variable('unemployed_pop_7f7185cb','None')>,
#  <Variable('pop_divorced_e2197ddd','The number of people in a geog...')>,
#  <Variable('male_50_to_54_8974448','The male population between th...')>,
#  <Variable('female_22_to_24_68eef381','The female population between ...')>,
#  <Variable('male_45_to_49_f1af268d','The male population between th...')>,
#  <Variable('female_80_to_84_945e16ea','The female population between ...')>,
#  <Variable('pop_widowed_c5edaec1','The number of people in a geog...')>,
#  <Variable('male_80_to_84_263c2fd4','The male population between th...')>,
#  <Variable('male_75_to_79_540d72ad','The male population between th...')>,
#  <Variable('white_male_45_5_7e896981','')>,
#  <Variable('male_70_to_74_788421b7','The male population between th...')>,
#  <Variable('female_21_b38f378','The female population with an ...')>,
#  <Variable('female_20_7c3fc3ee','The female population with an ...')>,
#  <Variable('male_67_to_69_1623525b','The male population between th...')>,
#  <Variable('not_hispanic_po_10fa19cf','The number of people not ident...')>,
#  <Variable('female_67_to_69_a4416b65','The female population between ...')>,
#  <Variable('male_35_to_39_b42bb953','The male population between th...')>,
#  <Variable('white_pop_238b2ed6','The number of people identifyi...')>,
#  <Variable('median_age_2c1a5de8','The median age of all people i...')>,
#  <Variable('hispanic_any_ra_fac9b5f5','')>,
#  <Variable('female_65_to_66_a36167dd','The female population between ...')>,
#  <Variable('male_30_to_34_98a2ea49','The male population between th...')>,
#  <Variable('female_55_to_59_967c2e6c','The female population between ...')>,
#  <Variable('do_date_6d87cebf','None')>,
#  <Variable('female_50_to_54_baf57d76','The female population between ...')>,
#  <Variable('geoidsl_9ee97b97','None')>,
#  <Variable('geoid_83dafc03','None')>,
#  <Variable('geoidsc_e566606','None')>,
#  <Variable('father_in_labor_9377f57d','')>,
#  <Variable('father_one_pare_652d82cc','')>,
#  <Variable('one_parent_fami_226df7b6','')>,
#  <Variable('two_parents_mot_4012074','')>,
#  <Variable('two_parents_fat_9d5855de','')>,
#  <Variable('pop_16_over_3c090251','The number of people in each g...')>,
#  <Variable('two_parents_in__f7bbba86','')>,
#  <Variable('two_parent_fami_52f762c8','')>,
#  <Variable('families_with_y_269b9c51','')>,
#  <Variable('pop_25_64_2573001b','The number of people in each g...')>,
#  <Variable('income_per_capi_4e2b1b93','Per capita income is the mean ...')>,
#  <Variable('gini_index_dff0cb44','The Gini index, or index of in...')>,
#  <Variable('three_cars_5d68539','The number of households with ...')>,
#  <Variable('two_cars_fdba6e6','The number of households with ...')>,
#  <Variable('one_car_df8521da','The number of households with ...')>,
#  <Variable('no_cars_f6aebb9f','The number of households witho...')>,
#  <Variable('in_grades_1_to__8e2f06f7','The total number of people in ...')>,
#  <Variable('aggregate_trave_3e6333f5','The total number of minutes ev...')>,
#  <Variable('commute_60_more_bc5dad13','The number of workers in a geo...')>,
#  <Variable('commute_35_44_m_533c42bb','The number of workers in a geo...')>,
#  <Variable('commute_less_10_fef6b178','The number of workers in a geo...')>,
#  <Variable('commuters_16_ov_85eebb2f','The number of workers in a geo...')>,
#  <Variable('no_car_18f7b480','All people in a geographic are...')>,
#  <Variable('walked_to_work_22a9d215','The number of workers age 16 y...')>,
#  <Variable('children_3dd99e67','The number of people within ea...')>,
#  <Variable('male_male_house_6829b5f8','An unmarried partner is a pers...')>,
#  <Variable('commuters_by_su_9e7b3cb','The number of workers age 16 y...')>,
#  <Variable('commuters_by_bu_3794706','The number of workers age 16 y...')>,
#  <Variable('commuters_by_ca_9b8b9c93','The number of workers age 16 y...')>,
#  <Variable('worked_at_home_4309c526','The count within a geographica...')>,
#  <Variable('workers_16_and__5761bc53','The number of people in each g...')>,
#  <Variable('different_house_29372bfa','All people in a geographic are...')>,
#  <Variable('different_house_e59ae07d','All people in a geographic are...')>,
#  <Variable('population_1_ye_cb37d950','All people, male and female, c...')>,
#  <Variable('graduate_profes_f6f44ed1','')>,
#  <Variable('some_college_an_f647abe8','The number of people in a geog...')>,
#  <Variable('high_school_inc_ac1260db','The number of people in a geog...')>,
#  <Variable('less_than_high__1b9b046','The number of people in a geog...')>,
#  <Variable('not_us_citizen__fcea7be7','The number of people within ea...')>,
#  <Variable('hispanic_pop_a0fde175','The number of people identifyi...')>,
#  <Variable('two_or_more_rac_ab331b68','The number of people identifyi...')>,
#  <Variable('asian_pop_f94b9a69','The number of people identifyi...')>,
#  <Variable('amerindian_pop_9e7332f4','The number of people identifyi...')>,
#  <Variable('black_pop_d39ae537','The number of people identifyi...')>,
#  <Variable('female_85_and_o_1024f5eb','The female population of the a...')>,
#  <Variable('female_70_to_74_cae61889','The female population between ...')>,
#  <Variable('male_65_to_66_11035ee3','The male population between th...')>,
#  <Variable('black_male_55_6_6ddaf8b3','')>,
#  <Variable('asian_including_8f37e71f','')>,
#  <Variable('amerindian_incl_522c82e','')>,
#  <Variable('female_62_to_64_88c8387f','The female population between ...')>,
#  <Variable('female_60_to_61_6f3dddd9','The female population between ...')>,
#  <Variable('female_15_to_17_91e2c895','The female population between ...')>,
#  <Variable('male_25_to_29_619a888c','The male population between th...')>,
#  <Variable('housing_units_r_17082c64','All occupied units which are n...')>,
#  <Variable('occupied_housin_71561246','A housing unit is classified a...')>,
#  <Variable('vacant_housing__ab4a48d2','The count of vacant housing un...')>,
#  <Variable('housing_units_1477d3d5','A count of housing units in ea...')>,
#  <Variable('not_in_labor_fo_4ea53009','The number of people in each g...')>,
#  <Variable('armed_forces_323f02a2','The number of people in each g...')>,
#  <Variable('employed_pop_5d593566','The number of civilians 16 yea...')>,
#  <Variable('civilian_labor__5d821d11','The number of civilians 16 yea...')>,
#  <Variable('pop_in_labor_fo_ad1a321f','The number of people in each g...')>,
#  <Variable('female_under_5_72049656','The female population over the...')>,
#  <Variable('white_including_c3fa3894','')>,
#  <Variable('male_22_to_24_da8ccabf','The male population between th...')>,
#  <Variable('dwellings_50_or_bc4b8334','')>,
#  <Variable('total_pop_48c1175d','The total number of all people...')>,
#  <Variable('dwellings_20_to_9c32bd88','')>,
#  <Variable('female_18_to_19_178d8452','The female population between ...')>,
#  <Variable('female_45_to_49_43cd1fb3','The female population between ...')>,
#  <Variable('female_25_to_29_d3f8b1b2','The female population between ...')>,
#  <Variable('female_75_to_79_e66f4b93','The female population between ...')>,
#  <Variable('hispanic_male_5_77477ada','')>,
#  <Variable('male_pop_c4584463','The number of people within ea...')>,
#  <Variable('other_race_pop_2a3f53bf','The number of people identifyi...')>,
#  <Variable('female_5_to_9_46f77444','The female population between ...')>,
#  <Variable('female_40_to_44_6f444ca9','The female population between ...')>]

# %%
from cartoframes.data.observatory import Variable

isinstance(vars1[0], Variable)
# Out:
# True

# %% [markdown]
# If we already know which dataset we want to recover, we can do so through its id or its slug:

# %%
CatalogDataset.get('od_acs_181619a3').to_dict()
# Out:
# {'id': 'carto-do-public-data.acs.demographics_acs_usa_pumaclipped_2015_5yrs_20102014',
#  'slug': 'od_acs_181619a3',
#  'name': 'American Community Survey (ACS) data at pumaclipped level (2010 - 2014)',
#  'description': None,
#  'country_id': 'usa',
#  'geography_id': 'carto-do-public-data.tiger.geography_usa_pumaclipped_2015',
#  'geography_name': 'Topologically Integrated Geographic Encoding and Referencing (TIGER) boundaries data at pumaclipped level (2015)',
#  'geography_description': None,
#  'category_id': 'demographics',
#  'category_name': 'Demographics',
#  'provider_id': 'open_data',
#  'provider_name': 'Open Data',
#  'data_source_id': 'acs',
#  'lang': 'eng',
#  'temporal_aggregation': '5yrs',
#  'time_coverage': '[2010-01-01,2014-01-01)',
#  'update_frequency': None,
#  'version': '20102014',
#  'is_public_data': True}

# %% [markdown]
# And if we have a list of ids or slugs that we want to get from the catalog, we can obtain them in one call:

# %%
CatalogDataset.get_list(['od_acs_181619a3', 'od_acs_13345497'])
# Out:
# [<CatalogDataset('od_acs_181619a3')>, <CatalogDataset('od_acs_13345497')>]

# %% [markdown]
# ## Navigate through the catalog with filters

# %% [markdown]
# It is possible to navigate the catalog by adding nested filters that will be applied when requesting lists of entities.

# %% [markdown]
# For example, we can add a country filter before requesting the list of datasets and then we will only obtain the datasets from that country:

# %%
from cartoframes.data.observatory import Catalog

catalog = Catalog()

# %%
catalog.country('spain').datasets

# %% [markdown]
# Applied filters are saved in that catalog instance, so if we now add a new filter the list of datasets will be affected by both filters:

# %%
catalog.category('demographics').datasets

# %% [markdown]
# We can also nest the filters in the same call with the same result:

# %%
catalog2 = Catalog()
catalog2.country('spain').category('demographics').datasets

# %% [markdown]
# To remove all past filters, we simply call the method to clear them:

# %%
catalog.clear_filters()
catalog.datasets
# Out:
# [<CatalogDataset('pb_pointsofint_ce35b8b8')>,
#  <CatalogDataset('pb_pointsofint_2cf3538b')>,
#  <CatalogDataset('od_acs_181619a3')>,
#  <CatalogDataset('pb_pointsofint_66b9e4e7')>,
#  <CatalogDataset('pb_pointsofint_8345a948')>,
#  <CatalogDataset('pb_pointsofint_17af1fae')>,
#  <CatalogDataset('pb_pointsofint_624640f3')>,
#  <CatalogDataset('pb_pointsofint_23ff89c4')>,
#  <CatalogDataset('pb_pointsofint_72337606')>,
#  <CatalogDataset('od_acs_550657ce')>,
#  <CatalogDataset('tt_trafficdens_c451dfb9')>,
#  <CatalogDataset('mbi_retail_turn_a40b2d9e')>,
#  <CatalogDataset('pb_pointsofint_2a9f04b8')>,
#  <CatalogDataset('pb_pointsofint_dcb3020c')>,
#  <CatalogDataset('pb_pointsofint_28463f13')>,
#  <CatalogDataset('od_acs_6e4b69f6')>,
#  <CatalogDataset('pb_pointsofint_50c122ed')>,
#  <CatalogDataset('mbi_purchasing__ff4ce909')>,
#  <CatalogDataset('mbi_population_73b2034')>,
#  <CatalogDataset('mbi_population_bf3a91db')>,
#  <CatalogDataset('pb_pointsofint_fd812dbc')>,
#  <CatalogDataset('pb_pointsofint_c6e8d9ca')>,
#  <CatalogDataset('pb_pointsofint_d3a292a5')>,
#  <CatalogDataset('pb_pointsofint_143d9f4c')>,
#  <CatalogDataset('pb_pointsofint_b4979de6')>,
#  <CatalogDataset('pb_pointsofint_4dba29dd')>,
#  <CatalogDataset('pb_pointsofint_c096e980')>,
#  <CatalogDataset('pb_pointsofint_7491a6e1')>,
#  <CatalogDataset('pb_pointsofint_da959db3')>,
#  <CatalogDataset('pb_pointsofint_bbf97d90')>,
#  <CatalogDataset('pb_pointsofint_16918074')>,
#  <CatalogDataset('pb_pointsofint_d92daabb')>,
#  <CatalogDataset('pb_pointsofint_27835e04')>,
#  <CatalogDataset('pb_pointsofint_33af2544')>,
#  <CatalogDataset('pb_pointsofint_ef1fa43d')>,
#  <CatalogDataset('pb_pointsofint_ca4642e7')>,
#  <CatalogDataset('pb_pointsofint_4d51347c')>,
#  <CatalogDataset('pb_pointsofint_d9bb829a')>,
#  <CatalogDataset('pb_pointsofint_8709bf08')>,
#  <CatalogDataset('pb_pointsofint_ec449f87')>,
#  <CatalogDataset('pb_pointsofint_1f58c936')>,
#  <CatalogDataset('pb_pointsofint_d0f68480')>,
#  <CatalogDataset('pb_pointsofint_15886251')>,
#  <CatalogDataset('pb_pointsofint_c1cf35b0')>,
#  <CatalogDataset('pb_pointsofint_44d2b5b2')>,
#  <CatalogDataset('pb_pointsofint_d717fe3d')>,
#  <CatalogDataset('pb_pointsofint_aba4b9d0')>,
#  <CatalogDataset('pb_pointsofint_662d8999')>,
#  <CatalogDataset('pb_pointsofint_c44e92be')>,
#  <CatalogDataset('pb_pointsofint_f95c2f51')>,
#  <CatalogDataset('pb_pointsofint_d28302c6')>,
#  <CatalogDataset('pb_pointsofint_df690f3d')>,
#  <CatalogDataset('pb_pointsofint_530e7429')>,
#  <CatalogDataset('pb_pointsofint_5b2e5fb')>,
#  <CatalogDataset('pb_pointsofint_ec2e874')>,
#  <CatalogDataset('pb_pointsofint_180f780c')>,
#  <CatalogDataset('pb_pointsofint_3dc0b6f7')>,
#  <CatalogDataset('pb_pointsofint_d937dcd1')>,
#  <CatalogDataset('pb_pointsofint_a917a951')>,
#  <CatalogDataset('pb_pointsofint_2c5a97b5')>,
#  <CatalogDataset('mc_mrli_323ee6ba')>,
#  <CatalogDataset('od_acs_9510981d')>,
#  <CatalogDataset('od_acs_6d43ed82')>,
#  <CatalogDataset('pb_pointsofint_d65e002b')>,
#  <CatalogDataset('pb_pointsofint_5fcfbdfd')>,
#  <CatalogDataset('pb_pointsofint_30081df5')>,
#  <CatalogDataset('pb_pointsofint_50fc8bad')>,
#  <CatalogDataset('pb_pointsofint_3659e386')>,
#  <CatalogDataset('pb_pointsofint_fe3e2638')>,
#  <CatalogDataset('pb_pointsofint_74fcb147')>,
#  <CatalogDataset('pb_pointsofint_dc65b6ed')>,
#  <CatalogDataset('od_acs_194c5960')>,
#  <CatalogDataset('mbi_population_552f1d19')>,
#  <CatalogDataset('mbi_population_70c11317')>,
#  <CatalogDataset('mbi_population_c207835a')>,
#  <CatalogDataset('mbi_population_8b8bf92b')>,
#  <CatalogDataset('mbi_education_3d6776b9')>,
#  <CatalogDataset('mbi_retail_turn_36a9dbe1')>,
#  <CatalogDataset('mbi_population_af1d83ba')>,
#  <CatalogDataset('mbi_retail_cent_ac0457a5')>,
#  <CatalogDataset('mbi_purchasing__c9645e12')>,
#  <CatalogDataset('pb_pointsofint_f7b0cf36')>,
#  <CatalogDataset('pb_pointsofint_134df15c')>,
#  <CatalogDataset('pb_pointsofint_ba4c808d')>,
#  <CatalogDataset('pb_pointsofint_18c4860b')>,
#  <CatalogDataset('pb_pointsofint_c3b3079')>,
#  <CatalogDataset('pb_pointsofint_4fe870b1')>,
#  <CatalogDataset('pb_pointsofint_e74e9b04')>,
#  <CatalogDataset('pb_pointsofint_482ed526')>,
#  <CatalogDataset('pb_pointsofint_7741ff9c')>,
#  <CatalogDataset('pb_pointsofint_13f6521b')>,
#  <CatalogDataset('pb_pointsofint_f5989f56')>,
#  <CatalogDataset('pb_pointsofint_61fc32a4')>,
#  <CatalogDataset('pb_pointsofint_16b163d2')>,
#  <CatalogDataset('od_acs_38016c42')>,
#  <CatalogDataset('pb_pointsofint_6881f53e')>,
#  <CatalogDataset('pb_pointsofint_f6aeb34a')>,
#  <CatalogDataset('pb_pointsofint_25db5324')>,
#  <CatalogDataset('pb_pointsofint_e852636d')>,
#  <CatalogDataset('pb_pointsofint_8a205de7')>,
#  <CatalogDataset('pb_pointsofint_ab3a80e2')>,
#  <CatalogDataset('pb_pointsofint_2313a8e9')>,
#  <CatalogDataset('pb_pointsofint_6370ce3a')>,
#  <CatalogDataset('pb_pointsofint_d73558c4')>,
#  <CatalogDataset('pb_pointsofint_710023c9')>,
#  <CatalogDataset('pb_pointsofint_f4db350c')>,
#  <CatalogDataset('pb_pointsofint_e0e52935')>,
#  <CatalogDataset('pb_pointsofint_7f88fa2')>,
#  <CatalogDataset('pb_pointsofint_82239967')>,
#  <CatalogDataset('pb_pointsofint_11de027b')>,
#  <CatalogDataset('pb_pointsofint_1e13727f')>,
#  <CatalogDataset('pb_pointsofint_93f924e5')>,
#  <CatalogDataset('pb_pointsofint_2126b26f')>,
#  <CatalogDataset('pb_pointsofint_8da9492f')>,
#  <CatalogDataset('pb_pointsofint_92b83da')>,
#  <CatalogDataset('pb_pointsofint_98002bb')>,
#  <CatalogDataset('od_acs_9a9c93b8')>,
#  <CatalogDataset('pb_pointsofint_31906b8e')>,
#  <CatalogDataset('pb_pointsofint_2d0ec92')>,
#  <CatalogDataset('pb_pointsofint_8191fa23')>,
#  <CatalogDataset('pb_pointsofint_7fac5f6e')>,
#  <CatalogDataset('pb_pointsofint_b02f99be')>,
#  <CatalogDataset('pb_pointsofint_110dcf49')>,
#  <CatalogDataset('od_acs_7b2649a9')>,
#  <CatalogDataset('od_acs_478c37b8')>,
#  <CatalogDataset('od_acs_f98ddfce')>,
#  <CatalogDataset('pb_pointsofint_2a8572d2')>,
#  <CatalogDataset('pb_pointsofint_b3435f08')>,
#  <CatalogDataset('od_acs_1f614ee8')>,
#  <CatalogDataset('mbi_sociodemogr_1469299e')>,
#  <CatalogDataset('mbi_retail_spen_c749c2ee')>,
#  <CatalogDataset('od_acs_8b00f653')>,
#  <CatalogDataset('od_acs_d52a0635')>,
#  <CatalogDataset('od_acs_1deaa51')>,
#  <CatalogDataset('od_acs_e0f5ff55')>,
#  <CatalogDataset('pb_pointsofint_4114b2f0')>,
#  <CatalogDataset('pb_pointsofint_4a8fa2de')>,
#  <CatalogDataset('pb_pointsofint_4255ff20')>,
#  <CatalogDataset('pb_pointsofint_f729ca88')>,
#  <CatalogDataset('pb_pointsofint_aa24fc9e')>,
#  <CatalogDataset('pb_pointsofint_b4d82cb9')>,
#  <CatalogDataset('pb_pointsofint_56c75ef4')>,
#  <CatalogDataset('pb_pointsofint_4e9436f4')>,
#  <CatalogDataset('pb_pointsofint_147757c0')>,
#  <CatalogDataset('pb_pointsofint_d11bd668')>,
#  <CatalogDataset('pb_pointsofint_136746b6')>,
#  <CatalogDataset('pb_pointsofint_aff2d9fa')>,
#  <CatalogDataset('pb_pointsofint_6c61078')>,
#  <CatalogDataset('bbva_consumption_919b0517')>,
#  <CatalogDataset('mc_mrli_35402a9d')>,
#  <CatalogDataset('mc_mrli_3e9a0d24')>,
#  <CatalogDataset('pb_pointsofint_1f0066c3')>,
#  <CatalogDataset('pb_pointsofint_a128259')>,
#  <CatalogDataset('pb_pointsofint_a67b0c78')>,
#  <CatalogDataset('pb_pointsofint_17c85c44')>,
#  <CatalogDataset('pb_pointsofint_a505adb7')>,
#  <CatalogDataset('pb_pointsofint_ff2766c8')>,
#  <CatalogDataset('od_acs_52710085')>,
#  <CatalogDataset('pb_pointsofint_589f304b')>,
#  <CatalogDataset('pb_pointsofint_81d166e3')>,
#  <CatalogDataset('od_acs_b3eac6e8')>,
#  <CatalogDataset('mbi_households__6e377f70')>,
#  <CatalogDataset('od_acs_1a09274c')>,
#  <CatalogDataset('bbva_basicstats_4da92e6a')>,
#  <CatalogDataset('pb_pointsofint_34df4b54')>,
#  <CatalogDataset('pb_pointsofint_a9c358ef')>,
#  <CatalogDataset('mc_mrli_4579ab81')>,
#  <CatalogDataset('pb_pointsofint_f9a710d6')>,
#  <CatalogDataset('pb_pointsofint_20e9467e')>,
#  <CatalogDataset('pb_pointsofint_dd73db82')>,
#  <CatalogDataset('mbi_retail_spen_74ef7398')>,
#  <CatalogDataset('pb_pointsofint_215cbb63')>,
#  <CatalogDataset('pb_pointsofint_7ea53db8')>,
#  <CatalogDataset('pb_pointsofint_9c88cb2a')>,
#  <CatalogDataset('pb_pointsofint_27eb3071')>,
#  <CatalogDataset('pb_pointsofint_81e1a763')>,
#  <CatalogDataset('pb_pointsofint_434efa8f')>,
#  <CatalogDataset('pb_pointsofint_d88221cc')>,
#  <CatalogDataset('pb_pointsofint_f2c57a20')>,
#  <CatalogDataset('pb_pointsofint_1342dcc3')>,
#  <CatalogDataset('pb_pointsofint_7a1f7cbf')>,
#  <CatalogDataset('pb_pointsofint_4e9c27e7')>,
#  <CatalogDataset('pb_pointsofint_c59e6916')>,
#  <CatalogDataset('pb_pointsofint_127b7f95')>,
#  <CatalogDataset('pb_pointsofint_1071890c')>,
#  <CatalogDataset('pb_pointsofint_62336460')>,
#  <CatalogDataset('pb_pointsofint_1be6f7b')>,
#  <CatalogDataset('pb_pointsofint_178f9bc')>,
#  <CatalogDataset('pb_pointsofint_83725444')>,
#  <CatalogDataset('pb_pointsofint_d5dca2ef')>,
#  <CatalogDataset('pb_pointsofint_213cc405')>,
#  <CatalogDataset('pb_pointsofint_a25059d2')>,
#  <CatalogDataset('pb_pointsofint_89a2ff23')>,
#  <CatalogDataset('pb_pointsofint_193e41d')>,
#  <CatalogDataset('pb_pointsofint_87365317')>,
#  <CatalogDataset('pb_pointsofint_50d34594')>,
#  <CatalogDataset('pb_pointsofint_bd33c302')>,
#  <CatalogDataset('pb_pointsofint_4f49a59c')>,
#  <CatalogDataset('pb_pointsofint_2f437590')>,
#  <CatalogDataset('mbi_retail_spen_bdbc88f4')>,
#  <CatalogDataset('mbi_retail_spen_9d8d164c')>,
#  <CatalogDataset('mbi_households__400e1f2')>,
#  <CatalogDataset('mbi_sociodemogr_241fcfe')>,
#  <CatalogDataset('mbi_consumer_sp_804ae09f')>,
#  <CatalogDataset('mbi_sociodemogr_59f19c8f')>,
#  <CatalogDataset('mbi_households__bc93fe13')>,
#  <CatalogDataset('ags_sociodemogr_e92b1637')>,
#  <CatalogDataset('pb_pointsofint_26f824cd')>,
#  <CatalogDataset('pb_pointsofint_69df1582')>,
#  <CatalogDataset('pb_pointsofint_e47af247')>,
#  <CatalogDataset('pb_pointsofint_6b3efeba')>,
#  <CatalogDataset('pb_pointsofint_618b58a')>,
#  <CatalogDataset('pb_pointsofint_82d78b7f')>,
#  <CatalogDataset('mbi_sociodemogr_7e5d7713')>,
#  <CatalogDataset('ags_consumerspe_fe5d060a')>,
#  <CatalogDataset('od_acs_e8a7d88d')>,
#  <CatalogDataset('od_epa_c006dd7d')>,
#  <CatalogDataset('pb_pointsofint_89c28045')>,
#  <CatalogDataset('vdf_footfall_c3eda566')>,
#  <CatalogDataset('vdf_odmatrix_93a2c970')>,
#  <CatalogDataset('mbi_sociodemogr_aaac5fe9')>,
#  <CatalogDataset('uc_pure_9df82704')>,
#  <CatalogDataset('mc_mrli_c044b645')>,
#  <CatalogDataset('uc_pure_5a167789')>,
#  <CatalogDataset('mbi_purchasing__3be4e0c8')>,
#  <CatalogDataset('od_acs_60614ff2')>,
#  <CatalogDataset('od_acs_f09b24f4')>,
#  <CatalogDataset('pb_pointsofint_ad3bc077')>,
#  <CatalogDataset('pb_pointsofint_f84d7eb2')>,
#  <CatalogDataset('pb_pointsofint_f8c10b50')>,
#  <CatalogDataset('uc_pure_cbc056f')>,
#  <CatalogDataset('uc_pure_4c47bfb2')>,
#  <CatalogDataset('od_acs_1cfa643a')>,
#  <CatalogDataset('od_acs_c4a00c26')>,
#  <CatalogDataset('od_acs_c1c86582')>,
#  <CatalogDataset('od_acs_5b8fdefd')>,
#  <CatalogDataset('mbi_sociodemogr_8a7b040c')>,
#  <CatalogDataset('mbi_sociodemogr_edae8408')>,
#  <CatalogDataset('mbi_sociodemogr_61abe88c')>,
#  <CatalogDataset('mbi_sociodemogr_63544b8')>,
#  <CatalogDataset('bbva_basicstats_7f331208')>,
#  <CatalogDataset('mbi_consumer_sp_98c8591e')>,
#  <CatalogDataset('bbva_categorydis_3c562aef')>,
#  <CatalogDataset('bbva_consumption_e9dcead')>,
#  <CatalogDataset('u360_demographic_94266d3')>,
#  <CatalogDataset('od_spielmansin_5d03106a')>,
#  <CatalogDataset('pb_pointsofint_de55d5b8')>,
#  <CatalogDataset('mbi_education_fcd214dd')>,
#  <CatalogDataset('mbi_households__109a963')>,
#  <CatalogDataset('mbi_sociodemogr_a260b8a8')>,
#  <CatalogDataset('mbi_education_b38f515')>,
#  <CatalogDataset('bbva_categorydis_2b5f9771')>,
#  <CatalogDataset('bbva_consumption_acbc3787')>,
#  <CatalogDataset('bbva_consumption_a86648df')>,
#  <CatalogDataset('mbi_sociodemogr_e7e8c988')>,
#  <CatalogDataset('pb_pointsofint_706e02f5')>,
#  <CatalogDataset('bbva_categorydis_72676c1a')>,
#  <CatalogDataset('bbva_basicstats_5f79cb93')>,
#  <CatalogDataset('od_acs_c2868f47')>,
#  <CatalogDataset('od_acs_b581bfd1')>,
#  <CatalogDataset('pb_pointsofint_21a0b868')>,
#  <CatalogDataset('pb_pointsofint_74dc52e1')>,
#  <CatalogDataset('pb_pointsofint_c2727b6b')>,
#  <CatalogDataset('pb_pointsofint_411ee6bc')>,
#  <CatalogDataset('pb_pointsofint_3bbe86bd')>,
#  <CatalogDataset('pb_pointsofint_2dbaad9d')>,
#  <CatalogDataset('mbi_sociodemogr_93d4a324')>,
#  <CatalogDataset('bbva_origindistr_8be145e8')>,
#  <CatalogDataset('mbi_purchasing__23143aac')>,
#  <CatalogDataset('od_acs_2d438a42')>,
#  <CatalogDataset('od_acs_c6bf32c9')>,
#  <CatalogDataset('od_acs_91ff81e3')>,
#  <CatalogDataset('od_epa_307e4909')>,
#  <CatalogDataset('mbi_purchasing__2f0c36fb')>,
#  <CatalogDataset('bbva_origindistr_e193b122')>,
#  <CatalogDataset('od_acs_13345497')>,
#  <CatalogDataset('od_acs_87fa66db')>,
#  <CatalogDataset('mbi_population_fbcd3b85')>,
#  <CatalogDataset('sg_patterns_183b05f1')>,
#  <CatalogDataset('mbi_sociodemogr_4066dd40')>,
#  <CatalogDataset('mbi_consumer_sp_fba12e82')>,
#  <CatalogDataset('od_acs_b98db80e')>,
#  <CatalogDataset('od_acs_9f4d1f13')>,
#  <CatalogDataset('od_acs_5b67fbbf')>,
#  <CatalogDataset('od_acs_29664073')>,
#  <CatalogDataset('mbi_population_deffab10')>,
#  <CatalogDataset('mbi_population_685846c7')>,
#  <CatalogDataset('mbi_consumer_sp_aa8046fd')>,
#  <CatalogDataset('od_acs_4bb9b377')>,
#  <CatalogDataset('od_acs_aa92e673')>,
#  <CatalogDataset('od_acs_1db77442')>,
#  <CatalogDataset('od_acs_9df157a1')>,
#  <CatalogDataset('bbva_origindistr_905335a8')>,
#  <CatalogDataset('mbi_population_c738f69c')>,
#  <CatalogDataset('od_acs_f3eaa128')>,
#  <CatalogDataset('od_tiger_19a6dc83')>,
#  <CatalogDataset('mbi_sociodemogr_7cf425e1')>,
#  <CatalogDataset('od_tiger_e5e51d96')>,
#  <CatalogDataset('od_tiger_41814018')>,
#  <CatalogDataset('od_tiger_b0608dc7')>,
#  <CatalogDataset('bbva_origindistr_3c1360f')>,
#  <CatalogDataset('mbi_consumer_sp_95cb4e50')>,
#  <CatalogDataset('mbi_consumer_sp_cdb8f12d')>,
#  <CatalogDataset('bbva_origindistr_66ff6183')>,
#  <CatalogDataset('od_acs_1a22afad')>,
#  <CatalogDataset('mc_mrli_51f61301')>,
#  <CatalogDataset('mc_mrli_c028d508')>,
#  <CatalogDataset('mc_mrli_7300555a')>,
#  <CatalogDataset('ags_retailpoten_ddf56a1a')>,
#  <CatalogDataset('mc_mrli_3c4ccbfc')>,
#  <CatalogDataset('mbi_households__a33ccbc4')>,
#  <CatalogDataset('ags_consumerpro_e8344e2e')>,
#  <CatalogDataset('u360_cadastersoc_a77aa6d9')>,
#  <CatalogDataset('ags_climateandw_cffac915')>,
#  <CatalogDataset('mbi_population_731c061e')>,
#  <CatalogDataset('mbi_population_37484b32')>,
#  <CatalogDataset('u360_cadaster_b738bf45')>,
#  <CatalogDataset('u360_touristicin_463a7b9e')>,
#  <CatalogDataset('u360_pedestriant_4757ec23')>,
#  <CatalogDataset('u360_commerciali_7694276b')>,
#  <CatalogDataset('bbva_basicstats_26e0eb21')>,
#  <CatalogDataset('mbi_purchasing__958db7d5')>,
#  <CatalogDataset('mbi_purchasing__448a9698')>,
#  <CatalogDataset('mbi_sociodemogr_9c07d454')>,
#  <CatalogDataset('mbi_sociodemogr_216c9a35')>,
#  <CatalogDataset('mbi_sociodemogr_6ee94536')>,
#  <CatalogDataset('mbi_sociodemogr_1c07f6d8')>,
#  <CatalogDataset('mbi_marital_sta_d63ec9b1')>,
#  <CatalogDataset('mbi_sociodemogr_81866af0')>,
#  <CatalogDataset('mbi_purchasing__7c3d7271')>,
#  <CatalogDataset('mbi_population_f6d646f1')>,
#  <CatalogDataset('mbi_marital_sta_e24fdd88')>,
#  <CatalogDataset('bbva_categorydis_2c78356')>,
#  <CatalogDataset('ags_businesscou_a8310a11')>,
#  <CatalogDataset('u360_workingpopu_ac666c1f')>,
#  <CatalogDataset('od_acs_dc3cfd0f')>,
#  <CatalogDataset('od_acs_5c10acf4')>,
#  <CatalogDataset('bbva_destination_b4858a78')>,
#  <CatalogDataset('mbi_education_5ae6af16')>,
#  <CatalogDataset('mbi_marital_sta_9f4f5206')>,
#  <CatalogDataset('bbva_destination_21e279d')>,
#  <CatalogDataset('mbi_population_f8f49fc')>,
#  <CatalogDataset('mbi_consumer_sp_735399ae')>,
#  <CatalogDataset('mbi_consumer_sp_7915d42e')>,
#  <CatalogDataset('mbi_households__45067b14')>,
#  <CatalogDataset('mbi_population_47bba1ac')>,
#  <CatalogDataset('mbi_population_83dbf8d6')>,
#  <CatalogDataset('mbi_consumer_sp_2fad0fe5')>,
#  <CatalogDataset('mbi_consumer_sp_bf918793')>,
#  <CatalogDataset('mbi_consumer_sp_ff56f52a')>,
#  <CatalogDataset('mbi_consumer_sp_f0145890')>,
#  <CatalogDataset('mbi_consumer_sp_82faeb7e')>,
#  <CatalogDataset('mbi_sociodemogr_898c773b')>,
#  <CatalogDataset('mbi_consumer_sp_1f7b7756')>,
#  <CatalogDataset('mbi_sociodemogr_2bf0faf3')>,
#  <CatalogDataset('mbi_consumer_sp_9a029b9')>,
#  <CatalogDataset('mbi_purchasing__44de421')>,
#  <CatalogDataset('mbi_purchasing__c2c9b79c')>,
#  <CatalogDataset('mbi_purchasing__9008c244')>,
#  <CatalogDataset('mbi_purchasing__7664929f')>,
#  <CatalogDataset('mbi_purchasing__87256cc1')>,
#  <CatalogDataset('mbi_purchasing__c90e0015')>,
#  <CatalogDataset('mc_mrli_359ae0b8')>,
#  <CatalogDataset('mbi_marital_sta_6576ce40')>,
#  <CatalogDataset('mc_mrli_cdabd5c6')>,
#  <CatalogDataset('mbi_purchasing__5b7c0907')>,
#  <CatalogDataset('mbi_education_c5c0352d')>,
#  <CatalogDataset('od_acs_d28e63ff')>,
#  <CatalogDataset('mc_mrli_12ec28f')>,
#  <CatalogDataset('mbi_consumer_sp_35d0adfe')>,
#  <CatalogDataset('mbi_purchasing__b926aa40')>,
#  <CatalogDataset('mbi_consumer_sp_8038837a')>,
#  <CatalogDataset('mbi_consumer_sp_148619aa')>,
#  <CatalogDataset('mbi_purchasing__59d55bf5')>,
#  <CatalogDataset('mbi_consumer_sp_72d263a7')>,
#  <CatalogDataset('mbi_purchasing__4bc83b22')>,
#  <CatalogDataset('mbi_purchasing__392688cc')>,
#  <CatalogDataset('mbi_consumer_sp_2fac9f2')>,
#  <CatalogDataset('mbi_purchasing__a4a714e4')>,
#  <CatalogDataset('ags_sociodemogr_e128078d')>,
#  <CatalogDataset('ags_crimerisk_9ec89442')>,
#  <CatalogDataset('pb_pointsofint_5b291765')>,
#  <CatalogDataset('uc_pure_21fe1bc5')>,
#  <CatalogDataset('uc_pure_7a581069')>,
#  <CatalogDataset('uc_pure_2f216276')>,
#  <CatalogDataset('uc_pure_547b67ab')>,
#  <CatalogDataset('uc_pure_c68de1c8')>,
#  <CatalogDataset('uc_pure_6198d758')>,
#  <CatalogDataset('uc_pure_31261faf')>,
#  <CatalogDataset('uc_pure_e1f837dd')>,
#  <CatalogDataset('uc_pure_48f8859a')>,
#  <CatalogDataset('uc_pure_62d0478c')>,
#  <CatalogDataset('uc_pure_f30913a7')>,
#  <CatalogDataset('uc_pure_88f58335')>,
#  <CatalogDataset('uc_pure_f2c9fc7a')>,
#  <CatalogDataset('mbi_sociodemogr_c9711f1c')>,
#  <CatalogDataset('uc_pure_c9171dd9')>,
#  <CatalogDataset('uc_pure_abf9728d')>,
#  <CatalogDataset('mbi_purchasing__ee2d67ac')>,
#  <CatalogDataset('mbi_sociodemogr_61df236e')>,
#  <CatalogDataset('uc_pure_dbba9830')>,
#  <CatalogDataset('uc_pure_f03ff1eb')>,
#  <CatalogDataset('uc_pure_3477f9b0')>,
#  <CatalogDataset('uc_pure_f7d04728')>,
#  <CatalogDataset('uc_pure_11bbb52f')>,
#  <CatalogDataset('uc_pure_6bf3be74')>,
#  <CatalogDataset('uc_pure_bae0b501')>,
#  <CatalogDataset('uc_pure_a1f3bf50')>,
#  <CatalogDataset('uc_pure_62177632')>,
#  <CatalogDataset('uc_pure_9eccf4b')>,
#  <CatalogDataset('uc_pure_d74a27fe')>,
#  <CatalogDataset('uc_pure_16b70734')>,
#  <CatalogDataset('mbi_consumer_sp_e2093847')>,
#  <CatalogDataset('uc_pure_6b1c5a4d')>,
#  <CatalogDataset('uc_activity_c1a47695')>,
#  <CatalogDataset('uc_activity_59eb19d9')>,
#  <CatalogDataset('od_acs_a9825694')>,
#  <CatalogDataset('od_tiger_5e55275d')>,
#  <CatalogDataset('od_acs_a665f9e1')>,
#  <CatalogDataset('od_acs_5ec6965e')>,
#  <CatalogDataset('od_acs_f2f40516')>,
#  <CatalogDataset('od_acs_1209a7e9')>,
#  <CatalogDataset('pb_pointsofint_dbc49bb')>,
#  <CatalogDataset('od_acs_6c9090b5')>,
#  <CatalogDataset('od_acs_f9681e48')>,
#  <CatalogDataset('od_acs_8c8516b')>,
#  <CatalogDataset('od_acs_59534db1')>,
#  <CatalogDataset('od_acs_57d06d64')>,
#  <CatalogDataset('mc_mrli_58fa8579')>,
#  <CatalogDataset('mc_mrli_60cab294')>,
#  <CatalogDataset('od_acs_e9e3046f')>,
#  <CatalogDataset('od_acs_506e3e6a')>,
#  <CatalogDataset('od_acs_b4cbd26')>,
#  <CatalogDataset('od_acs_fc07c6c5')>,
#  <CatalogDataset('od_acs_a1083df8')>,
#  <CatalogDataset('od_acs_6bfd54ac')>,
#  <CatalogDataset('od_tiger_f9247903')>,
#  <CatalogDataset('od_acs_abd63a91')>,
#  <CatalogDataset('mbi_households__981be2e8')>,
#  <CatalogDataset('od_acs_e1b123b7')>,
#  <CatalogDataset('od_acs_c31e5f28')>,
#  <CatalogDataset('od_tiger_476ce2e9')>,
#  <CatalogDataset('od_tiger_fac69779')>,
#  <CatalogDataset('od_tiger_384d0b09')>,
#  <CatalogDataset('od_acs_7c4b8db0')>,
#  <CatalogDataset('od_acs_eaf66737')>,
#  <CatalogDataset('od_lodes_b4b9dfac')>,
#  <CatalogDataset('od_acs_17667f64')>,
#  <CatalogDataset('od_acs_8c6d324a')>,
#  <CatalogDataset('od_acs_d60f0d6e')>,
#  <CatalogDataset('od_tiger_e10059f')>,
#  <CatalogDataset('od_acs_4f56aa89')>,
#  <CatalogDataset('od_acs_d9e8a21b')>,
#  <CatalogDataset('mbi_education_821a28eb')>,
#  <CatalogDataset('mbi_sociodemogr_b1501243')>,
#  <CatalogDataset('mbi_sociodemogr_b529bc50')>,
#  <CatalogDataset('mbi_sociodemogr_5345ec8b')>,
#  <CatalogDataset('od_acs_c5eb4b5e')>,
#  <CatalogDataset('od_tiger_3336cbf')>,
#  <CatalogDataset('mbi_sociodemogr_ec2f7e01')>,
#  <CatalogDataset('od_acs_de856602')>,
#  <CatalogDataset('od_acs_5978c550')>,
#  <CatalogDataset('mbi_sociodemogr_684ad049')>,
#  <CatalogDataset('mbi_sociodemogr_27d9ea78')>,
#  <CatalogDataset('mbi_sociodemogr_b3653f6')>,
#  <CatalogDataset('od_epa_de702825')>,
#  <CatalogDataset('od_tiger_66b9092c')>,
#  <CatalogDataset('od_acs_db9898c5')>,
#  <CatalogDataset('od_acs_670c8beb')>,
#  <CatalogDataset('od_acs_6926adef')>,
#  <CatalogDataset('pb_pointsofint_7a783f55')>,
#  <CatalogDataset('mbi_purchasing__c88ffa1c')>,
#  <CatalogDataset('mbi_education_cc926c54')>,
#  <CatalogDataset('mbi_education_762e04ae')>,
#  <CatalogDataset('mbi_population_678f3375')>,
#  <CatalogDataset('mbi_purchasing__94716c57')>,
#  <CatalogDataset('mbi_purchasing__2e172de2')>,
#  <CatalogDataset('mbi_purchasing__af5a7a18')>,
#  <CatalogDataset('mbi_education_1d29e506')>,
#  <CatalogDataset('mbi_education_bac941f7')>,
#  <CatalogDataset('mbi_purchasing__4d6bae5d')>,
#  <CatalogDataset('mbi_purchasing__8e0cce4c')>,
#  <CatalogDataset('mbi_education_8f53024')>,
#  <CatalogDataset('mbi_education_1b4edb2e')>,
#  <CatalogDataset('mbi_education_227ba9ac')>,
#  <CatalogDataset('mbi_consumer_sp_17716a9d')>,
#  <CatalogDataset('mbi_consumer_sp_f6b7cdef')>,
#  <CatalogDataset('mbi_population_954f45aa')>,
#  <CatalogDataset('mbi_population_63cf59c9')>,
#  <CatalogDataset('mbi_population_1b846234')>,
#  <CatalogDataset('mbi_education_50ded682')>,
#  <CatalogDataset('mbi_marital_sta_a0d1c86b')>,
#  <CatalogDataset('mbi_retail_cent_9fddd44a')>,
#  <CatalogDataset('mbi_education_54220c21')>,
#  <CatalogDataset('mbi_retail_spen_928a0453')>,
#  <CatalogDataset('mbi_retail_spen_1f4f5cc4')>,
#  <CatalogDataset('mbi_retail_spen_5eb92763')>,
#  <CatalogDataset('mbi_retail_spen_bfd9b3fb')>,
#  <CatalogDataset('mbi_households__a52da13')>,
#  <CatalogDataset('mbi_consumer_pr_70e4fbd')>,
#  <CatalogDataset('mbi_consumer_pr_d1cd7490')>,
#  <CatalogDataset('mbi_retail_spen_ffbcad71')>,
#  <CatalogDataset('mbi_retail_spen_628b3e25')>,
#  <CatalogDataset('mbi_consumer_sp_6b599fad')>,
#  <CatalogDataset('mbi_education_ab1322a4')>,
#  <CatalogDataset('mbi_retail_spen_959b2837')>,
#  <CatalogDataset('mbi_consumer_sp_26cf73a9')>,
#  <CatalogDataset('mbi_retail_spen_e2c1988e')>,
#  <CatalogDataset('mbi_retail_spen_14142fb4')>,
#  <CatalogDataset('mbi_retail_cent_73bd00d0')>,
#  <CatalogDataset('mbi_retail_spen_71ed889f')>,
#  <CatalogDataset('mbi_population_7c37e8d2')>,
#  <CatalogDataset('mbi_education_b3faf5f3')>,
#  <CatalogDataset('mbi_retail_spen_95e72b80')>,
#  <CatalogDataset('mbi_consumer_sp_dedd5576')>,
#  <CatalogDataset('mbi_consumer_sp_9a7b0cbd')>,
#  <CatalogDataset('mbi_consumer_sp_4e3123b7')>,
#  <CatalogDataset('mbi_households__23f746a9')>,
#  <CatalogDataset('mbi_population_b5973234')>,
#  <CatalogDataset('mbi_population_f8cc9f68')>,
#  <CatalogDataset('mbi_population_12e15a3f')>,
#  <CatalogDataset('mbi_population_7d5c9b58')>,
#  <CatalogDataset('mbi_education_80732cd')>,
#  <CatalogDataset('mbi_population_240d4d56')>,
#  <CatalogDataset('mbi_education_4ae1d50e')>,
#  <CatalogDataset('mbi_population_92d0ee3c')>,
#  <CatalogDataset('mbi_retail_spen_d00d641b')>,
#  <CatalogDataset('mbi_retail_turn_ee9532ae')>,
#  <CatalogDataset('mbi_purchasing__67ffb52')>,
#  <CatalogDataset('mbi_marital_sta_a68a7ec9')>,
#  <CatalogDataset('mbi_marital_sta_c20496ee')>,
#  <CatalogDataset('mbi_sociodemogr_d0d203f')>,
#  <CatalogDataset('mbi_retail_spen_179140fc')>,
#  <CatalogDataset('mbi_marital_sta_faf50e6b')>,
#  <CatalogDataset('mbi_marital_sta_676c857f')>,
#  <CatalogDataset('mbi_marital_sta_29244604')>,
#  <CatalogDataset('mbi_marital_sta_6d4a8559')>,
#  <CatalogDataset('mbi_education_f4887324')>,
#  <CatalogDataset('mbi_education_302cf48c')>,
#  <CatalogDataset('mbi_consumer_pr_85cc0535')>,
#  <CatalogDataset('mbi_consumer_pr_405e0e3b')>,
#  <CatalogDataset('mbi_consumer_pr_71f4fc68')>,
#  <CatalogDataset('mbi_population_d744417')>,
#  <CatalogDataset('mbi_retail_spen_32189ad3')>,
#  <CatalogDataset('mbi_population_a7baa4dd')>,
#  <CatalogDataset('mbi_population_47662835')>,
#  <CatalogDataset('mbi_sociodemogr_c700bf1c')>,
#  <CatalogDataset('mbi_retail_spen_366134c0')>,
#  <CatalogDataset('mbi_education_cea38973')>,
#  <CatalogDataset('mbi_population_136939b')>,
#  <CatalogDataset('mbi_population_7e96d5e8')>,
#  <CatalogDataset('mbi_population_dc8d2bec')>,
#  <CatalogDataset('mbi_population_71e2c41c')>,
#  <CatalogDataset('mbi_population_c38dcfaa')>,
#  <CatalogDataset('mbi_population_956eb25b')>,
#  <CatalogDataset('mbi_retail_turn_8963eda8')>,
#  <CatalogDataset('mbi_population_74d98571')>,
#  <CatalogDataset('mbi_education_1c7d8e8d')>,
#  <CatalogDataset('mbi_education_20d3049e')>,
#  <CatalogDataset('mbi_education_2e058ac6')>,
#  <CatalogDataset('mbi_population_43bf2e02')>,
#  <CatalogDataset('mbi_education_a867ecf')>,
#  <CatalogDataset('mbi_education_89792663')>,
#  <CatalogDataset('mbi_population_16200069')>,
#  <CatalogDataset('mbi_population_41569e34')>,
#  <CatalogDataset('mbi_population_b831b137')>,
#  <CatalogDataset('mbi_population_4222736e')>,
#  <CatalogDataset('mbi_population_fc7060e9')>,
#  <CatalogDataset('mbi_households__5e25ce97')>,
#  <CatalogDataset('mbi_population_40294f32')>,
#  <CatalogDataset('mbi_population_2d9c4518')>,
#  <CatalogDataset('mbi_population_54d31d6')>,
#  <CatalogDataset('mbi_population_499d6201')>,
#  <CatalogDataset('mbi_population_74ca8906')>,
#  <CatalogDataset('mbi_retail_spen_de784e49')>,
#  <CatalogDataset('mbi_population_a2991dc9')>,
#  <CatalogDataset('mbi_population_7f2f09bc')>,
#  <CatalogDataset('mbi_population_af9b0dc9')>,
#  <CatalogDataset('mbi_population_fd063cd8')>,
#  <CatalogDataset('mbi_consumer_pr_587a8dc1')>,
#  <CatalogDataset('mbi_population_c8491953')>,
#  <CatalogDataset('mbi_population_e4fc2cbe')>,
#  <CatalogDataset('mbi_population_128ae3a6')>,
#  <CatalogDataset('mbi_education_378ccce3')>,
#  <CatalogDataset('mbi_population_ffacf93a')>,
#  <CatalogDataset('mbi_education_9624b12b')>,
#  <CatalogDataset('mbi_population_3064fd97')>,
#  <CatalogDataset('mbi_population_e2d9a96b')>,
#  <CatalogDataset('mbi_education_39439103')>,
#  <CatalogDataset('mbi_population_f89041ae')>,
#  <CatalogDataset('mbi_population_a839556e')>,
#  <CatalogDataset('mbi_population_478bbbc3')>,
#  <CatalogDataset('mbi_population_87a15c36')>,
#  <CatalogDataset('mbi_population_fe818ea5')>,
#  <CatalogDataset('mbi_population_258fbbb9')>,
#  <CatalogDataset('mbi_population_616e9e3f')>,
#  <CatalogDataset('mbi_population_1c94706d')>,
#  <CatalogDataset('mbi_population_44e7cf10')>,
#  <CatalogDataset('mbi_population_4a68bc06')>,
#  <CatalogDataset('mbi_population_769cfa61')>,
#  <CatalogDataset('mbi_households__e3135e72')>,
#  <CatalogDataset('mbi_households__529bb220')>,
#  <CatalogDataset('mbi_population_abc14d43')>,
#  <CatalogDataset('mbi_consumer_pr_8a83111d')>,
#  <CatalogDataset('mbi_population_6d32d5c')>,
#  <CatalogDataset('mbi_population_9f1da2f7')>,
#  <CatalogDataset('mbi_population_e3f7984f')>,
#  <CatalogDataset('mbi_population_5e131025')>,
#  <CatalogDataset('mbi_population_ae87ca7a')>,
#  <CatalogDataset('mbi_population_9976c948')>,
#  <CatalogDataset('mbi_population_33106824')>,
#  <CatalogDataset('mbi_purchasing__7e784fa9')>,
#  <CatalogDataset('mbi_consumer_pr_ac6cc45b')>,
#  <CatalogDataset('mbi_population_c4c2d80f')>,
#  <CatalogDataset('mbi_population_8d74a32b')>,
#  <CatalogDataset('mbi_population_2af27f65')>,
#  <CatalogDataset('mbi_population_5114023a')>,
#  <CatalogDataset('mbi_population_ce57f616')>,
#  <CatalogDataset('mbi_education_10e7aab7')>,
#  <CatalogDataset('mbi_population_90824269')>,
#  <CatalogDataset('mbi_consumer_sp_fbde05a6')>,
#  <CatalogDataset('mbi_consumer_sp_26e2cfad')>,
#  <CatalogDataset('mbi_consumer_sp_3b5a536a')>,
#  <CatalogDataset('mbi_consumer_sp_a19bdf2e')>,
#  <CatalogDataset('mbi_population_5aefb1ef')>,
#  <CatalogDataset('mbi_population_2fd3aba0')>,
#  <CatalogDataset('mbi_population_68f8f0d5')>,
#  <CatalogDataset('mbi_population_bf8ee918')>,
#  <CatalogDataset('mbi_population_59f39389')>,
#  <CatalogDataset('mbi_households__e5b63cab')>,
#  <CatalogDataset('mbi_education_48a0352e')>,
#  <CatalogDataset('mbi_population_a77a929d')>,
#  <CatalogDataset('mbi_population_bf79d506')>,
#  <CatalogDataset('mbi_consumer_sp_d2fbe466')>,
#  <CatalogDataset('mbi_consumer_sp_66cdcdfc')>,
#  <CatalogDataset('mbi_consumer_sp_1763f32e')>,
#  <CatalogDataset('mbi_consumer_sp_c59a5a07')>,
#  <CatalogDataset('mbi_population_8b7faa5f')>,
#  <CatalogDataset('mbi_population_cff75bb3')>,
#  <CatalogDataset('mbi_population_f8718f91')>,
#  <CatalogDataset('mbi_population_341ee33b')>,
#  <CatalogDataset('mbi_population_b22eaf47')>,
#  <CatalogDataset('mbi_retail_spen_925acc12')>,
#  <CatalogDataset('mbi_population_afdcc52b')>,
#  <CatalogDataset('mbi_population_b4091b9')>,
#  <CatalogDataset('mbi_education_c0caec99')>,
#  <CatalogDataset('mbi_retail_spen_59d0722f')>,
#  <CatalogDataset('mbi_education_f2064218')>,
#  <CatalogDataset('mbi_education_8e4e3d70')>,
#  <CatalogDataset('mbi_education_b2fb2a3f')>,
#  <CatalogDataset('mbi_education_336089f1')>,
#  <CatalogDataset('mbi_consumer_pr_4a8e3dea')>,
#  <CatalogDataset('mbi_retail_spen_ac4ffab')>,
#  <CatalogDataset('mbi_education_8fb7c5fd')>,
#  <CatalogDataset('mbi_education_7a4855d5')>,
#  <CatalogDataset('mbi_education_99403e78')>,
#  <CatalogDataset('mbi_education_de6e0e32')>,
#  <CatalogDataset('mbi_retail_spen_c3140e65')>,
#  <CatalogDataset('mbi_education_97a54b22')>,
#  <CatalogDataset('mbi_consumer_sp_e363df4a')>,
#  <CatalogDataset('mbi_education_ed20829a')>,
#  <CatalogDataset('mbi_education_de67cf03')>,
#  <CatalogDataset('mbi_education_50cf9b0b')>,
#  <CatalogDataset('mbi_education_33a31435')>,
#  <CatalogDataset('mbi_education_29a29bcd')>,
#  <CatalogDataset('mbi_education_6a48b9e0')>,
#  <CatalogDataset('mbi_education_cc226caa')>,
#  <CatalogDataset('mbi_education_c2a8191a')>,
#  <CatalogDataset('mbi_education_18f605d6')>,
#  <CatalogDataset('mbi_education_2450f136')>,
#  <CatalogDataset('mbi_education_2057bd69')>,
#  <CatalogDataset('mbi_education_da0ac3b6')>,
#  <CatalogDataset('mbi_retail_turn_cd694587')>,
#  <CatalogDataset('mbi_marital_sta_8c6a94a5')>,
#  <CatalogDataset('mbi_population_da23a6ad')>,
#  <CatalogDataset('mbi_education_341b4904')>,
#  <CatalogDataset('mbi_education_9ff0e490')>,
#  <CatalogDataset('mbi_education_bb1e11d5')>,
#  <CatalogDataset('mbi_education_ea303241')>,
#  <CatalogDataset('mbi_purchasing__2b64f47')>,
#  <CatalogDataset('mbi_purchasing__afa42339')>,
#  <CatalogDataset('mbi_education_1b880265')>,
#  <CatalogDataset('mbi_education_c649c1a4')>,
#  <CatalogDataset('mbi_education_32248c13')>,
#  <CatalogDataset('mbi_consumer_sp_8c599d3c')>,
#  <CatalogDataset('mbi_retail_spen_74852ef5')>,
#  <CatalogDataset('mbi_purchasing__7a1dc666')>,
#  <CatalogDataset('mbi_purchasing__49aa311a')>,
#  <CatalogDataset('mbi_sociodemogr_bf4776ae')>,
#  <CatalogDataset('mbi_sociodemogr_48eabcd2')>,
#  <CatalogDataset('mbi_sociodemogr_a7b672ae')>,
#  <CatalogDataset('mbi_retail_spen_db24546b')>,
#  <CatalogDataset('mbi_purchasing__35515ec1')>,
#  <CatalogDataset('mbi_consumer_pr_8046648e')>,
#  <CatalogDataset('mbi_population_455945fd')>,
#  <CatalogDataset('mbi_purchasing__4d5fbd08')>,
#  <CatalogDataset('mbi_purchasing__72115dbe')>,
#  <CatalogDataset('mbi_purchasing__83037bfe')>,
#  <CatalogDataset('mbi_purchasing__a65ee8cb')>,
#  <CatalogDataset('mbi_households__4c36e6ce')>,
#  <CatalogDataset('mbi_marital_sta_1f4365c8')>,
#  <CatalogDataset('mbi_education_c7a8da7e')>,
#  <CatalogDataset('mbi_sociodemogr_baeafe91')>,
#  <CatalogDataset('mbi_sociodemogr_5bdd884a')>,
#  <CatalogDataset('mbi_sociodemogr_1c800e51')>,
#  <CatalogDataset('mbi_sociodemogr_34b172d4')>,
#  <CatalogDataset('mbi_sociodemogr_80fa578c')>,
#  <CatalogDataset('mbi_education_6dd7d678')>,
#  <CatalogDataset('mbi_education_37b7467a')>,
#  <CatalogDataset('bbva_origindistr_beccac0e')>,
#  <CatalogDataset('mbi_consumer_sp_51d11f12')>,
#  <CatalogDataset('mbi_education_d15ecc92')>,
#  <CatalogDataset('mbi_education_911c1555')>,
#  <CatalogDataset('mbi_population_1a9f3725')>,
#  <CatalogDataset('mbi_consumer_sp_95c54caa')>,
#  <CatalogDataset('mbi_education_ecdf994c')>,
#  <CatalogDataset('mbi_education_73bda418')>,
#  <CatalogDataset('mbi_retail_turn_77b14ad6')>,
#  <CatalogDataset('mbi_consumer_pr_4292e0dc')>,
#  <CatalogDataset('mbi_population_c9da91f3')>,
#  <CatalogDataset('mbi_population_43643b60')>,
#  <CatalogDataset('mbi_population_aed19ab4')>,
#  <CatalogDataset('mbi_population_f074b6b8')>,
#  <CatalogDataset('mbi_population_6be8055b')>,
#  <CatalogDataset('mbi_population_e268978d')>,
#  <CatalogDataset('mbi_population_bd228fa6')>,
#  <CatalogDataset('mbi_education_21568154')>,
#  <CatalogDataset('mbi_population_53cb6ef3')>,
#  <CatalogDataset('mbi_population_10a5fd7')>,
#  <CatalogDataset('mbi_population_3d9c9b3d')>,
#  <CatalogDataset('mbi_population_e7dc93f5')>,
#  <CatalogDataset('mbi_education_aec62b5c')>,
#  <CatalogDataset('mbi_marital_sta_5369a832')>,
#  <CatalogDataset('mbi_marital_sta_957d69df')>,
#  <CatalogDataset('mbi_population_86a083fa')>,
#  <CatalogDataset('mbi_households__a9b97e1')>,
#  <CatalogDataset('mbi_education_773f92a5')>,
#  <CatalogDataset('mbi_purchasing__e78441d9')>,
#  <CatalogDataset('mbi_population_f95255c3')>,
#  <CatalogDataset('mbi_purchasing__bd9b0ad3')>,
#  <CatalogDataset('mbi_education_415eefcb')>,
#  <CatalogDataset('mbi_education_d71b708e')>,
#  <CatalogDataset('mbi_education_a0d89cb1')>,
#  <CatalogDataset('mbi_consumer_sp_c52095ec')>,
#  <CatalogDataset('mbi_consumer_sp_23abf591')>,
#  <CatalogDataset('mbi_consumer_sp_1d828b79')>,
#  <CatalogDataset('mbi_consumer_sp_bfd1ac4c')>,
#  <CatalogDataset('mbi_retail_spen_d8c4d322')>,
#  <CatalogDataset('mbi_education_846a2135')>,
#  <CatalogDataset('mbi_education_c5937c3f')>,
#  <CatalogDataset('mbi_education_db808f46')>,
#  <CatalogDataset('mbi_marital_sta_4911d8dc')>,
#  <CatalogDataset('mbi_retail_spen_c5a5cb0a')>,
#  <CatalogDataset('mbi_sociodemogr_e0353759')>,
#  <CatalogDataset('mbi_sociodemogr_ddf1aff3')>,
#  <CatalogDataset('mbi_sociodemogr_2488a49c')>,
#  <CatalogDataset('mbi_education_32999cea')>,
#  <CatalogDataset('mbi_sociodemogr_3f309ba')>,
#  <CatalogDataset('mbi_sociodemogr_5364ffc6')>,
#  <CatalogDataset('mbi_retail_spen_80789b98')>,
#  <CatalogDataset('mbi_consumer_sp_54c4abc3')>,
#  <CatalogDataset('mbi_households__541b50b5')>,
#  <CatalogDataset('mbi_consumer_pr_47d227cf')>,
#  <CatalogDataset('mbi_purchasing__9c98e51b')>,
#  <CatalogDataset('mbi_sociodemogr_5b5931bd')>,
#  <CatalogDataset('mbi_sociodemogr_151b070c')>,
#  <CatalogDataset('mbi_sociodemogr_e108978b')>,
#  <CatalogDataset('mbi_retail_spen_7450f97a')>,
#  <CatalogDataset('mbi_retail_turn_7654ee53')>,
#  <CatalogDataset('mbi_sociodemogr_4cff6123')>,
#  <CatalogDataset('mbi_sociodemogr_d5908982')>,
#  <CatalogDataset('mbi_sociodemogr_5461519b')>,
#  <CatalogDataset('mbi_education_189e2205')>,
#  <CatalogDataset('mbi_retail_spen_6f67f691')>,
#  <CatalogDataset('mbi_retail_spen_178c8c6d')>,
#  <CatalogDataset('mbi_sociodemogr_67dcce6a')>,
#  <CatalogDataset('mbi_sociodemogr_a99b8d3')>,
#  <CatalogDataset('mbi_sociodemogr_2f9e11bd')>,
#  <CatalogDataset('mbi_sociodemogr_e0eff8ec')>,
#  <CatalogDataset('mbi_sociodemogr_b9522069')>,
#  <CatalogDataset('mbi_consumer_pr_c43a7e92')>,
#  <CatalogDataset('mbi_sociodemogr_ab4e015c')>,
#  <CatalogDataset('mbi_sociodemogr_f2f31340')>,
#  <CatalogDataset('mbi_sociodemogr_ba82d942')>,
#  <CatalogDataset('mbi_sociodemogr_d54c1e7f')>,
#  <CatalogDataset('mbi_sociodemogr_ae7c4ad3')>,
#  <CatalogDataset('mbi_sociodemogr_1c1af215')>,
#  <CatalogDataset('mbi_sociodemogr_4c55184')>,
#  <CatalogDataset('mbi_sociodemogr_90fd9e3')>,
#  <CatalogDataset('mbi_marital_sta_c04e775')>,
#  <CatalogDataset('mbi_sociodemogr_6be48ed8')>,
#  <CatalogDataset('mbi_sociodemogr_3dec1fd7')>,
#  <CatalogDataset('mbi_retail_spen_51ee9377')>,
#  <CatalogDataset('mbi_purchasing__76f7182f')>,
#  <CatalogDataset('mbi_purchasing__eb570392')>,
#  <CatalogDataset('mbi_consumer_pr_2d885c89')>,
#  <CatalogDataset('mbi_sociodemogr_ba72e486')>,
#  <CatalogDataset('mbi_sociodemogr_a1f5b96a')>,
#  <CatalogDataset('mbi_sociodemogr_482cc906')>,
#  <CatalogDataset('mbi_sociodemogr_74ba0dec')>,
#  <CatalogDataset('mbi_purchasing__5bb7b3be')>,
#  <CatalogDataset('mbi_consumer_pr_71810128')>,
#  <CatalogDataset('mbi_consumer_sp_d617a174')>,
#  <CatalogDataset('mbi_consumer_sp_b275be11')>,
#  <CatalogDataset('mbi_households__4ba4a1b4')>,
#  <CatalogDataset('mbi_consumer_sp_d8105e3c')>,
#  <CatalogDataset('mbi_retail_spen_b6aaa6dc')>,
#  <CatalogDataset('mbi_households__90dd4218')>,
#  <CatalogDataset('mbi_consumer_pr_4216592b')>,
#  <CatalogDataset('mbi_consumer_sp_9097456')>,
#  <CatalogDataset('mbi_consumer_sp_68b9815b')>,
#  <CatalogDataset('mbi_consumer_sp_aaac9d89')>,
#  <CatalogDataset('mbi_consumer_sp_2f9e7020')>,
#  <CatalogDataset('mbi_retail_spen_a22412a5')>,
#  <CatalogDataset('mbi_retail_spen_e2e3601c')>,
#  <CatalogDataset('mbi_retail_spen_371e4f')>,
#  <CatalogDataset('mbi_retail_spen_9f4f7e48')>,
#  <CatalogDataset('mbi_consumer_sp_aff46bfd')>,
#  <CatalogDataset('mbi_education_64db9744')>,
#  <CatalogDataset('mbi_education_ca53d0c9')>,
#  <CatalogDataset('mbi_consumer_sp_fae394ee')>,
#  <CatalogDataset('mbi_consumer_sp_d0af3e77')>,
#  <CatalogDataset('mbi_consumer_sp_1509de7d')>,
#  <CatalogDataset('mbi_households__5d5b1ed6')>,
#  <CatalogDataset('mbi_consumer_sp_bfd34dd7')>,
#  <CatalogDataset('mbi_consumer_sp_90236f6e')>,
#  <CatalogDataset('mbi_consumer_sp_f460f004')>,
#  <CatalogDataset('mbi_consumer_sp_c5a42c1b')>,
#  <CatalogDataset('mbi_consumer_sp_4ecb60c9')>,
#  <CatalogDataset('mbi_consumer_sp_cde9549c')>,
#  <CatalogDataset('mbi_consumer_sp_d0809991')>,
#  <CatalogDataset('mbi_consumer_sp_5fe0bb64')>,
#  <CatalogDataset('mbi_consumer_sp_ce830d51')>,
#  <CatalogDataset('mbi_consumer_sp_c7df2517')>,
#  <CatalogDataset('mbi_consumer_sp_ce0bd24c')>,
#  <CatalogDataset('mbi_consumer_sp_7bb411a7')>,
#  <CatalogDataset('mbi_consumer_sp_9f9eb8cf')>,
#  <CatalogDataset('mbi_consumer_sp_233ee921')>,
#  <CatalogDataset('mbi_consumer_sp_c937fcca')>,
#  <CatalogDataset('mbi_consumer_sp_5e11b3e4')>,
#  <CatalogDataset('mbi_consumer_sp_a8c1aec5')>,
#  <CatalogDataset('mbi_consumer_sp_1d71955d')>,
#  <CatalogDataset('mbi_consumer_pr_786039ed')>,
#  <CatalogDataset('mbi_consumer_sp_1c991bfb')>,
#  <CatalogDataset('mbi_consumer_sp_a9293242')>,
#  <CatalogDataset('mbi_households__f90930aa')>,
#  <CatalogDataset('mbi_households__8af896e3')>,
#  <CatalogDataset('mbi_households__56a61919')>,
#  <CatalogDataset('mbi_households__b2153c15')>,
#  <CatalogDataset('mbi_retail_spen_e66b9090')>,
#  <CatalogDataset('mbi_households__9e2c7244')>,
#  <CatalogDataset('mbi_households__6058cba3')>,
#  <CatalogDataset('mbi_households__bf3e0a4')>,
#  <CatalogDataset('mbi_households__7bfb8a4f')>,
#  <CatalogDataset('mbi_households__d0b84ddd')>,
#  <CatalogDataset('mbi_households__e7146470')>,
#  <CatalogDataset('mbi_households__da53f787')>,
#  <CatalogDataset('mbi_retail_spen_fa06f554')>,
#  <CatalogDataset('mbi_households__c510e2cc')>,
#  <CatalogDataset('mbi_households__91883048')>,
#  <CatalogDataset('mbi_households__dd3cdfa0')>,
#  <CatalogDataset('mbi_households__cad2ff8d')>,
#  <CatalogDataset('mbi_education_38ed8470')>,
#  <CatalogDataset('mbi_households__1afde171')>,
#  <CatalogDataset('mbi_households__52c47fac')>,
#  <CatalogDataset('mbi_households__4458cdcf')>,
#  <CatalogDataset('mbi_households__7c08c60c')>,
#  <CatalogDataset('mbi_households__68d4d6b1')>,
#  <CatalogDataset('mbi_consumer_pr_262c944e')>,
#  <CatalogDataset('mbi_retail_spen_709f5d')>,
#  <CatalogDataset('mbi_households__cd0c3ffa')>,
#  <CatalogDataset('mbi_households__9b6cb6e8')>,
#  <CatalogDataset('mbi_households__15ae55dc')>,
#  <CatalogDataset('mbi_households__83bb8b60')>,
#  <CatalogDataset('mbi_households__b523df4d')>,
#  <CatalogDataset('mbi_households__9ae0a9c1')>,
#  <CatalogDataset('mbi_households__3466a5b7')>,
#  <CatalogDataset('mbi_households__997e9144')>,
#  <CatalogDataset('mbi_households__dfc9029b')>,
#  <CatalogDataset('mbi_households__8a4ffc52')>,
#  <CatalogDataset('mbi_households__5c453314')>,
#  <CatalogDataset('mbi_households__d5c29eea')>,
#  <CatalogDataset('mbi_households__9c948cd1')>,
#  <CatalogDataset('mbi_households__66e99138')>,
#  <CatalogDataset('mbi_households__f6573901')>,
#  <CatalogDataset('mbi_households__2b96fac0')>,
#  <CatalogDataset('mbi_households__fb6792ca')>,
#  <CatalogDataset('mbi_households__fdd5fe53')>,
#  <CatalogDataset('mbi_households__3a2cc928')>,
#  <CatalogDataset('mbi_households__ec5a08b7')>,
#  <CatalogDataset('mbi_households__8e06a7f3')>,
#  <CatalogDataset('mbi_households__b11a7344')>,
#  <CatalogDataset('mbi_households__c88593a3')>,
#  <CatalogDataset('mbi_education_fafff1e')>,
#  <CatalogDataset('mbi_households__764c6196')>,
#  <CatalogDataset('mbi_retail_turn_42ff98b9')>,
#  <CatalogDataset('mbi_consumer_sp_58f735aa')>,
#  <CatalogDataset('mbi_households__69695999')>,
#  <CatalogDataset('mbi_households__372b910a')>,
#  <CatalogDataset('mbi_sociodemogr_5d30c6d9')>,
#  <CatalogDataset('mbi_households__f78d0c4c')>,
#  <CatalogDataset('mbi_households__a4f03ceb')>,
#  <CatalogDataset('mbi_marital_sta_290f87e6')>,
#  <CatalogDataset('mbi_households__cd156e0e')>,
#  <CatalogDataset('mbi_households__bf75c797')>,
#  <CatalogDataset('mbi_retail_cent_c00d1dfc')>,
#  <CatalogDataset('mbi_households__eaa86152')>,
#  <CatalogDataset('mbi_marital_sta_5e11da68')>,
#  <CatalogDataset('mbi_households__4478d9e')>,
#  <CatalogDataset('mbi_households__5da15f26')>,
#  <CatalogDataset('mbi_marital_sta_e945e70c')>,
#  <CatalogDataset('mbi_households__4818f2c8')>,
#  <CatalogDataset('mbi_households__7ccd4ea0')>,
#  <CatalogDataset('mbi_population_4c9ea8ad')>,
#  <CatalogDataset('mbi_households__452920ed')>,
#  <CatalogDataset('mbi_households__a9aa3313')>,
#  <CatalogDataset('mbi_households__b6ee8fb2')>,
#  <CatalogDataset('mbi_retail_cent_91a8fe18')>,
#  <CatalogDataset('mbi_retail_spen_9a2c77fc')>,
#  <CatalogDataset('mbi_retail_spen_286538c8')>,
#  <CatalogDataset('mbi_retail_spen_64a04118')>,
#  <CatalogDataset('mbi_retail_spen_cf4e7150')>,
#  <CatalogDataset('mbi_retail_cent_7684f9c0')>,
#  <CatalogDataset('mbi_retail_spen_86f1a870')>,
#  <CatalogDataset('mbi_retail_spen_eb0258d9')>,
#  <CatalogDataset('mbi_retail_spen_386e24b4')>,
#  <CatalogDataset('mbi_retail_spen_9338c9c')>,
#  <CatalogDataset('mbi_retail_spen_d89500da')>,
#  <CatalogDataset('mbi_retail_spen_ec0cd59d')>,
#  <CatalogDataset('mbi_retail_spen_eda1cda6')>,
#  <CatalogDataset('mbi_retail_spen_70768c40')>,
#  <CatalogDataset('mbi_population_e1529805')>,
#  <CatalogDataset('mbi_retail_spen_ad9d00ac')>,
#  <CatalogDataset('mbi_retail_spen_96e753c4')>,
#  <CatalogDataset('mbi_retail_cent_b123832')>,
#  <CatalogDataset('mbi_retail_cent_418c2702')>,
#  <CatalogDataset('mbi_retail_cent_b1884e39')>,
#  <CatalogDataset('mbi_retail_cent_104b0974')>,
#  <CatalogDataset('mbi_retail_cent_99309ad9')>,
#  <CatalogDataset('mbi_retail_turn_19d5f465')>,
#  <CatalogDataset('mbi_retail_turn_25703f0e')>,
#  <CatalogDataset('mbi_retail_turn_b9b65fe2')>,
#  <CatalogDataset('mbi_retail_turn_95e0a3be')>,
#  <CatalogDataset('mbi_retail_turn_147e3217')>,
#  <CatalogDataset('mbi_education_87bcae55')>,
#  <CatalogDataset('mbi_retail_turn_7c76fd5f')>,
#  <CatalogDataset('mbi_retail_turn_cb840b14')>,
#  <CatalogDataset('mbi_retail_turn_f1f26bd2')>,
#  <CatalogDataset('mbi_retail_turn_4ba5304f')>,
#  <CatalogDataset('mbi_purchasing__56d4d9b2')>,
#  <CatalogDataset('mbi_education_952fa1b')>,
#  <CatalogDataset('mbi_retail_turn_4da82cad')>,
#  <CatalogDataset('mbi_retail_turn_f033cfff')>,
#  <CatalogDataset('mbi_retail_turn_f8135317')>,
#  <CatalogDataset('mbi_purchasing__c2d48fc1')>,
#  <CatalogDataset('mbi_purchasing__bc2a0709')>,
#  <CatalogDataset('mbi_purchasing__f1ebc21c')>,
#  <CatalogDataset('mbi_purchasing__6dcbc2c6')>,
#  <CatalogDataset('mbi_purchasing__f81944c')>,
#  <CatalogDataset('mbi_purchasing__84a62bd4')>,
#  <CatalogDataset('mbi_purchasing__e3d4a3da')>,
#  <CatalogDataset('mbi_purchasing__5a80cc29')>,
#  <CatalogDataset('mbi_purchasing__c2527bf0')>,
#  <CatalogDataset('mbi_purchasing__46112d4d')>,
#  <CatalogDataset('mbi_education_afcbc85a')>,
#  <CatalogDataset('mbi_purchasing__dcc70505')>,
#  <CatalogDataset('mbi_purchasing__692787d4')>,
#  <CatalogDataset('mbi_purchasing__494e4978')>,
#  <CatalogDataset('mbi_purchasing__b413352')>,
#  <CatalogDataset('mbi_purchasing__41dadaba')>,
#  <CatalogDataset('mbi_purchasing__6fd2bc1')>,
#  <CatalogDataset('mbi_purchasing__b54d32ba')>,
#  <CatalogDataset('mbi_purchasing__d3134b00')>,
#  <CatalogDataset('mbi_purchasing__87a3e23c')>,
#  <CatalogDataset('mbi_purchasing__ee45ca6b')>,
#  <CatalogDataset('mbi_purchasing__b99055d2')>,
#  <CatalogDataset('mbi_purchasing__b15d896e')>,
#  <CatalogDataset('mbi_households__f3093d63')>,
#  <CatalogDataset('mbi_sociodemogr_ab2db058')>,
#  <CatalogDataset('mbi_purchasing__edbb1709')>,
#  <CatalogDataset('mbi_purchasing__15d2f1c3')>,
#  <CatalogDataset('mbi_marital_sta_b620160')>,
#  <CatalogDataset('mbi_education_9f17d26c')>,
#  <CatalogDataset('mbi_purchasing__4f1c1ca8')>,
#  <CatalogDataset('mbi_purchasing__c22d6fc8')>,
#  <CatalogDataset('mbi_purchasing__bc3ac75d')>,
#  <CatalogDataset('mbi_sociodemogr_dc2b5374')>,
#  <CatalogDataset('mbi_purchasing__9a05a28f')>,
#  <CatalogDataset('mbi_purchasing__ab8ea8c5')>,
#  <CatalogDataset('mbi_purchasing__9e816ee3')>,
#  <CatalogDataset('mbi_marital_sta_3cab91b6')>,
#  <CatalogDataset('mbi_purchasing__69bdc2d6')>,
#  <CatalogDataset('mbi_purchasing__4c8327cd')>,
#  <CatalogDataset('mbi_purchasing__6cf8fb63')>,
#  <CatalogDataset('mbi_purchasing__c1098dee')>,
#  <CatalogDataset('mbi_purchasing__7a42824')>,
#  <CatalogDataset('mbi_purchasing__5da8fc60')>,
#  <CatalogDataset('mbi_purchasing__1618bf73')>,
#  <CatalogDataset('mbi_purchasing__8f54483e')>,
#  <CatalogDataset('mbi_purchasing__191dbb94')>,
#  ...]

# %% [markdown]
# Nested filters can also be applied when requesting countries, categories, or geogrpahies:

# %%
catalog.clear_filters()
catalog.category('demographics').countries
# Out:
# [<Country('gtm')>,
#  <Country('tjk')>,
#  <Country('tca')>,
#  <Country('prt')>,
#  <Country('gab')>,
#  <Country('bwa')>,
#  <Country('aia')>,
#  <Country('png')>,
#  <Country('ury')>,
#  <Country('nga')>,
#  <Country('twn')>,
#  <Country('nzl')>,
#  <Country('svn')>,
#  <Country('swe')>,
#  <Country('qat')>,
#  <Country('ago')>,
#  <Country('ven')>,
#  <Country('khm')>,
#  <Country('swz')>,
#  <Country('omn')>,
#  <Country('tza')>,
#  <Country('uga')>,
#  <Country('mrt')>,
#  <Country('gnq')>,
#  <Country('mkd')>,
#  <Country('bel')>,
#  <Country('aze')>,
#  <Country('ecu')>,
#  <Country('pyf')>,
#  <Country('msr')>,
#  <Country('vir')>,
#  <Country('irn')>,
#  <Country('pak')>,
#  <Country('jpn')>,
#  <Country('phl')>,
#  <Country('guy')>,
#  <Country('tto')>,
#  <Country('jam')>,
#  <Country('ner')>,
#  <Country('fji')>,
#  <Country('srb')>,
#  <Country('bmu')>,
#  <Country('cpv')>,
#  <Country('mmr')>,
#  <Country('pri')>,
#  <Country('fro')>,
#  <Country('jor')>,
#  <Country('uzb')>,
#  <Country('rus')>,
#  <Country('mar')>,
#  <Country('dnk')>,
#  <Country('mli')>,
#  <Country('usa')>,
#  <Country('hun')>,
#  <Country('vnm')>,
#  <Country('per')>,
#  <Country('pan')>,
#  <Country('tcd')>,
#  <Country('grl')>,
#  <Country('ukr')>,
#  <Country('bgr')>,
#  <Country('rou')>,
#  <Country('alb')>,
#  <Country('zwe')>,
#  <Country('mus')>,
#  <Country('hkg')>,
#  <Country('lie')>,
#  <Country('pol')>,
#  <Country('xkx')>,
#  <Country('cri')>,
#  <Country('reu')>,
#  <Country('cyp')>,
#  <Country('moz')>,
#  <Country('lbn')>,
#  <Country('col')>,
#  <Country('and')>,
#  <Country('dom')>,
#  <Country('aus')>,
#  <Country('can')>,
#  <Country('cze')>,
#  <Country('ita')>,
#  <Country('nor')>,
#  <Country('lka')>,
#  <Country('pry')>,
#  <Country('esp')>,
#  <Country('bdi')>,
#  <Country('gmb')>,
#  <Country('est')>,
#  <Country('sle')>,
#  <Country('tgo')>,
#  <Country('chl')>,
#  <Country('kgz')>,
#  <Country('svk')>,
#  <Country('mda')>,
#  <Country('isl')>,
#  <Country('glp')>,
#  <Country('kaz')>,
#  <Country('tun')>,
#  <Country('mne')>,
#  <Country('npl')>,
#  <Country('mex')>,
#  <Country('geo')>,
#  <Country('bhs')>,
#  <Country('gha')>,
#  <Country('sgp')>,
#  <Country('tha')>,
#  <Country('sdn')>,
#  <Country('myt')>,
#  <Country('arm')>,
#  <Country('sen')>,
#  <Country('arg')>,
#  <Country('mco')>,
#  <Country('mys')>,
#  <Country('bih')>,
#  <Country('che')>,
#  <Country('lca')>,
#  <Country('bra')>,
#  <Country('isr')>,
#  <Country('cym')>,
#  <Country('ltu')>,
#  <Country('deu')>,
#  <Country('bfa')>,
#  <Country('mng')>,
#  <Country('abw')>,
#  <Country('cmr')>,
#  <Country('are')>,
#  <Country('sau')>,
#  <Country('mdv')>,
#  <Country('lux')>,
#  <Country('tur')>,
#  <Country('kwt')>,
#  <Country('nic')>,
#  <Country('chn')>,
#  <Country('egy')>,
#  <Country('kor')>,
#  <Country('brb')>,
#  <Country('dza')>,
#  <Country('aut')>,
#  <Country('irl')>,
#  <Country('zaf')>,
#  <Country('nam')>,
#  <Country('bhr')>,
#  <Country('gbr')>,
#  <Country('lva')>,
#  <Country('nld')>,
#  <Country('ben')>,
#  <Country('hrv')>,
#  <Country('ind')>,
#  <Country('eth')>,
#  <Country('mac')>,
#  <Country('gin')>,
#  <Country('brn')>,
#  <Country('guf')>,
#  <Country('bol')>,
#  <Country('mdg')>,
#  <Country('mtq')>,
#  <Country('hnd')>,
#  <Country('grc')>,
#  <Country('caf')>,
#  <Country('ncl')>,
#  <Country('slv')>,
#  <Country('zmb')>,
#  <Country('fra')>,
#  <Country('blr')>,
#  <Country('civ')>,
#  <Country('lso')>,
#  <Country('mwi')>,
#  <Country('fin')>,
#  <Country('hti')>,
#  <Country('idn')>,
#  <Country('ken')>,
#  <Country('bgd')>,
#  <Country('lbr')>,
#  <Country('mlt')>,
#  <Country('gnb')>,
#  <Country('cog')>]

# %%
catalog.clear_filters()
catalog.country('spain').categories

# %%
catalog.clear_filters()
catalog.country('usa').category('demographics').geographies
# Out:
# [<Geography('mbi_counties_141b61cd')>,
#  <Geography('od_placeclippe_48a89947')>,
#  <Geography('mbi_blockgroups_1ab060a')>,
#  <Geography('od_pumaclipped_b065909')>,
#  <Geography('ags_blockgroup_1c63771c')>,
#  <Geography('od_schooldistr_75493a16')>,
#  <Geography('od_stateclippe_8d79f5be')>,
#  <Geography('od_cbsaclipped_b6a32adc')>,
#  <Geography('od_schooldistr_6d5c417f')>,
#  <Geography('mbi_pc_5_digit_4b1682a6')>,
#  <Geography('od_countyclipp_caef1ec9')>,
#  <Geography('od_censustract_5962fe30')>,
#  <Geography('od_congression_6774ebb')>,
#  <Geography('od_blockclippe_9c508438')>,
#  <Geography('usct_censustract_784cc2ed')>,
#  <Geography('od_zcta5clippe_6b6ff33c')>,
#  <Geography('ags_q17_4739be4f')>,
#  <Geography('od_blockgroupc_3ab29c84')>,
#  <Geography('mbi_county_subd_e8e6ea23')>,
#  <Geography('od_schooldistr_f70c7e28')>]

# %% [markdown]
# And we can use all the filters at the same time:

# %%
catalog.clear_filters()
catalog.country('usa').category('demographics').geography('ags_blockgroup_1c63771c').datasets
# Out:
# [<CatalogDataset('ags_sociodemogr_e92b1637')>,
#  <CatalogDataset('ags_consumerspe_fe5d060a')>,
#  <CatalogDataset('ags_retailpoten_ddf56a1a')>,
#  <CatalogDataset('ags_consumerpro_e8344e2e')>,
#  <CatalogDataset('ags_businesscou_a8310a11')>,
#  <CatalogDataset('ags_crimerisk_9ec89442')>]

# %%
Catalog().country('usa').category('demographics').geography('od_countyclipp_caef1ec9').datasets
# Out:
# [<CatalogDataset('od_acs_550657ce')>,
#  <CatalogDataset('od_acs_1f614ee8')>,
#  <CatalogDataset('od_acs_c1c86582')>,
#  <CatalogDataset('od_acs_5b8fdefd')>,
#  <CatalogDataset('od_acs_c2868f47')>,
#  <CatalogDataset('od_acs_b581bfd1')>,
#  <CatalogDataset('od_acs_5c10acf4')>,
#  <CatalogDataset('od_acs_c5eb4b5e')>,
#  <CatalogDataset('od_tiger_66b9092c')>]
